# %%
import sys
sys.path.append('../Storage')

import pgConn
import PostgresSQL_table_queries
import CloudStorage

import pandas as pd
from datetime import datetime

# %%
pg_conn = pgConn.PgConn("historical")
df = pg_conn.get_stocks_prices()
# Out:
# Connection to the database successful!
# Table name set to: historical

# %%
df.head()
# Out:
#                          ref      book        date      open      high  \
# 0  https://finance.yahoo.com  tusd-btc  2023-08-09  0.000034  0.000034
# 1  https://finance.yahoo.com  tusd-btc  2023-08-08  0.000034  0.000034
# 2  https://finance.yahoo.com  tusd-btc  2023-08-07  0.000034  0.000034
# 3  https://finance.yahoo.com  tusd-btc  2023-08-06  0.000034  0.000034
# 4  https://finance.yahoo.com  tusd-btc  2023-08-05  0.000034  0.000034
#
#         low     close  adj_close  volume
# 0  0.000034  0.000034   0.000034  102207
# 1  0.000034  0.000034   0.000034   74850
# 2  0.000034  0.000034   0.000034   34264
# 3  0.000034  0.000034   0.000034   29283
# 4  0.000034  0.000034   0.000034   78352

# %%
df.count()
# Out:
# ref          114097
# book         114097
# date         114097
# open         114097
# high         114097
# low          114097
# close        114097
# adj_close    114097
# volume       114097
# dtype: int64

# %%
# Assuming df is your DataFrame
date_column_type = df['date'].dtype
print("Type of values in 'date' column:", date_column_type)
# Out:
# Type of values in 'date' column: object

# %%
class DataETL():
    
    def __init__(self, dataframe):
            self.df = dataframe
    
    class Export():
        def __init__(self, dataframe):
            self.cloudProvider = CloudStorage.CloudStorageProvider()
            self.df = dataframe
            
        def export_stocks_to_s3(self, bucket_name, prefix_path, file_format):
            # Initialize AWS storage
            aws_storage = self.cloudProvider.AWS()

            # Create a new bucket
            aws_storage.create_bucket(bucket_name)

            # Upload DataFrame with datetime subfolder structure
            aws_storage.upload_dataframe_with_timestamp(self.df, bucket_name, prefix_path, file_format)
            
        def export_stocks_to_s3_full_file(self, bucket_name, prefix_path, filename):
            # Initialize AWS storage
            aws_storage = self.cloudProvider.AWS()
            aws_storage.upload_dataframe_to_csv(self.df, bucket_name, filename, prefix_path)
            
    class Ingestion():
        
        def __init__(self, dataframe):
            self.df = dataframe
            self.cloudProvider = CloudStorage.CloudStorageProvider()
            
        def get_full_data_csv_file(self, bucket_name, prefix_path):
            # Initialize AWS storage
            aws_storage = self.cloudProvider.AWS()
            return aws_storage.get_csv_from_specific_folder(bucket_name, prefix_path)
    
    class Process():
        
        def __init__(self, dataframe):
            self.df = dataframe
        
        def getData():
            self.df = pg_conn.get_financial_news()
        
        def filter_by_current_date(self):
            # Get the current date as a string
            today_date_str = datetime.today().strftime('%Y-%m-%d')

            # Extract the year, month, and day from the current date string
            current_year, current_month, current_day = today_date_str.split('-')

            # Filter the DataFrame by comparing the substrings of the datetime column
            filtered_df = self.df[self.df['date'].str.startswith(f'{current_year}-{current_month}-{current_day}')]

            return filtered_df
        
        def filter_by_date_range(self, df, start_date, end_date):
            # Convert start_date and end_date strings to datetime objects
            start_date = pd.to_datetime(start_date)
            end_date = pd.to_datetime(end_date)
            
            df['date'] = pd.to_datetime(df['date'])
            # Filter by date range
            filtered_df = df[(df['date'] >= start_date) & (df['date'] <= end_date)]
            return filtered_df
        
        def filter_by_book(self, df, book=None):
            # Filter by book if specified
            if book is not None:
                filtered_df = df[df['book'] == book]
            return filtered_df
        
        def get_unique_by_date(self, df):
            # Sort the DataFrame by 'date' in descending order
            df_sorted = df.sort_values(by='date', ascending=False)

            # Drop duplicates, keeping only the first occurrence for each unique combination of book and date
            df_unique_latest = df_sorted.drop_duplicates(subset=['book', 'date'])
            df_unique_latest.count()
            return df_unique_latest
            
    class Transform():
        def extractStopWords():
            pass

# %%
FILTER_BY_CURRENT_DATE = False
FILTER_BY_RANGE_DATE = True
FILTER_BY_BOOK_DATE = False
# TODO 2017-2016
etl = DataETL(df)
etl_process = etl.Process(etl.df)
uniqued_df = etl_process.get_unique_by_date(etl_process.df)
processed_df = uniqued_df

if FILTER_BY_CURRENT_DATE == True:
    processed_df = etl_process.filter_by_current_date(uniqued_df)
    processed_df.head()
elif FILTER_BY_RANGE_DATE == True:
    start_date='2025-11-09'
    end_date='2025-11-16'
    processed_df = etl_process.filter_by_date_range(uniqued_df, start_date, end_date)
    processed_df.head()
elif FILTER_BY_BOOK_DATE == True:
    processed_df = etl_process.filter_by_current_date(uniqued_df)
    processed_df.head()

# %%
etl_export = etl.Export(processed_df)
bucket_name = "test-financial-stocks-bucket"
prefix_path = "stocks/crypto"
post_full_csv = False
post_to_s3 = True
now = datetime.now()
filename = f"{now.year}-{now.month:02}-{now.day:02}_full_record"
file_format = "csv"
if post_to_s3 == True:
    etl_export.export_stocks_to_s3(bucket_name, prefix_path, file_format)
if post_full_csv == True:
    etl_export.export_stocks_to_s3_full_file(bucket_name, prefix_path, filename)
# Out:
# Bucket 'test-financial-stocks-bucket' created successfully.
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=link-usd/year=2025/month=11/day=09/format=csv/20251109-link-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=ltc-usd/year=2025/month=11/day=09/format=csv/20251109-ltc-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=avax-usd/year=2025/month=11/day=09/format=csv/20251109-avax-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=arb-usd/year=2025/month=11/day=09/format=csv/20251109-arb-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=sol-usd/year=2025/month=11/day=09/format=csv/20251109-sol-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=floki-usd/year=2025/month=11/day=09/format=csv/20251109-floki-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=eth-usd/year=2025/month=11/day=09/format=csv/20251109-eth-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=shib-usd/year=2025/month=11/day=09/format=csv/20251109-shib-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=sushi-usd/year=2025/month=11/day=09/format=csv/20251109-sushi-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=chz-usd/year=2025/month=11/day=09/format=csv/20251109-chz-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=eth-btc/year=2025/month=11/day=09/format=csv/20251109-eth-btc.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=qnt-usd/year=2025/month=11/day=09/format=csv/20251109-qnt-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=bonk-usd/year=2025/month=11/day=09/format=csv/20251109-bonk-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=bal-usd/year=2025/month=11/day=09/format=csv/20251109-bal-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=axs-usd/year=2025/month=11/day=09/format=csv/20251109-axs-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=dydx-usd/year=2025/month=11/day=09/format=csv/20251109-dydx-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=ondo-usd/year=2025/month=11/day=09/format=csv/20251109-ondo-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=mana-usd/year=2025/month=11/day=09/format=csv/20251109-mana-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=trx-usd/year=2025/month=11/day=09/format=csv/20251109-trx-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=hbar-usd/year=2025/month=11/day=09/format=csv/20251109-hbar-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=sand-usd/year=2025/month=11/day=09/format=csv/20251109-sand-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=ada-usd/year=2025/month=11/day=09/format=csv/20251109-ada-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=bat-usd/year=2025/month=11/day=09/format=csv/20251109-bat-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=near-usd/year=2025/month=11/day=09/format=csv/20251109-near-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=wif-usd/year=2025/month=11/day=09/format=csv/20251109-wif-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=algo-usd/year=2025/month=11/day=09/format=csv/20251109-algo-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=fet-usd/year=2025/month=11/day=09/format=csv/20251109-fet-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=render-usd/year=2025/month=11/day=09/format=csv/20251109-render-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=dot-usd/year=2025/month=11/day=09/format=csv/20251109-dot-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=ton-usd/year=2025/month=11/day=09/format=csv/20251109-ton-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=atom-usd/year=2025/month=11/day=09/format=csv/20251109-atom-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=tusd-btc/year=2025/month=11/day=09/format=csv/20251109-tusd-btc.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=bch-usd/year=2025/month=11/day=09/format=csv/20251109-bch-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=snx-usd/year=2025/month=11/day=09/format=csv/20251109-snx-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=gala-usd/year=2025/month=11/day=09/format=csv/20251109-gala-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=sky-usd/year=2025/month=11/day=09/format=csv/20251109-sky-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=paxg-usd/year=2025/month=11/day=09/format=csv/20251109-paxg-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=enj-usd/year=2025/month=11/day=09/format=csv/20251109-enj-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=yfi-usd/year=2025/month=11/day=09/format=csv/20251109-yfi-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=tigres-usd/year=2025/month=11/day=09/format=csv/20251109-tigres-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=virtual-usd/year=2025/month=11/day=09/format=csv/20251109-virtual-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=xrp-usd/year=2025/month=11/day=09/format=csv/20251109-xrp-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=aave-usd/year=2025/month=11/day=09/format=csv/20251109-aave-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=omg-usd/year=2025/month=11/day=09/format=csv/20251109-omg-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=ldo-usd/year=2025/month=11/day=09/format=csv/20251109-ldo-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=lrc-usd/year=2025/month=11/day=09/format=csv/20251109-lrc-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=crv-usd/year=2025/month=11/day=09/format=csv/20251109-crv-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=doge-usd/year=2025/month=11/day=09/format=csv/20251109-doge-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=xlm-usd/year=2025/month=11/day=09/format=csv/20251109-xlm-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=psg-usd/year=2025/month=11/day
usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=bat-usd/year=2025/month=11/day=02/format=csv/20251102-bat-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=paxg-usd/year=2025/month=11/day=02/format=csv/20251102-paxg-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=snx-usd/year=2025/month=11/day=02/format=csv/20251102-snx-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=bal-usd/year=2025/month=11/day=02/format=csv/20251102-bal-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=btc-usd/year=2025/month=11/day=02/format=csv/20251102-btc-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=aave-usd/year=2025/month=11/day=02/format=csv/20251102-aave-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=arb-usd/year=2025/month=11/day=02/format=csv/20251102-arb-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=bonk-usd/year=2025/month=11/day=02/format=csv/20251102-bonk-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=lrc-usd/year=2025/month=11/day=02/format=csv/20251102-lrc-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=crv-usd/year=2025/month=11/day=02/format=csv/20251102-crv-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=ltc-usd/year=2025/month=11/day=02/format=csv/20251102-ltc-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=axs-usd/year=2025/month=11/day=02/format=csv/20251102-axs-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=bar-usd/year=2025/month=11/day=02/format=csv/20251102-bar-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=chz-usd/year=2025/month=11/day=02/format=csv/20251102-chz-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=link-usd/year=2025/month=11/day=02/format=csv/20251102-link-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=sand-usd/year=2025/month=11/day=02/format=csv/20251102-sand-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=avax-usd/year=2025/month=11/day=02/format=csv/20251102-avax-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=near-usd/year=2025/month=11/day=02/format=csv/20251102-near-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=bch-usd/year=2025/month=11/day=02/format=csv/20251102-bch-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=yfi-usd/year=2025/month=11/day=02/format=csv/20251102-yfi-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=fet-usd/year=2025/month=11/day=02/format=csv/20251102-fet-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=sky-usd/year=2025/month=11/day=02/format=csv/20251102-sky-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=gala-usd/year=2025/month=11/day=02/format=csv/20251102-gala-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=trx-usd/year=2025/month=11/day=02/format=csv/20251102-trx-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=dot-usd/year=2025/month=11/day=02/format=csv/20251102-dot-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=neiro-usd/year=2025/month=11/day=02/format=csv/20251102-neiro-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=enj-usd/year=2025/month=11/day=02/format=csv/20251102-enj-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=psg-usd/year=2025/month=11/day=02/format=csv/20251102-psg-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=xlm-usd/year=2025/month=11/day=02/format=csv/20251102-xlm-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=tigres-usd/year=2025/month=11/day=02/format=csv/20251102-tigres-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=ada-usd/year=2025/month=11/day=02/format=csv/20251102-ada-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=tusd-btc/year=2025/month=11/day=02/format=csv/20251102-tusd-btc.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=dydx-usd/year=2025/month=11/day=02/format=csv/20251102-dydx-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=eth-btc/year=2025/month=11/day=02/format=csv/20251102-eth-btc.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=atom-usd/year=2025/month=11/day=02/format=csv/20251102-atom-usd.csv'
# Data uploaded to S3 bucket 'test-financial-stocks-bucket' under folder 'stocks/crypto/book=ondo-usd/year=2025/month=11/day=02/format=csv/20251102-ondo-usd.csv'
# Task finished: all files were succesfully uploaded to S3 bucket test-financial-stocks-bucket

# %%
ingest_data = False
get_full_file = True
df_from_file = None

if ingest_data == True:
    etl_ingestion = etl.Ingestion(etl.df)
    bucket_name = "test-financial-stocks-bucket"
    prefix_path = "stocks/crypto/"
    year = ''
    mont = ''
    day = ''
    hour = ''
    minute = ''
    if get_full_file == True:
        df_from_file = etl_ingestion.get_full_data_csv_file(bucket_name, prefix_path)

# %%
if df_from_file is not None:
    print(df_from_file.head())
