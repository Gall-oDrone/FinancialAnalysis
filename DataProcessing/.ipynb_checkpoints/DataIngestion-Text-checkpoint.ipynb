# %%
import sys
sys.path.append('../Storage')

import pgConn
import PostgresSQL_table_queries
import CloudStorage

import pandas as pd
from datetime import datetime

# %%
table_name = PostgresSQL_table_queries.FINANCIAL_NEWS_TABLE_NAME
pg_conn = pgConn.PgConn(table_name)
df = pg_conn.get_financial_news()
# Out:
# Connection to the database successful!
# Table name set to: financial_news_241118

# %%
print(f"Total news articles queried: {df.shape[0]}")
# Out:
# Total news articles queried: 2690

# %%
df.head()
# Out:
#                                         id         source  \
# 0  214287918542718613358470608080600126044      TheStreet
# 1   38252604400503696170355593828287690149      TheStreet
# 2  203190672811611076623544141482628794189  CoinMarketCap
# 3  141589963459276634875970714304065101103        Fortune
# 4   97877627616960187638742954914577909517   Investopedia
#
#                                             headline  \
# 0  $1.5M Bitcoin prediction firm Ark Invest calls...
# 1  $360M in crypto liquidations as Bitcoin whipsa...
# 2  $635 Million Liquidated in 24 Hours as Bitcoin...
# 3  $749 million ‘treasure hunt’: Crypto miner fig...
# 4  'Bitcoin $100K' Was So Near, Yet So Far. What'...
#
#                                                 href  \
# 0  https://finance.yahoo.com/news/1-5m-bitcoin-pr...
# 1  https://finance.yahoo.com/news/360m-crypto-liq...
# 2  https://finance.yahoo.com/news/635-million-liq...
# 3  https://finance.yahoo.com/news/749-million-tre...
# 4  https://finance.yahoo.com/news/bitcoin-100k-ne...
#
#                                              summary  \
# 0  According to ARK Invest's latest Bitcoin month...
# 1  Bitcoin's sharp price swings triggered $366M i...
# 2  $635 Million Liquidated in 24 Hours as Bitcoin...
# 3  $749 million ‘treasure hunt’: Crypto miner fig...
# 4  Bitcoin's price has pulled back from levels ne...
#
#                                              content           author  \
# 0  The Cathie Wood-owned firm believes Bitcoin, w...     Anushka Basu
# 1  In the past 24 hours, about $366 million worth...     Anushka Basu
# 2  Bitcoin crossed $94,000 on April 23, triggerin...      Ayesha Aziz
# 3  An early Bitcoin miner says he lost a fortune ...  Eleanor Pringle
# 4  Investopedia / Illustration by Alice Morgan / ...      Kyle Torpey
#
#      minsread                  datetime
# 0  2 min read  2025-03-12T16:42:53.000Z
# 1  1 min read  2025-04-14T18:08:41.000Z
# 2  2 min read  2025-04-24T01:11:12.000Z
# 3  4 min read  2024-11-21T12:52:14.000Z
# 4  3 min read  2024-11-26T19:03:43.000Z

# %%
def delete_records_for_current_date(df, pg_conn):
    if df is None:
        print("DataFrame is empty. No records to delete.")
        return
        
    # Filter DataFrame for records with today's date
    current_date = datetime.now().strftime("%Y-%m-%d")
    today_records = df[df['datetime'].str.startswith(current_date)]

    # Extract date strings
    date_strings = today_records['datetime'].tolist()

    # Call the delete_records_by_date method
    pg_conn.delete_records_by_date(date_strings)

# Then call the delete_records_for_current_date method
#delete_records_for_current_date(df, pg_conn)
#list_ids = ["11111"]
#pg_conn.delete_records_by_ids(list_ids)

# %%
class DataETL():
    
    def __init__(self, dataframe):
            self.df = dataframe
            self.cloudProvider = CloudStorage.CloudStorageProvider()
            
    class Export():
        def __init__(self, dataframe):
            self.df = dataframe
            self.cloudProvider = CloudStorage.CloudStorageProvider()
            
        def set_dataframe(self, dataframe):
            self.df = dataframe
        
        def export_text_to_s3(self, bucket_name, prefix_path, file_format):
            # Initialize AWS storage
            aws_storage = self.cloudProvider.AWS()

            # Create a new bucket
            aws_storage.create_bucket(bucket_name)

            # Upload DataFrame with datetime subfolder structure
            aws_storage.upload_dataframe_with_datetime_subfolders(self.df, bucket_name, prefix_path, file_format)
        
        def export_text_to_s3_full_file(self, bucket_name, prefix_path, filename):
            aws_storage = self.cloudProvider.AWS()
            aws_storage.upload_dataframe_to_csv(self.df, bucket_name, filename, prefix_path)
            
    class Ingestion():
        def __init__(self, dataframe):
            self.df = dataframe
            self.cloudProvider = CloudStorage.CloudStorageProvider()
            
        def get_full_data_csv_file(self, bucket_name, prefix_path):
            # Initialize AWS storage
            aws_storage = self.cloudProvider.AWS()
            return aws_storage.get_csv_from_specific_folder(bucket_name, prefix_path)
        
        def get_data_csv_file_by_datetime(self, bucket_name, prefix_path, year, month, day, hour, minute):
            # Initialize AWS storage
            aws_storage = self.cloudProvider.AWS()
            return aws_storage.get_dataframe_from_specific_datetime(bucket_name, prefix_path, year=None, month=None, day=None, hour=None, minute=None)
    
    class Process():
        
        def __init__(self, dataframe):
            self.df = dataframe
        
        def getData():
            self.df = pg_conn.get_financial_news()
        
        def filter_by_current_date(self):
            # Get the current date as a string
            today_date_str = datetime.today().strftime('%Y-%m-%d')

            # Extract the year, month, and day from the current date string
            current_year, current_month, current_day = today_date_str.split('-')

            # Filter the DataFrame by comparing the substrings of the datetime column
            #filtered_df = self.df[self.df['datetime'].str.startswith(f'2025-06-05')]
            filtered_df = self.df[self.df['datetime'].str.startswith(f'{current_year}-{current_month}-{current_day}')]

            return filtered_df
            
    class Transform():
        def extractStopWords():
            pass

# %%
etl = DataETL(df)
etl_process = etl.Process(etl.df)
filtered_df = etl_process.filter_by_current_date()
filtered_df.head()
# Out:
#                                            id         source  \
# 496   143277927326762124638203460491263117529       CoinDesk
# 1617  229817259251900788716594350563083576958      TheStreet
# 1852  143277927326762124638203460491263117529       CoinDesk
# 2221  143277927326762124638203460491263117529  Yahoo Finance
# 2435  110976521910093067139536351006804014858      TheStreet
#
#                                                headline  \
# 496   Bitcoin Threatens $100K, Crypto Losses Grow as...
# 1617  Mark Cuban backs Elon Musk’s idea of launching...
# 1852  PTSD-Afflicted Crypto Investors Hit the Sell B...
# 2221  The race to embrace stablecoins heats up on Wa...
# 2435  Uber CEO says stablecoins could reduce cross-b...
#
#                                                    href  \
# 496   https://finance.yahoo.com/news/bitcoin-threate...
# 1617  https://finance.yahoo.com/news/mark-cuban-back...
# 1852  https://finance.yahoo.com/news/ptsd-afflicted-...
# 2221  https://finance.yahoo.com/news/the-race-to-emb...
# 2435  https://finance.yahoo.com/news/uber-ceo-says-s...
#
#                                                 summary  \
# 496   Bitcoin Threatens $100K, Crypto Losses Grow as...
# 1617  Mark Cuban backs Elon Musk’s idea of launching...
# 1852  PTSD-Afflicted Crypto Investors Hit the Sell B...
# 2221  The race to embrace stablecoins heats up on Wa...
# 2435  Uber CEO says stablecoins could reduce cross-b...
#
#                                                 content  \
# 496   In This Article:\nStockStory Top Pick\nCOIN\n+...
# 1617  In This Article:\nTSLA\n-14.26%\nMark Cuban ba...
# 1852  In This Article:\nStockStory Top Pick\nCOIN\n+...
# 2221  In This Article:\nUSDT-USD\n+0.05%\nWFC\n+1.35...
# 2435  In This Article:\nStockStory Top Pick\nUBER\n+...
#
#                                   author    minsread                  datetime
# 496                         Tom Carreras  1 min read  2025-06-05T21:01:37.000Z
# 1617                         Anand Sinha  3 min read  2025-06-05T21:47:44.000Z
# 1852                        Tom Carreras  1 min read  2025-06-05T18:26:06.000Z
# 2221  David Hollerith\n· Senior Reporter  4 min read  2025-06-05T20:06:52.000Z
# 2435                       Mehab Qureshi  2 min read  2025-06-05T22:05:49.000Z

# %%
print(f"Total filtered news articles queried: {filtered_df.shape[0]}")
# Out:
# Total filtered news articles queried: 5

# %%
export_rows_to_s3 = True
etl_export = etl.Export(filtered_df)
bucket_name = "test-financial-news-bucket"
prefix_path = "news/crypto"
file_format = "csv"
if export_rows_to_s3 == True and not filtered_df.empty:
    etl_export.export_text_to_s3(bucket_name, prefix_path, file_format)
# Out:
# Bucket 'test-financial-news-bucket' created successfully.
# Data for row 496 with id '143277927326762124638203460491263117529' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2025/month=06/day=05/hour=21/minute=01/second=37/format=csv/143277927326762124638203460491263117529.csv'
# Data for row 1617 with id '229817259251900788716594350563083576958' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2025/month=06/day=05/hour=21/minute=47/second=44/format=csv/229817259251900788716594350563083576958.csv'
# Data for row 1852 with id '143277927326762124638203460491263117529' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2025/month=06/day=05/hour=18/minute=26/second=06/format=csv/143277927326762124638203460491263117529.csv'
# Data for row 2221 with id '143277927326762124638203460491263117529' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2025/month=06/day=05/hour=20/minute=06/second=52/format=csv/143277927326762124638203460491263117529.csv'
# Data for row 2435 with id '110976521910093067139536351006804014858' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2025/month=06/day=05/hour=22/minute=05/second=49/format=csv/110976521910093067139536351006804014858.csv'
# Task finished: all files were succesfully uploaded to S3 bucket test-financial-news-bucket

# %%
post_full_csv = False
if (post_full_csv == True) and not filtered_df.empty:
    now = datetime.now()
    filename = f"{now.year}-{now.month:02}-{now.day:02}_full_record"
    etl_export.set_dataframe(etl.df)
    etl_export.export_text_to_s3_full_file(bucket_name, prefix_path, filename)

# %%
ingest_data = False
get_full_file = True
get_by_datetime = False
df_from_file = None

if ingest_data == True:
    etl_ingestion = etl.Ingestion(etl.df)
    bucket_name = "test-financial-news-bucket"
    prefix_path = "news/crypto/"
    year = '2024'
    month = '08'
    day = '01'
    hour = ''
    minute = ''
    if get_full_file == True:
        filename = f"{year}-{month}-{day}_full_record.csv"
        full_path = f"{prefix_path}{filename}"
        df_from_file = etl_ingestion.get_full_data_csv_file(bucket_name, full_path)
    elif get_by_datetime == True:
        df_from_file = etl_ingestion.get_data_csv_file_by_datetime(bucket_name, prefix_path, year, month, day, hour, minute)

# %%
if df_from_file is not None:
    print(df_from_file.count())

# %%
# Assuming df is your DataFrame
targetId = ''
if len(targetId) > 0:
    filtered_content = filtered_df.loc[filtered_df['id'] == targetId, 'content']

    # If you want to display the full content, convert it to a list or display all rows
    full_content = filtered_content.tolist()

    print(full_content)
