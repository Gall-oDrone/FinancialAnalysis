# %%
import sys
sys.path.append('../Storage')

import pgConn
import PostgresSQL_table_queries
import CloudStorage

import pandas as pd
from datetime import datetime

# %%
table_name = PostgresSQL_table_queries.FINANCIAL_NEWS_TABLE_NAME
pg_conn = pgConn.PgConn(table_name)
df = pg_conn.get_financial_news()
# Out:
# Connection to the database successful!
# Table name set to: financial_news_241118

# %%
print(f"Total news articles queried: {df.shape[0]}")
# Out:
# Total news articles queried: 8665

# %%
df.head()
# Out:
#                                         id       source  \
# 0   45876047236640910017045281208231353781  Motley Fool
# 1  220799662638683730910896676542146227596     CoinDesk
# 2   47514014236007877639078711690178672970  Motley Fool
# 3  152599983586513563130066357372522406611  Coinspeaker
# 4  214287918542718613358470608080600126044    TheStreet
#
#                                             headline  \
# 0  "Tokenized" Stocks Are Breaking Down Barriers....
# 1  "We're a Tweet Away from a 15% Dump:" CEO on C...
# 2  $1 Billion in New Capital Could Soon Flow to X...
# 3  $1.2B Left BTC ETFs This Week, but Not All is ...
# 4  $1.5M Bitcoin prediction firm Ark Invest calls...
#
#                                                 href  \
# 0  https://finance.yahoo.com/news/tokenized-stock...
# 1  https://finance.yahoo.com/video/were-tweet-awa...
# 2  https://finance.yahoo.com/news/1-billion-capit...
# 3  https://finance.yahoo.com/news/1-2b-left-btc-e...
# 4  https://finance.yahoo.com/news/1-5m-bitcoin-pr...
#
#                                              summary  \
# 0
# 1
# 2
# 3
# 4  According to ARK Invest's latest Bitcoin month...
#
#                                              content  \
# 0  In This Article:\nHOOD\n+0.23%\nAAPL\n-0.12%\n...
# 1  In today's Markets Outlook, CoinDesk's Jennife...
# 2  In this article:\nXRP-USD\n-0.06%\nKey Points\...
# 3  In this article:\nBTC-USD\n+0.22%\nSOSO-USD\n+...
# 4  The Cathie Wood-owned firm believes Bitcoin, w...
#
#                            author    minsread                  datetime
# 0  Alex Carchidi, The Motley Fool  6 min read  2025-07-23T17:19:00.000Z
# 1                        CoinDesk              2025-10-31T17:34:16.000Z
# 2  Alex Carchidi, The Motley Fool  5 min read  2025-11-02T11:35:00.000Z
# 3                     Parth Dubey  2 min read  2025-10-18T10:15:49.000Z
# 4                    Anushka Basu  2 min read  2025-03-12T16:42:53.000Z

# %%
def delete_records_for_current_date(df, pg_conn):
    if df is None:
        print("DataFrame is empty. No records to delete.")
        return
        
    # Filter DataFrame for records with today's date
    current_date = datetime.now().strftime("%Y-%m-%d")
    today_records = df[df['datetime'].str.startswith(current_date)]

    # Extract date strings
    date_strings = today_records['datetime'].tolist()

    # Call the delete_records_by_date method
    pg_conn.delete_records_by_date(date_strings)

# Then call the delete_records_for_current_date method
#delete_records_for_current_date(df, pg_conn)
#list_ids = ["11111"]
#pg_conn.delete_records_by_ids(list_ids)

# %%
class DataETL():
    
    def __init__(self, dataframe):
            self.df = dataframe
            self.cloudProvider = CloudStorage.CloudStorageProvider()
            
    class Export():
        def __init__(self, dataframe):
            self.df = dataframe
            self.cloudProvider = CloudStorage.CloudStorageProvider()
            
        def set_dataframe(self, dataframe):
            self.df = dataframe
        
        def export_text_to_s3(self, bucket_name, prefix_path, file_format):
            # Initialize AWS storage
            aws_storage = self.cloudProvider.AWS()

            # Create a new bucket
            aws_storage.create_bucket(bucket_name)

            # Upload DataFrame with datetime subfolder structure
            aws_storage.upload_dataframe_with_datetime_subfolders(self.df, bucket_name, prefix_path, file_format)
        
        def export_text_to_s3_full_file(self, bucket_name, prefix_path, filename):
            aws_storage = self.cloudProvider.AWS()
            aws_storage.upload_dataframe_to_csv(self.df, bucket_name, filename, prefix_path)
            
    class Ingestion():
        def __init__(self, dataframe):
            self.df = dataframe
            self.cloudProvider = CloudStorage.CloudStorageProvider()
            
        def get_full_data_csv_file(self, bucket_name, prefix_path):
            # Initialize AWS storage
            aws_storage = self.cloudProvider.AWS()
            return aws_storage.get_csv_from_specific_folder(bucket_name, prefix_path)
        
        def get_data_csv_file_by_datetime(self, bucket_name, prefix_path, year, month, day, hour, minute):
            # Initialize AWS storage
            aws_storage = self.cloudProvider.AWS()
            return aws_storage.get_dataframe_from_specific_datetime(bucket_name, prefix_path, year=None, month=None, day=None, hour=None, minute=None)
    
    class Process():
        
        def __init__(self, dataframe):
            self.df = dataframe
        
        def getData():
            self.df = pg_conn.get_financial_news()
        
        def filter_by_current_date(self):
            # Get the current date as a string
            today_date_str = datetime.today().strftime('%Y-%m-%d')

            # Extract the year, month, and day from the current date string
            current_year, current_month, current_day = today_date_str.split('-')

            # Filter the DataFrame by comparing the substrings of the datetime column
            filtered_df = self.df[self.df['datetime'].str.startswith(f'2026-01-27')]
            #filtered_df = self.df[self.df['datetime'].str.startswith(f'{current_year}-{current_month}-{current_day}')]

            return filtered_df
            
    class Transform():
        def extractStopWords():
            pass

# %%
etl = DataETL(df)
etl_process = etl.Process(etl.df)
filtered_df = etl_process.filter_by_current_date()
filtered_df.head()
# Out:
#                                           id          source  \
# 240  168566118104308947473269545212042573694      BeInCrypto
# 271  244421434519614295171468139725785106283     Motley Fool
# 282   27716076029405896859730809504195546335      BeInCrypto
# 316   37820427211444995154919623368629314632  GOBankingRates
# 435  255841634908860507023675387795085023220      99bitcoins
#
#                                               headline  \
# 240  3 Privacy Coins Crypto Whales are Buying and S...
# 271  3 Things Investors Need to Know About the ARK ...
# 282  39% of Merchants, 60% of Banks: Crypto Payment...
# 316  5 Best Crypto To Invest in for 2026: Top Picks...
# 435  ASTER Crypto Price Jumps on Buybacks and CZ Ba...
#
#                                                   href summary  \
# 240  https://finance.yahoo.com/news/3-privacy-coins...
# 271  https://finance.yahoo.com/news/3-things-invest...
# 282  https://finance.yahoo.com/news/39-merchants-60...
# 316  https://finance.yahoo.com/news/experts-predict...
# 435  https://finance.yahoo.com/news/aster-crypto-pr...
#
#                                                content  \
# 240  In this article:\nZEC-USD\n-6.53%\nPrivacy coi...
# 271  In this article:\nBTC-USD\n-1.31%\nIt's been a...
# 282  In this article:\nBTC-USD\n-1.08%\nPYPL\n-2.58...
# 316  In this article:\nETH-USD\n-1.14%\nThe cryptoc...
# 435  In this article:\nASTER36341-USD\n-3.16%\nETH-...
#
#                             author    minsread                  datetime
# 240                Ananda Banerjee  5 min read  2026-01-28T15:28:16.000Z
# 271  Todd Shriber, The Motley Fool  4 min read  2026-01-28T18:05:00.000Z
# 282                     Oihyun Kim  4 min read  2026-01-28T02:00:00.000Z
# 316                    Lydia Kibet  2 min read  2026-01-28T17:37:03.000Z
# 435                         Fatima  2 min read  2026-01-28T11:00:36.000Z

# %%
print(f"Total filtered news articles queried: {filtered_df.shape[0]}")
# Out:
# Total filtered news articles queried: 96

# %%
export_rows_to_s3 = True
etl_export = etl.Export(filtered_df)
bucket_name = "test-financial-news-bucket"
prefix_path = "news/crypto"
file_format = "csv"
if export_rows_to_s3 == True and not filtered_df.empty:
    etl_export.export_text_to_s3(bucket_name, prefix_path, file_format)
# Out:
# Bucket 'test-financial-news-bucket' created successfully.
# Data for row 240 with id '168566118104308947473269545212042573694' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=15/minute
uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=06/minute=19/second=09/format=csv/20465531076527780494304214190100600789.csv'
# Data for row 4366 with id '191156753254293287170867740936140887308' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=09/minute=33/second=11/format=csv/191156753254293287170867740936140887308.csv'
# Data for row 4401 with id '90358827454853797850392275413275007506' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=20/minute=12/second=06/format=csv/90358827454853797850392275413275007506.csv'
# Data for row 4405 with id '221958455635209086205678933611636700784' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=16/minute=20/second=51/format=csv/221958455635209086205678933611636700784.csv'
# Data for row 4600 with id '23903660813047322285323646012073134846' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=12/minute=20/second=00/format=csv/23903660813047322285323646012073134846.csv'
# Data for row 4621 with id '179203440669239014381153178792138365663' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=12/minute=59/second=00/format=csv/179203440669239014381153178792138365663.csv'
# Data for row 4688 with id '233387832460846347288402114331027399548' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=10/minute=55/second=54/format=csv/233387832460846347288402114331027399548.csv'
# Data for row 4800 with id '47436060326312191993938570531755538748' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=20/minute=40/second=00/format=csv/47436060326312191993938570531755538748.csv'
# Data for row 4879 with id '139214626379131966826290645351050649677' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=07/minute=35/second=29/format=csv/139214626379131966826290645351050649677.csv'
# Data for row 4922 with id '181449407682710244537474140647952731731' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=11/minute=02/second=15/format=csv/181449407682710244537474140647952731731.csv'
# Data for row 4925 with id '42102391920338528498540324439102696471' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=23/minute=26/second=50/format=csv/42102391920338528498540324439102696471.csv'
# Data for row 4976 with id '193466378015271946764133534781988574413' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=13/minute=14/second=31/format=csv/193466378015271946764133534781988574413.csv'
# Data for row 5130 with id '239574201448145296165816327937198265072' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=23/minute=07/second=46/format=csv/239574201448145296165816327937198265072.csv'
# Data for row 5176 with id '89765009222692903307192176159170944486' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=00/minute=35/second=08/format=csv/89765009222692903307192176159170944486.csv'
# Data for row 5361 with id '102726463468051787769163519782489643784' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=08/minute=07/second=03/format=csv/102726463468051787769163519782489643784.csv'
# Data for row 5519 with id '51068790499602341423097530881387001947' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=10/minute=49/second=40/format=csv/51068790499602341423097530881387001947.csv'
# Data for row 5521 with id '228158496638721180183343606198932387309' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=00/minute=48/second=26/format=csv/228158496638721180183343606198932387309.csv'
# Data for row 5680 with id '161232939470974961976231208781220430362' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=19/minute=40/second=24/format=csv/161232939470974961976231208781220430362.csv'
# Data for row 5724 with id '158758368445821951973138783841472735932' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=15/minute=10/second=37/format=csv/158758368445821951973138783841472735932.csv'
# Data for row 5743 with id '126189429724044412498550574251532704352' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=11/minute=18/second=29/format=csv/126189429724044412498550574251532704352.csv'
# Data for row 6128 with id '27088100310508474746158262830944776153' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=16/minute=59/second=40/format=csv/27088100310508474746158262830944776153.csv'
# Data for row 6554 with id '939765781399304261735718163758366667' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=06/minute=50/second=00/format=csv/939765781399304261735718163758366667.csv'
# Data for row 6555 with id '77846324167353821753227183139285250739' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=15/minute=14/second=21/format=csv/77846324167353821753227183139285250739.csv'
# Data for row 6561 with id '247499976105043142631307251486483632374' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=14/minute=29/second=55/format=csv/247499976105043142631307251486483632374.csv'
# Data for row 6613 with id '174335080786794530133223126008691759546' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=08/minute=10/second=00/format=csv/174335080786794530133223126008691759546.csv'
# Data for row 6624 with id '102972341500179766192258885400671683013' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=17/minute=42/second=22/format=csv/102972341500179766192258885400671683013.csv'
# Data for row 6765 with id '136268187900448767921314389160564482627' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=18/minute=50/second=47/format=csv/136268187900448767921314389160564482627.csv'
# Data for row 6776 with id '81578801550579591347298975051638061778' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=21/minute=39/second=57/format=csv/81578801550579591347298975051638061778.csv'
# Data for row 6854 with id '209075918670941384217225993783486916254' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=21/minute=11/second=15/format=csv/209075918670941384217225993783486916254.csv'
# Data for row 6870 with id '2555143252775150070604613987861112733' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=07/minute=50/second=09/format=csv/2555143252775150070604613987861112733.csv'
# Data for row 6964 with id '246151738467551958442632378190457026987' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=12/minute=20/second=32/format=csv/246151738467551958442632378190457026987.csv'
# Data for row 6977 with id '289181204349765467755799680113603463440' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=16/minute=36/second=00/format=csv/289181204349765467755799680113603463440.csv'
# Data for row 7003 with id '288594343384161234931264020984466484943' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=12/minute=12/second=24/format=csv/288594343384161234931264020984466484943.csv'
# Data for row 7043 with id '1848794267709278189236030294585115944' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=16/minute=51/second=16/format=csv/1848794267709278189236030294585115944.csv'
# Data for row 7176 with id '163955120669770419746730212401012782493' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=09/minute=37/second=51/format=csv/163955120669770419746730212401012782493.csv'
# Data for row 7235 with id '112227251553698778484020442889518008684' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=15/minute=29/second=09/format=csv/112227251553698778484020442889518008684.csv'
# Data for row 7246 with id '271116150800564886958798885030784329320' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=05/minute=27/second=24/format=csv/271116150800564886958798885030784329320.csv'
# Data for row 7609 with id '336944471900036065905063635105098104689' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=12/minute=14/second=57/format=csv/336944471900036065905063635105098104689.csv'
# Data for row 7612 with id '39413221101263777073963297351951617804' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=04/minute=46/second=37/format=csv/39413221101263777073963297351951617804.csv'
# Data for row 7624 with id '287792038244319143601973158811646444280' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=00/minute=54/second=27/format=csv/287792038244319143601973158811646444280.csv'
# Data for row 7791 with id '314831425597918648920925741147238529305' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=12/minute=14/second=57/format=csv/314831425597918648920925741147238529305.csv'
# Data for row 7958 with id '320423965888285317131799078644549354923' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=22/minute=54/second=39/format=csv/320423965888285317131799078644549354923.csv'
# Data for row 7963 with id '168338813391062989529171383805884132038' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=19/minute=34/second=38/format=csv/168338813391062989529171383805884132038.csv'
# Data for row 8153 with id '266893622095073620806237724310477398900' uploaded to S3 bucket 'test-financial-news-bucket' under folder 'news/crypto/year=2026/month=01/day=28/hour=12/minute=32/second=59/format=csv/266893622095073620806237724310477398900.csv'
# Task finished: all files were succesfully uploaded to S3 bucket test-financial-news-bucket

# %%
post_full_csv = False
if (post_full_csv == True) and not filtered_df.empty:
    now = datetime.now()
    filename = f"{now.year}-{now.month:02}-{now.day:02}_full_record"
    etl_export.set_dataframe(etl.df)
    etl_export.export_text_to_s3_full_file(bucket_name, prefix_path, filename)

# %%
ingest_data = False
get_full_file = True
get_by_datetime = False
df_from_file = None

if ingest_data == True:
    etl_ingestion = etl.Ingestion(etl.df)
    bucket_name = "test-financial-news-bucket"
    prefix_path = "news/crypto/"
    year = '2024'
    month = '08'
    day = '01'
    hour = ''
    minute = ''
    if get_full_file == True:
        filename = f"{year}-{month}-{day}_full_record.csv"
        full_path = f"{prefix_path}{filename}"
        df_from_file = etl_ingestion.get_full_data_csv_file(bucket_name, full_path)
    elif get_by_datetime == True:
        df_from_file = etl_ingestion.get_data_csv_file_by_datetime(bucket_name, prefix_path, year, month, day, hour, minute)

# %%
if df_from_file is not None:
    print(df_from_file.count())

# %%
# Assuming df is your DataFrame
targetId = ''
if len(targetId) > 0:
    filtered_content = filtered_df.loc[filtered_df['id'] == targetId, 'content']

    # If you want to display the full content, convert it to a list or display all rows
    full_content = filtered_content.tolist()

    print(full_content)
