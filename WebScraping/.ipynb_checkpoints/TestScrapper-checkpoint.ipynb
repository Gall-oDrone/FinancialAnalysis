# %%
import WebScraper as ws

# %%
contents = []
topics = ['crypto']
Header = ["id", "source", "company", "category", "header", "summary", "content", "published_date", "href"]
n = len(Header)
freq = 'daily'
# Create a DataFrame using Pandas
#df = pd.DataFrame(columns=Header)


def scrap_data():
    NEWS = False
    STOCKS = True
    SHOW_BROWSER_UI = False
    if NEWS == True:
        topics = ['crypto']
        test_querying_full_news_content = False
        try:
            html_element = '/html/body/div[1]/div/div/div[1]/div/div[3]/div[1]/div/div[1]/div/div[1]/h1'
            news_scraper = ws.NewsScrapper(SHOW_BROWSER_UI, topics)
            if test_querying_full_news_content == True:
                print("Corso 0")
                news_scraper.test_fullNewContent()
            else:
                news_scraper.selenium_scrapper(html_element)
        except Exception as e:
            print('error during scrap_data()=> ', e)
    elif STOCKS == True:
        topics = ['crypto']
        try:
            html_element = '/html/body/div[1]/div/div/div[1]/div/div[3]/div[1]/div/div[1]/div/div[1]/h1'
            stock_scraper = ws.StocksScrapper(SHOW_BROWSER_UI, topics)
            stock_scraper.startScrapping()
        except Exception as e:
            print('error during scrap_data()=> ', e)
        
def run():
    try:
        scrap_data()
    except Exception as e:
        print('error during run process => ', e)

# %%
run()
# Out:
# Connection to the database successful!
# Table name set to: financial_news
# Table 'financial_news' already exists.
# Topic: crypto
# -------------------------------------------------------------------------
# loading target url https://finance.yahoo.com/topic/crypto/ ...successed
# -------------------------------------------------------------------------
# driver.current_url != target_url:  False
# In selectUnorderList method
# html element: /html/body/div[1]/div/div/div[1]/div/div[3]/div[1]/div/div[3]/div/div/div/ul
# -------------------------------------------------------------------------
# on selectLiNewsElements method
# -------------------------------------------------------------------------
# Element XPath: None
# Element Class: js-stream-content Pos(r)
# li div_childs loop h:  0
# Element XPath: None
# Element Class: Py(14px) Pos(r)
# div_chlds2 loop i:  0
# Element XPath: None
# Element Class: Cf
# div_chlds3 loop, k=  0
# div_chlds3 loop, k=  1
# Element XPath: None
# Element Class: Ov(h) Pend(44px) Pstart(25px)
# div_chlds4 loop, l=  0
# Element XPath: None
# Element Class: Fz(12px) Fw(b) Tt(c) D(ib) Mb(6px) C($c-fuji-blue-1-a) Mend(9px) Mt(-2px)
# div_chlds4 loop, l=  1
# Test:  Reuters•42 minutes ago
# news_source:  Reuters , calculated_datetime:  2024-05-20 18:52:56.181688 , calculated_timestamp 1716252776
# div_chlds4 loop, l=  2
# Href: https://finance.yahoo.com/news/dollar-steady-ether-fuels-crypto-005256084.html
# div_chlds4 loop, l=  3
# DataFrame is not initialized. Creating a DataFrame.
# -------------------------------------------------------------------------
# on selectLiNewsElements method
# -------------------------------------------------------------------------
# Element XPath: None
# Element Class: js-stream-content Pos(r)
# li div_childs loop h:  0
# Element XPath: None
# Element Class: Py(14px) Pos(r)
# div_chlds2 loop i:  0
# Element XPath: None
# Element Class: Cf
# div_chlds3 loop, k=  0
# div_chlds3 loop, k=  1
# Element XPath: None
# Element Class: Ov(h) Pend(44px) Pstart(25px)
# div_chlds4 loop, l=  0
# Element XPath: None
# Element Class: Fz(12px) Fw(b) Tt(c) D(ib) Mb(6px) C($c-fuji-blue-1-a) Mend(9px) Mt(-2px)
# div_chlds4 loop, l=  1
# Test:  Motley Fool•3 hours ago
# news_source:  Motley Fool , calculated_datetime:  2024-05-20 16:34:56.541249 , calculated_timestamp 1716244496
# div_chlds4 loop, l=  2
# Href: https://finance.yahoo.com/news/block-stock-once-generation-buying-223600112.html
# div_chlds4 loop, l=  3
# -------------------------------------------------------------------------
# on selectLiNewsElements method
# -------------------------------------------------------------------------
# Element XPath: None
# Element Class: js-stream-content Pos(r)
# li div_childs loop h:  0
# Element XPath: None
# Element Class: Py(14px) Pos(r)
# div_chlds2 loop i:  0
# Element XPath: None
# Element Class: Cf
# div_chlds3 loop, k=  0
# div_chlds3 loop, k=  1
# Element XPath: None
# Element Class: Ov(h) Pend(44px) Pstart(25px)
# div_chlds4 loop, l=  0
# Element XPath: None
# Element Class: Fz(12px) Fw(b) Tt(c) D(ib) Mb(6px) C($c-fuji-blue-1-a) Mend(9px) Mt(-2px)
# div_chlds4 loop, l=  1
# Test:  Fortune•5 hours ago
# news_source:  Fortune , calculated_datetime:  2024-05-20 14:34:56.876633 , calculated_timestamp 1716237296
# div_chlds4 loop, l=  2
# Href: https://finance.yahoo.com/news/absurd-morgan-stanley-state-wisconsin-203438217.html
# div_chlds4 loop, l=  3
# -------------------------------------------------------------------------
# on selectLiNewsElements method
# -------------------------------------------------------------------------
# Element XPath: None
# Element Class: js-stream-content Pos(r)
# li div_childs loop h:  0
# Element XPath: None
# Element Class: Py(14px) Pos(r)
# div_chlds2 loop i:  0
# Element XPath: None
# Element Class: Cf
# div_chlds3 loop, k=  0
# div_chlds3 loop, k=  1
# Element XPath: None
# Element Class: Ov(h) Pend(44px) Pstart(25px)
# div_chlds4 loop, l=  0
# Element XPath: None
# Element Class: Fz(12px) Fw(b) Tt(c) D(ib) Mb(6px) C($c-fuji-blue-1-a) Mend(9px) Mt(-2px)
# div_chlds4 loop, l=  1
# Test:  CoinDesk•8 hours ago
# news_source:  CoinDesk , calculated_datetime:  2024-05-20 11:34:57.226213 , calculated_timestamp 1716226497
# div_chlds4 loop, l=  2
# Href: https://finance.yahoo.com/news/bitcoin-breaks-above-68k-solanas-174207975.html
# div_chlds4 loop, l=  3
# -------------------------------------------------------------------------
# on selectLiNewsElements method
# -------------------------------------------------------------------------
# Element XPath: None
# Element Class: js-stream-content Pos(r)
# li div_childs loop h:  0
# Element XPath: None
# Element Class: Py(14px) Pos(r)
# div_chlds2 loop i:  0
# Element XPath: None
# Element Class: Cf
# div_chlds3 loop, k=  0
# div_chlds3 loop, k=  1
# Element XPath: None
# Element Class: Pos(a) T(14px) End(0) W(36px) Ta(c) NoJs_D(n) Mt(20px)
# div_chlds4 loop, l=  0
# Element XPath: None
# Element Class: share-menu-wrapper D(ib) Pos(r)
# -------------------------------------------------------------------------
# on selectLiNewsElements method
# -------------------------------------------------------------------------
# Element XPath: None
# Element Class: js-stream-content Pos(r)
# li div_childs loop h:  0
# Element XPath: None
# Element Class: Py(14px) Pos(r)
# div_chlds2 loop i:  0
# Element XPath: None
# Element Class: Cf
# div_chlds3 loop, k=  0
# div_chlds3 loop, k=  1
# Element XPath: None
# Element Class: Ov(h) Pend(44px) Pstart(25px)
# div_chlds4 loop, l=  0
# Element XPath: None
# Element Class: Fz(12px) Fw(b) Tt(c) D(ib) Mb(6px) C($c-fuji-blue-1-a) Mend(9px) Mt(-2px)
# div_chlds4 loop, l=  1
# Test:  Bloomberg•11 hours ago
# news_source:  Bloomberg , calculated_datetime:  2024-05-20 08:34:57.815222 , calculated_timestamp 1716215697
# div_chlds4 loop, l=  2
# Href: https://finance.yahoo.com/news/crypto-firm-grayscale-turns-goldman-145811747.html
# div_chlds4 loop, l=  3
# -------------------------------------------------------------------------
# on selectLiNewsElements method
# -------------------------------------------------------------------------
# Element XPath: None
# Element Class: js-stream-content Pos(r)
# li div_childs loop h:  0
# Element XPath: None
# Element Class: Py(14px) Pos(r)
# div_chlds2 loop i:  0
# Element XPath: None
# Element Class: Cf
# div_chlds3 loop, k=  0
# div_chlds3 loop, k=  1
# Element XPath: None
# Element Class: Ov(h) Pend(44px) Pstart(25px)
# div_chlds4 loop, l=  0
# Element XPath: None
# Element Class: Fz(12px) Fw(b) Tt(c) D(ib) Mb(6px) C($c-fuji-blue-1-a) Mend(9px) Mt(-2px)
# div_chlds4 loop, l=  1
# Test:  Reuters•11 hours ago
# news_source:  Reuters , calculated_datetime:  2024-05-20 08:34:58.172036 , calculated_timestamp 1716215698
# div_chlds4 loop, l=  2
# Href: https://finance.yahoo.com/news/self-proclaimed-bitcoin-inventor-lied-142254293.html
# div_chlds4 loop, l=  3
# -------------------------------------------------------------------------
# on selectLiNewsElements method
# -------------------------------------------------------------------------
# Element XPath: None
# Element Class: js-stream-content Pos(r)
# li div_childs loop h:  0
# Element XPath: None
# Element Class: Py(14px) Pos(r)
# div_chlds2 loop i:  0
# Element XPath: None
# Element Class: Cf
# div_chlds3 loop, k=  0
# div_chlds3 loop, k=  1
# Element XPath: None
# Element Class: Ov(h) Pend(44px) Pstart(25px)
# div_chlds4 loop, l=  0
# Element XPath: None
# Element Class: Fz(12px) Fw(b) Tt(c) D(ib) Mb(6px) C($c-fuji-blue-1-a) Mend(9px) Mt(-2px)
# div_chlds4 loop, l=  1
# Test:  Reuters•11 hours ago
# news_source:  Reuters , calculated_datetime:  2024-05-20 08:34:58.604135 , calculated_timestamp 1716215698
# div_chlds4 loop, l=  2
# Href: https://finance.yahoo.com/news/brazil-central-bank-plans-end-140842279.html
# div_chlds4 loop, l=  3
# -------------------------------------------------------------------------
# on selectLiNewsElements method
# -------------------------------------------------------------------------
# Element XPath: None
# Element Class: js-stream-content Pos(r)
# li div_childs loop h:  0
# Element XPath: None
# Element Class: Py(14px) Pos(r)
# div_chlds2 loop i:  0
# Element XPath: None
# Element Class: Cf
# div_chlds3 loop, k=  0
# div_chlds3 loop, k=  1
# Element XPath: None
# Element Class: Ov(h) Pend(44px) Pstart(25px)
# div_chlds4 loop, l=  0
# Element XPath: None
# Element Class: Fz(12px) Fw(b) Tt(c) D(ib) Mb(6px) C($c-fuji-blue-1-a) Mend(9px) Mt(-2px)
# div_chlds4 loop, l=  1
# Test:  CoinDesk•12 hours ago
# news_source:  CoinDesk , calculated_datetime:  2024-05-20 07:34:58.935328 , calculated_timestamp 1716212098
# div_chlds4 loop, l=  2
# Href: https://finance.yahoo.com/news/hamster-wheel-telegram-social-gaming-134857411.html
# div_chlds4 loop, l=  3
# -------------------------------------------------------------------------
# on selectLiNewsElements method
# -------------------------------------------------------------------------
# Element XPath: None
# Element Class: js-stream-content Pos(r)
# li div_childs loop h:  0
# Element XPath: None
# Element Class: Py(14px) Pos(r)
# div_chlds2 loop i:  0
# Element XPath: None
# Element Class: Cf
# div_chlds3 loop, k=  0
# div_chlds3 loop, k=  1
# Element XPath: None
# Element Class: Ov(h) Pend(44px) Pstart(25px)
# div_chlds4 loop, l=  0
# Element XPath: None
# Element Class: Fz(12px) Fw(b) Tt(c) D(ib) Mb(6px) C($c-fuji-blue-1-a) Mend(9px) Mt(-2px)
# div_chlds4 loop, l=  1
# Test:  Zacks•14 hours ago
# news_source:  Zacks , calculated_datetime:  2024-05-20 05:34:59.266626 , calculated_timestamp 1716204899
# div_chlds4 loop, l=  2
# Href: https://finance.yahoo.com/news/5-bitcoin-centric-stocks-buy-120300955.html
# div_chlds4 loop, l=  3
# -------------------------------------------------------------------------
# on printDataframe()
# -------------------------------------------------------------------------
# id                    184615634271720255200774755329567199867
# source                                                Reuters
# category                                             Business
# headline              Dollar steady; ether fuels crypto rally
# href        https://finance.yahoo.com/news/dollar-steady-e...
# summary     The dollar was firm on Tuesday while the yen s...
# content                                                  <NA>
# datetime                                                 <NA>
# Name: 0, dtype: object
# id                      2874203601661229524996469596724483258
# source                                            Motley Fool
# category                                             Business
# headline    Is Block Stock a Once-in-a-Generation Buying O...
# href        https://finance.yahoo.com/news/block-stock-onc...
# summary     The fintech company's CEO has his eyes on a bo...
# content                                                  <NA>
# datetime                                                 <NA>
# Name: 1, dtype: object
# id                    239386256173420839373892122226225991387
# source                                                Fortune
# category                                             Business
# headline    ‘It’s absurd’: From Morgan Stanley to the stat...
# href        https://finance.yahoo.com/news/absurd-morgan-s...
# summary     More than 900 firms at least $100 million in s...
# content                                                  <NA>
# datetime                                                 <NA>
# Name: 2, dtype: object
# id                     81052551433183251071975593716901104418
# source                                               CoinDesk
# category                                             Business
# headline    Bitcoin Breaks Out Above $68K as Solana's 7% G...
# href        https://finance.yahoo.com/news/bitcoin-breaks-...
# summary     Inflows into the spot bitcoin ETFs restarted i...
# content                                                  <NA>
# datetime                                                 <NA>
# Name: 3, dtype: object
# id                     47348039563061586840425160817788854170
# source                                              Bloomberg
# category                                             Business
# headline    Crypto Firm Grayscale Turns to Wall Street Alu...
# href        https://finance.yahoo.com/news/crypto-firm-gra...
# summary     (Bloomberg) -- Michael Sonnenshein is stepping...
# content                                                  <NA>
# datetime                                                 <NA>
# Name: 4, dtype: object
# id                    161873488321950409007785330799736247202
# source                                                Reuters
# category                                                World
# headline    Self-proclaimed bitcoin inventor lied 'repeate...
# href        https://finance.yahoo.com/news/self-proclaimed...
# summary     An Australian computer scientist who claimed h...
# content                                                  <NA>
# datetime                                                 <NA>
# Name: 5, dtype: object
# id                    211384653694741982736783758417318980515
# source                                                Reuters
# category                                             Business
# headline    Brazil central bank plans year-end proposal fo...
# href        https://finance.yahoo.com/news/brazil-central-...
# summary     BRASILIA (Reuters) -Brazil's central bank anno...
# content                                                  <NA>
# datetime                                                 <NA>
# Name: 6, dtype: object
# id                    270613164189555155582557227016435319628
# source                                               CoinDesk
# category                                             Business
# headline    Hamster Wheel: Telegram’s Social Gaming Brings...
# href        https://finance.yahoo.com/news/hamster-wheel-t...
# summary     Telegram’s Hamster Kombat game has amassed 8 m...
# content                                                  <NA>
# datetime                                                 <NA>
# Name: 7, dtype: object
# id                     51887558406931078881794532957461869050
# source                                                  Zacks
# category                                             Business
# headline    5 Bitcoin-Centric Stocks to Buy to Gain From t...
# href        https://finance.yahoo.com/news/5-bitcoin-centr...
# summary     We have narrowed our search to five bitcoin-or...
# content                                                  <NA>
# datetime                                                 <NA>
# Name: 8, dtype: object
# -------------------------------------------------------------------------
# on retrieveFullNewsArticle()
# -------------------------------------------------------------------------
# -------------------------------------------------------------------------
# loading target url https://finance.yahoo.com/news/dollar-steady-ether-fuels-crypto-005256084.html ...successed
# -------------------------------------------------------------------------
# Element XPath: None
# Element Class: caas-body-content
# -------------------------------------------------------------------------
# on selectFullNewsElements() method
# -------------------------------------------------------------------------
# full_div_parent loop
# Element XPath: None
# Element Class: caas-content-wrapper neo-grid-container
# full_div_chlds2 loop, i= 0
# Element XPath: None
# Element Class: col-neofull-offset-3-span-8 col-neolg-offset-3-span-8 col-neomd-offset-1-span-6 col-neosm-offset-2-span-4
# full_div_chlds3 loop, j= 0
# full_div_chlds3 loop, j= 1
# full_div_chlds3 loop, j= 2
# Element XPath: None
# Element Class: caas-content-byline-wrapper
# full_div_chlds4 loop, l= 0
# Element XPath: None
# Element Class: caas-attr
# full_div_chlds5 loop, m= 0
# Element XPath: None
# Element Class: caas-attr-meta
# Element XPath: None
# Element Class: caas-attr-time-style
# full news_datetime:  2024-05-21T00:52:56.000Z
# full_div_chlds4 loop, l= 1
# full_div_chlds2 loop, i= 1
# div_child_2 loop, i= 1
# Element XPath: None
# Element Class: morpheusGridBody col-neofull-offset-3-span-8 col-neolg-offset-3-span-8 col-neomd-offset-1-span-6 col-neosm-offset-2-span-4
# -------------------------------------------------------------------------
# loading target url https://finance.yahoo.com/news/block-stock-once-generation-buying-223600112.html ...successed
# -------------------------------------------------------------------------
# Element XPath: None
# Element Class: caas-body-content
# -------------------------------------------------------------------------
# on selectFullNewsElements() method
# -------------------------------------------------------------------------
# full_div_parent loop
# Element XPath: None
# Element Class: caas-content-wrapper neo-grid-container
# full_div_chlds2 loop, i= 0
# Element XPath: None
# Element Class: col-neofull-offset-3-span-8 col-neolg-offset-3-span-8 col-neomd-offset-1-span-6 col-neosm-offset-2-span-4
# full_div_chlds3 loop, j= 0
# full_div_chlds3 loop, j= 1
# full_div_chlds3 loop, j= 2
# Element XPath: None
# Element Class: caas-content-byline-wrapper
# full_div_chlds4 loop, l= 0
# Element XPath: None
# Element Class: caas-attr
# full_div_chlds5 loop, m= 0
# Element XPath: None
# Element Class: caas-attr-meta
# Element XPath: None
# Element Class: caas-attr-time-style
# full news_datetime:  2024-05-20T22:36:00.000Z
# full_div_chlds4 loop, l= 1
# full_div_chlds2 loop, i= 1
# div_child_2 loop, i= 1
# Element XPath: None
# Element Class: morpheusGridBody col-neofull-offset-3-span-8 col-neolg-offset-3-span-8 col-neomd-offset-1-span-6 col-neosm-offset-2-span-4
# -------------------------------------------------------------------------
# loading target url https://finance.yahoo.com/news/absurd-morgan-stanley-state-wisconsin-203438217.html ...successed
# -------------------------------------------------------------------------
# Element XPath: None
# Element Class: caas-body-content
# -------------------------------------------------------------------------
# on selectFullNewsElements() method
# -------------------------------------------------------------------------
# full_div_parent loop
# Element XPath: None
# Element Class: caas-content-wrapper neo-grid-container
# full_div_chlds2 loop, i= 0
# Element XPath: None
# Element Class: col-neofull-offset-3-span-8 col-neolg-offset-3-span-8 col-neomd-offset-1-span-6 col-neosm-offset-2-span-4
# full_div_chlds3 loop, j= 0
# full_div_chlds3 loop, j= 1
# full_div_chlds3 loop, j= 2
# Element XPath: None
# Element Class: caas-content-byline-wrapper
# full_div_chlds4 loop, l= 0
# Element XPath: None
# Element Class: caas-attr
# full_div_chlds5 loop, m= 0
# Element XPath: None
# Element Class: caas-attr-meta
# Element XPath: None
# Element Class: caas-attr-time-style
# full news_datetime:  2024-05-20T20:34:38.000Z
# full_div_chlds4 loop, l= 1
# full_div_chlds2 loop, i= 1
# div_child_2 loop, i= 1
# Element XPath: None
# Element Class: morpheusGridBody col-neofull-offset-3-span-8 col-neolg-offset-3-span-8 col-neomd-offset-1-span-6 col-neosm-offset-2-span-4
# -------------------------------------------------------------------------
# loading target url https://finance.yahoo.com/news/bitcoin-breaks-above-68k-solanas-174207975.html ...successed
# -------------------------------------------------------------------------
# Element XPath: None
# Element Class: caas-body-content
# No buttons with class 'caas-readmore' found
# -------------------------------------------------------------------------
# on selectFullNewsElements() method
# -------------------------------------------------------------------------
# full_div_parent loop
# Element XPath: None
# Element Class: caas-content-wrapper neo-grid-container
# full_div_chlds2 loop, i= 0
# Element XPath: None
# Element Class: col-neofull-offset-3-span-8 col-neolg-offset-3-span-8 col-neomd-offset-1-span-6 col-neosm-offset-2-span-4
# full_div_chlds3 loop, j= 0
# full_div_chlds3 loop, j= 1
# full_div_chlds3 loop, j= 2
# Element XPath: None
# Element Class: caas-content-byline-wrapper
# full_div_chlds4 loop, l= 0
# Element XPath: None
# Element Class: caas-attr
# full_div_chlds5 loop, m= 0
# Element XPath: None
# Element Class: caas-attr-meta
# Element XPath: None
# Element Class: caas-attr-time-style
# full news_datetime:  2024-05-20T17:42:07.000Z
# full_div_chlds4 loop, l= 1
# full_div_chlds2 loop, i= 1
# div_child_2 loop, i= 1
# Element XPath: None
# Element Class: morpheusGridBody col-neofull-offset-3-span-8 col-neolg-offset-3-span-8 col-neomd-offset-1-span-6 col-neosm-offset-2-span-4
# -------------------------------------------------------------------------
# loading target url https://finance.yahoo.com/news/crypto-firm-grayscale-turns-goldman-145811747.html ...successed
# -------------------------------------------------------------------------
# Element XPath: None
# Element Class: caas-body-content
# -------------------------------------------------------------------------
# on selectFullNewsElements() method
# -------------------------------------------------------------------------
# full_div_parent loop
# Element XPath: None
# Element Class: caas-content-wrapper neo-grid-container
# full_div_chlds2 loop, i= 0
# Element XPath: None
# Element Class: col-neofull-offset-3-span-8 col-neolg-offset-3-span-8 col-neomd-offset-1-span-6 col-neosm-offset-2-span-4
# full_div_chlds3 loop, j= 0
# full_div_chlds3 loop, j= 1
# full_div_chlds3 loop, j= 2
# Element XPath: None
# Element Class: caas-content-byline-wrapper
# full_div_chlds4 loop, l= 0
# Element XPath: None
# Element Class: caas-attr
# full_div_chlds5 loop, m= 0
# Element XPath: None
# Element Class: caas-attr-meta
# Element XPath: None
# Element Class: caas-attr-time-style
# full news_datetime:  2024-05-20T14:58:11.000Z
# full_div_chlds4 loop, l= 1
# full_div_chlds2 loop, i= 1
# div_child_2 loop, i= 1
# Element XPath: None
# Element Class: morpheusGridBody col-neofull-offset-3-span-8 col-neolg-offset-3-span-8 col-neomd-offset-1-span-6 col-neosm-offset-2-span-4
# -------------------------------------------------------------------------
# loading target url https://finance.yahoo.com/news/self-proclaimed-bitcoin-inventor-lied-142254293.html ...successed
# -------------------------------------------------------------------------
# Element XPath: None
# Element Class: caas-body-content
# No buttons with class 'caas-readmore' found
# -------------------------------------------------------------------------
# on selectFullNewsElements() method
# -------------------------------------------------------------------------
# full_div_parent loop
# Element XPath: None
# Element Class: caas-content-wrapper neo-grid-container
# full_div_chlds2 loop, i= 0
# Element XPath: None
# Element Class: col-neofull-offset-3-span-8 col-neolg-offset-3-span-8 col-neomd-offset-1-span-6 col-neosm-offset-2-span-4
# full_div_chlds3 loop, j= 0
# full_div_chlds3 loop, j= 1
# full_div_chlds3 loop, j= 2
# Element XPath: None
# Element Class: caas-content-byline-wrapper
# full_div_chlds4 loop, l= 0
# Element XPath: None
# Element Class: caas-attr
# full_div_chlds5 loop, m= 0
# Element XPath: None
# Element Class: caas-attr-meta
# Element XPath: None
# Element Class: caas-attr-time-style
# full news_datetime:  2024-05-20T14:22:54.000Z
# full_div_chlds4 loop, l= 1
# full_div_chlds2 loop, i= 1
# div_child_2 loop, i= 1
# Element XPath: None
# Element Class: morpheusGridBody col-neofull-offset-3-span-8 col-neolg-offset-3-span-8 col-neomd-offset-1-span-6 col-neosm-offset-2-span-4
# -------------------------------------------------------------------------
# loading target url https://finance.yahoo.com/news/brazil-central-bank-plans-end-140842279.html ...successed
# -------------------------------------------------------------------------
# Element XPath: None
# Element Class: caas-body-content
# No buttons with class 'caas-readmore' found
# -------------------------------------------------------------------------
# on selectFullNewsElements() method
# -------------------------------------------------------------------------
# full_div_parent loop
# Element XPath: None
# Element Class: caas-content-wrapper neo-grid-container
# full_div_chlds2 loop, i= 0
# Element XPath: None
# Element Class: col-neofull-offset-3-span-8 col-neolg-offset-3-span-8 col-neomd-offset-1-span-6 col-neosm-offset-2-span-4
# full_div_chlds3 loop, j= 0
# full_div_chlds3 loop, j= 1
# full_div_chlds3 loop, j= 2
# Element XPath: None
# Element Class: caas-content-byline-wrapper
# full_div_chlds4 loop, l= 0
# Element XPath: None
# Element Class: caas-attr
# full_div_chlds5 loop, m= 0
# Element XPath: None
# Element Class: caas-attr-meta
# Element XPath: None
# Element Class: caas-attr-time-style
# full news_datetime:  2024-05-20T22:43:32.000Z
# full_div_chlds4 loop, l= 1
# full_div_chlds2 loop, i= 1
# div_child_2 loop, i= 1
# Element XPath: None
# Element Class: morpheusGridBody col-neofull-offset-3-span-8 col-neolg-offset-3-span-8 col-neomd-offset-1-span-6 col-neosm-offset-2-span-4
# -------------------------------------------------------------------------
# loading target url https://finance.yahoo.com/news/hamster-wheel-telegram-social-gaming-134857411.html ...successed
# -------------------------------------------------------------------------
# Element XPath: None
# Element Class: caas-body-content
# -------------------------------------------------------------------------
# on selectFullNewsElements() method
# -------------------------------------------------------------------------
# full_div_parent loop
# Element XPath: None
# Element Class: caas-content-wrapper neo-grid-container
# full_div_chlds2 loop, i= 0
# Element XPath: None
# Element Class: col-neofull-offset-3-span-8 col-neolg-offset-3-span-8 col-neomd-offset-1-span-6 col-neosm-offset-2-span-4
# full_div_chlds3 loop, j= 0
# full_div_chlds3 loop, j= 1
# full_div_chlds3 loop, j= 2
# Element XPath: None
# Element Class: caas-content-byline-wrapper
# full_div_chlds4 loop, l= 0
# Element XPath: None
# Element Class: caas-attr
# full_div_chlds5 loop, m= 0
# Element XPath: None
# Element Class: caas-attr-meta
# Element XPath: None
# Element Class: caas-attr-time-style
# full news_datetime:  2024-05-20T14:59:47.000Z
# full_div_chlds4 loop, l= 1
# full_div_chlds2 loop, i= 1
# div_child_2 loop, i= 1
# Element XPath: None
# Element Class: morpheusGridBody col-neofull-offset-3-span-8 col-neolg-offset-3-span-8 col-neomd-offset-1-span-6 col-neosm-offset-2-span-4
# -------------------------------------------------------------------------
# loading target url https://finance.yahoo.com/news/5-bitcoin-centric-stocks-buy-120300955.html ...successed
# -------------------------------------------------------------------------
# Element XPath: None
# Element Class: caas-body-content
# -------------------------------------------------------------------------
# on selectFullNewsElements() method
# -------------------------------------------------------------------------
# full_div_parent loop
# Element XPath: None
# Element Class: caas-content-wrapper neo-grid-container
# full_div_chlds2 loop, i= 0
# Element XPath: None
# Element Class: col-neofull-offset-3-span-8 col-neolg-offset-3-span-8 col-neomd-offset-1-span-6 col-neosm-offset-2-span-4
# full_div_chlds3 loop, j= 0
# full_div_chlds3 loop, j= 1
# full_div_chlds3 loop, j= 2
# Element XPath: None
# Element Class: caas-content-byline-wrapper
# full_div_chlds4 loop, l= 0
# Element XPath: None
# Element Class: caas-attr
# full_div_chlds5 loop, m= 0
# Element XPath: None
# Element Class: caas-attr-meta
# Element XPath: None
# Element Class: caas-attr-time-style
# full news_datetime:  2024-05-20T12:03:00.000Z
# full_div_chlds4 loop, l= 1
# full_div_chlds2 loop, i= 1
# div_child_2 loop, i= 1
# Element XPath: None
# Element Class: morpheusGridBody col-neofull-offset-3-span-8 col-neolg-offset-3-span-8 col-neomd-offset-1-span-6 col-neosm-offset-2-span-4
# -------------------------------------------------------------------------
# storing to Database
# -------------------------------------------------------------------------
# Connection is already open.
# Saving to postgres db...done
# Saving to postgres db...done
# Saving to postgres db...done
# Saving to postgres db...done
# Saving to postgres db...done
# Saving to postgres db...done
# Saving to postgres db...done
# Saving to postgres db...done
# Saving to postgres db...done
# scraping data task finished
# ====================================================================
# **All book data was scraped**
# Connection closed.
