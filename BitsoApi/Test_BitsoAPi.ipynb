# %%
# Ensure the file is in the correct directory or provide the full path
# %run ws_trades.py
# Out:
# Connected
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# ask
# bid
#
# closing connection
