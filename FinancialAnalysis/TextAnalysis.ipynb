# %%
import sys
sys.path.append('../Storage')

import pgConn
import PostgresSQL_table_queries
import remoteStorage

import pandas as pd
from datetime import datetime
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
pg_conn = pgConn.PgConn("financial_news")
df = pg_conn.get_financial_news()
# Out:
# Connection to the database successful!
# Table name set to: financial_news

# %%
class TextAnalysis:
    def __init__(self, dataframe):
        self.dataframe = dataframe
        self.vectorizer = None
        self.tfidf_matrix = None
        
    def term_freq(self):
        # Calculate term frequency
        if self.dataframe is not None:
            self.vectorizer = TfidfVectorizer(use_idf=False)
            self.tfidf_matrix = self.vectorizer.fit_transform(self.dataframe['content'].values.astype('U'))
            return self.tfidf_matrix
        else:
            return None
        
    def doc_freq(self):
        # Calculate document frequency
        if self.vectorizer is not None:
            doc_freq = self.tfidf_matrix.astype(bool).sum(axis=0)
            return doc_freq
        else:
            return None
        
    def tf_Idf(self):
        # Calculate TF-IDF
        if self.vectorizer is not None:
            tfidf_transformer = TfidfVectorizer(use_idf=True)
            self.tfidf_matrix = tfidf_transformer.fit_transform(self.dataframe['content'].values.astype('U'))
            return self.tfidf_matrix
        else:
            return None
    
    def print_term_freq(self):
        # Print term frequency
        if self.vectorizer is not None:
            terms = self.vectorizer.get_feature_names_out()
            for term in terms:
                print(f"Term: {term}")
        else:
            print("No term frequency calculated.")
    
    def print_doc_freq(self):
        # Print document frequency
        if self.vectorizer is not None:
            doc_freq = self.doc_freq()
            terms = self.vectorizer.get_feature_names_out()
            for i, term in enumerate(terms):
                print(f"Term: {term}, Document Frequency: {doc_freq[0, i]}")
        else:
            print("No document frequency calculated.")
    
    def print_tf_Idf(self):
        # Print TF-IDF
        if self.vectorizer is not None:
            terms = self.vectorizer.get_feature_names_out()
            for i, term in enumerate(terms):
                print(f"Term: {term}, TF-IDF: {self.tfidf_matrix[0, i]}")
        else:
            print("No TF-IDF calculated.")

# %%
analysis = TextAnalysis(df)
term_freq_matrix = analysis.term_freq()
doc_freq_vector = analysis.doc_freq()
tfidf_matrix = analysis.tf_Idf()

# %%
# Print the results
analysis.print_term_freq()
# Out:
# Term: 00
# Term: 000
# Term: 000th
# Term: 000x
# Term: 01
# Term: 02
# Term: 03
# Term: 06
# Term: 07
# Term: 070
# Term: 075
# Term: 08
# Term: 10
# Term: 100
# Term: 100x
# Term: 103
# Term: 104
# Term: 105
# Term: 107
# Term: 10x
# Term: 11
# Term: 110
# Term: 115
# Term: 12
# Term: 122
# Term: 125
# Term: 13
# Term: 13bn
# Term: 14
# Term: 141
# Term: 147
# Term: 15
# Term: 150
# Term: 16
# Term: 160
# Term: 164
# Term: 17
# Term: 170
# Term: 176
# Term: 18
# Term: 182
# Term: 19
# Term: 190
# Term: 1930
# Term: 1946
# Term: 195
# Term: 196
# Term: 1990
# Term: 1m
# Term: 20
# Term: 200
# Term: 2000
# Term: 2002
# Term: 2005
# Term: 2008
# Term: 2009
# Term: 2011
# Term: 2013
# Term: 2014
# Term: 2018
# Term: 2019
# Term: 2020
# Term: 2021
# Term: 2022
# Term: 2023
# Term: 2024
# Term: 2025
# Term: 2028
# Term: 2030
# Term: 21
# Term: 210
# Term: 214
# Term: 2140
# Term: 217
# Term: 21shares
# Term: 22
# Term: 23
# Term: 237
# Term: 23m
# Term: 24
# Term: 244
# Term: 25
# Term: 250
# Term: 26
# Term: 27
# Term: 28
# Term: 280
# Term: 29
# Term: 291
# Term: 30
# Term: 300
# Term: 305
# Term: 31
# Term: 33
# Term: 332
# Term: 34
# Term: 345
# Term: 350
# Term: 355
# Term: 36
# Term: 366m
# Term: 36bn
# Term: 37
# Term: 370
# Term: 379
# Term: 38
# Term: 380m
# Term: 38m
# Term: 39
# Term: 390
# Term: 399
# Term: 3m
# Term: 40
# Term: 400
# Term: 401
# Term: 41
# Term: 422
# Term: 428
# Term: 44
# Term: 45
# Term: 450
# Term: 450m
# Term: 46
# Term: 461
# Term: 480
# Term: 49
# Term: 50
# Term: 500
# Term: 505
# Term: 506
# Term: 518
# Term: 53
# Term: 537
# Term: 55
# Term: 553
# Term: 557
# Term: 559
# Term: 56
# Term: 567
# Term: 575
# Term: 580
# Term: 588
# Term: 59
# Term: 5g
# Term: 60
# Term: 600
# Term: 600bn
# Term: 61
# Term: 62
# Term: 63
# Term: 64
# Term: 644
# Term: 64k
# Term: 65
# Term: 66
# Term: 68
# Term: 685
# Term: 69
# Term: 692
# Term: 6bn
# Term: 6th
# Term: 70
# Term: 700
# Term: 701
# Term: 71
# Term: 72
# Term: 73
# Term: 74
# Term: 75
# Term: 750
# Term: 76
# Term: 765
# Term: 78
# Term: 79
# Term: 790
# Term: 7936
# Term: 80
# Term: 800
# Term: 82
# Term: 84
# Term: 85
# Term: 850
# Term: 875
# Term: 89
# Term: 90
# Term: 900
# Term: 923
# Term: 93
# Term: 94
# Term: 95
# Term: 97
# Term: 982
# Term: 983
# Term: 99
# Term: 990
# Term: 992
# Term: aapl
# Term: abandoned
# Term: ability
# Term: able
# Term: about
# Term: above
# Term: academics
# Term: accelerating
# Term: accept
# Term: acceptable
# Term: acceptance
# Term: accepted
# Term: access
# Term: accessibility
# Term: accomplish
# Term: according
# Term: account
# Term: accountably
# Term: accounted
# Term: accounting
# Term: accounts
# Term: accumulate
# Term: accumulating
# Term: accuracy
# Term: acgl
# Term: acheson
# Term: acpr
# Term: acquire
# Term: acquired
# Term: acquisition
# Term: across
# Term: act
# Term: acted
# Term: action
# Term: actions
# Term: active
# Term: actively
# Term: activities
# Term: activity
# Term: actual
# Term: actually
# Term: add
# Term: added
# Term: adding
# Term: addition
# Term: additional
# Term: additionally
# Term: address
# Term: addresses
# Term: adds
# Term: adjunct
# Term: administration
# Term: adopt
# Term: adopted
# Term: adopting
# Term: adoption
# Term: adult
# Term: advance
# Term: advanced
# Term: advancing
# Term: advantages
# Term: advertised
# Term: advice
# Term: advisor
# Term: advocate
# Term: affairs
# Term: affect
# Term: affected
# Term: affiliated
# Term: afloat
# Term: africa
# Term: after
# Term: afternoon
# Term: again
# Term: against
# Term: age
# Term: agency
# Term: agent
# Term: agents
# Term: aggregates
# Term: ago
# Term: ahead
# Term: ai
# Term: aid
# Term: aided
# Term: aim
# Term: aimed
# Term: aiming
# Term: algorithm
# Term: aligns
# Term: all
# Term: allegations
# Term: allegedly
# Term: alleges
# Term: allocating
# Term: allocation
# Term: allocations
# Term: allow
# Term: allowed
# Term: allowing
# Term: allows
# Term: ally
# Term: almost
# Term: alone
# Term: along
# Term: alps
# Term: already
# Term: also
# Term: altcoins
# Term: alternative
# Term: alternatives
# Term: alters
# Term: although
# Term: altogether
# Term: alts
# Term: always
# Term: amass
# Term: amazon
# Term: amd
# Term: america
# Term: americas
# Term: amf
# Term: amicus
# Term: amid
# Term: among
# Term: amount
# Term: amounts
# Term: amzn
# Term: an
# Term: analysing
# Term: analysis
# Term: analyst
# Term: analysts
# Term: analytics
# Term: analyzing
# Term: anarchist
# Term: and
# Term: andvaneck
# Term: animal
# Term: announced
# Term: announcement
# Term: annualized
# Term: anonymity
# Term: anonymous
# Term: another
# Term: answer
# Term: anthony
# Term: anti
# Term: anticipated
# Term: anticipation
# Term: any
# Term: anyone
# Term: anything
# Term: anytime
# Term: app
# Term: apparent
# Term: appeal
# Term: appealing
# Term: appeals
# Term: appear
# Term: appeared
# Term: appears
# Term: appellate
# Term: appetite
# Term: apple
# Term: application
# Term: applications
# Term: applied
# Term: apply
# Term: applying
# Term: appointed
# Term: appointment
# Term: appreciate
# Term: appreciated
# Term: appreciation
# Term: apprehension
# Term: approach
# Term: approval
# Term: approvals
# Term: approved
# Term: approving
# Term: approximately
# Term: apr
# Term: april
# Term: apy
# Term: arca
# Term: arch
# Term: architecture
# Term: ardoino
# Term: are
# Term: aren
# Term: arguably
# Term: argued
# Term: argues
# Term: arguing
# Term: argument
# Term: arise
# Term: ark
# Term: arkb
# Term: arkham
# Term: arkw
# Term: arm
# Term: arms
# Term: around
# Term: arrests
# Term: arrival
# Term: arrive
# Term: arrived
# Term: article
# Term: artificial
# Term: as
# Term: asap
# Term: asia
# Term: asian
# Term: asic
# Term: asics
# Term: aside
# Term: asked
# Term: asking
# Term: aspect
# Term: assault
# Term: assert
# Term: assessment
# Term: assessments
# Term: asset
# Term: assets
# Term: assistance
# Term: associated
# Term: association
# Term: astounding
# Term: astronomically
# Term: asx
# Term: at
# Term: ath
# Term: aths
# Term: atop
# Term: attempting
# Term: attention
# Term: attract
# Term: attracted
# Term: attracting
# Term: attractive
# Term: attributes
# Term: attuned
# Term: auctioned
# Term: august
# Term: aum
# Term: auspicious
# Term: austin
# Term: australia
# Term: australian
# Term: author
# Term: authorities
# Term: authority
# Term: authorization
# Term: authorized
# Term: automated
# Term: automatically
# Term: availability
# Term: available
# Term: avenue
# Term: average
# Term: awaiting
# Term: awarded
# Term: aware
# Term: away
# Term: back
# Term: backed
# Term: backing
# Term: backlash
# Term: bad
# Term: bahamas
# Term: balance
# Term: balanced
# Term: balances
# Term: ballooned
# Term: bank
# Term: bankers
# Term: banking
# Term: bankman
# Term: bankrate
# Term: banks
# Term: barely
# Term: barriers
# Term: basak
# Term: base
# Term: based
# Term: basic
# Term: basics
# Term: basis
# Term: basulto
# Term: bat
# Term: batch
# Term: bats
# Term: battle
# Term: bcb
# Term: be
# Term: beach
# Term: bear
# Term: bearing
# Term: bearish
# Term: because
# Term: become
# Term: becomes
# Term: becoming
# Term: bedroom
# Term: been
# Term: before
# Term: began
# Term: beginning
# Term: begs
# Term: begun
# Term: behalf
# Term: behave
# Term: behemoth
# Term: behind
# Term: being
# Term: belief
# Term: believe
# Term: believer
# Term: believes
# Term: belong
# Term: below
# Term: benchmark
# Term: beneficial
# Term: beneficiaries
# Term: beneficiary
# Term: benefit
# Term: benefited
# Term: benefits
# Term: benzinga
# Term: berkrot
# Term: bernstein
# Term: best
# Term: beta
# Term: betashares
# Term: better
# Term: between
# Term: beyond
# Term: bezos
# Term: biden
# Term: big
# Term: bigger
# Term: biggest
# Term: bill
# Term: billion
# Term: billions
# Term: binance
# Term: bitb
# Term: bitcoin
# Term: bitcoins
# Term: bitcointreasuries
# Term: bito
# Term: bitwise
# Term: black
# Term: blackrock
# Term: blamed
# Term: blk
# Term: bloc
# Term: block
# Term: blockchain
# Term: blockchains
# Term: blocks
# Term: blog
# Term: bloomberg
# Term: blow
# Term: blueprint
# Term: board
# Term: boj
# Term: bonds
# Term: bonk
# Term: bonuses
# Term: book
# Term: boom
# Term: boost
# Term: born
# Term: boston
# Term: both
# Term: bottom
# Term: bought
# Term: bound
# Term: boutique
# Term: bradford
# Term: brain
# Term: brand
# Term: breach
# Term: breached
# Term: breaking
# Term: brexit
# Term: bridges
# Term: brief
# Term: briefs
# Term: brilliant
# Term: bring
# Term: brings
# Term: british
# Term: broad
# Term: broader
# Term: brody
# Term: broker
# Term: brokerages
# Term: brokers
# Term: bros
# Term: brought
# Term: btc
# Term: bucket
# Term: buckle
# Term: budgetary
# Term: buffett
# Term: bug
# Term: build
# Term: builder
# Term: building
# Term: built
# Term: bukele
# Term: bull
# Term: bullish
# Term: bulls
# Term: bully
# Term: bureau
# Term: burgeoning
# Term: business
# Term: businesses
# Term: businessweek
# Term: busy
# Term: but
# Term: buy
# Term: buyers
# Term: buying
# Term: buys
# Term: by
# Term: california
# Term: call
# Term: called
# Term: calm
# Term: calpers
# Term: cambridge
# Term: came
# Term: campaign
# Term: campbell
# Term: can
# Term: candidate
# Term: cap
# Term: capabilities
# Term: capability
# Term: capable
# Term: capital
# Term: capitalist
# Term: capitalization
# Term: caps
# Term: carbon
# Term: cards
# Term: carefully
# Term: carries
# Term: case
# Term: cases
# Term: casey
# Term: cash
# Term: cashflows
# Term: casino
# Term: cat
# Term: catalyst
# Term: catching
# Term: categories
# Term: category
# Term: caterpillar
# Term: cathedrals
# Term: cathie
# Term: caught
# Term: cause
# Term: causes
# Term: cboe
# Term: cd20
# Term: celebrated
# Term: center
# Term: centers
# Term: central
# Term: centralized
# Term: centric
# Term: cents
# Term: century
# Term: ceo
# Term: certainly
# Term: chain
# Term: chair
# Term: chairman
# Term: challenge
# Term: challenger
# Term: challenging
# Term: chance
# Term: change
# Term: changed
# Term: changer
# Term: changing
# Term: changpeng
# Term: characteristics
# Term: charges
# Term: chart
# Term: charting
# Term: chase
# Term: check
# Term: checks
# Term: chesapeake
# Term: chg
# Term: chhugani
# Term: chief
# Term: china
# Term: chipmixer
# Term: chk
# Term: choice
# Term: choices
# Term: choose
# Term: chooses
# Term: choppy
# Term: chunk
# Term: cifr
# Term: cipher
# Term: circle
# Term: circuits
# Term: circulation
# Term: circumvent
# Term: cited
# Term: cites
# Term: citing
# Term: citizens
# Term: cityfunds
# Term: civil
# Term: claiming
# Term: claims
# Term: clarity
# Term: classic
# Term: classification
# Term: cleanspark
# Term: clear
# Term: clearing
# Term: clearly
# Term: click
# Term: clients
# Term: climate
# Term: climbs
# Term: clorox
# Term: close
# Term: closed
# Term: closely
# Term: closer
# Term: closest
# Term: closing
# Term: cloud
# Term: clsk
# Term: clubs
# Term: clx
# Term: cmcsa
# Term: co
# Term: coca
# Term: code
# Term: cohorts
# Term: coin
# Term: coinbase
# Term: coincided
# Term: coindesk
# Term: coinfund
# Term: coingecko
# Term: coinkite
# Term: coins
# Term: cola
# Term: collaborate
# Term: collapse
# Term: collapsed
# Term: collateral
# Term: collateralized
# Term: collection
# Term: collective
# Term: collectively
# Term: collison
# Term: columbia
# Term: columnist
# Term: com
# Term: combination
# Term: combined
# Term: comcast
# Term: come
# Term: comes
# Term: coming
# Term: command
# Term: commensurate
# Term: comment
# Term: comments
# Term: commercial
# Term: commercialization
# Term: commission
# Term: commissioners
# Term: committed
# Term: committee
# Term: commodities
# Term: commodity
# Term: communication
# Term: community
# Term: companies
# Term: company
# Term: compared
# Term: comparison
# Term: compelling
# Term: compete
# Term: competent
# Term: competition
# Term: competitor
# Term: competitors
# Term: compiled
# Term: complete
# Term: completeness
# Term: complex
# Term: complexity
# Term: compliance
# Term: complicated
# Term: component
# Term: compute
# Term: computer
# Term: computers
# Term: computing
# Term: con
# Term: conceal
# Term: concentrated
# Term: concern
# Term: concerned
# Term: concerning
# Term: concerns
# Term: concluded
# Term: condition
# Term: conditions
# Term: condo
# Term: conference
# Term: confidence
# Term: confirmation
# Term: confiscated
# Term: conflate
# Term: confuse
# Term: congress
# Term: congressional
# Term: congressman
# Term: connected
# Term: consecutive
# Term: consensus
# Term: consensys
# Term: conservative
# Term: consider
# Term: considerable
# Term: considerably
# Term: considerations
# Term: considered
# Term: consistent
# Term: consistently
# Term: consists
# Term: constant
# Term: constitutes
# Term: consultant
# Term: consume
# Term: consumer
# Term: consumers
# Term: consumes
# Term: consumption
# Term: contained
# Term: contender
# Term: content
# Term: contest
# Term: context
# Term: continue
# Term: continued
# Term: continues
# Term: continuing
# Term: continuously
# Term: contract
# Term: contribute
# Term: contributing
# Term: control
# Term: controlled
# Term: controlling
# Term: controls
# Term: conundrum
# Term: convenient
# Term: conventional
# Term: convert
# Term: converted
# Term: convertible
# Term: cool
# Term: cooled
# Term: cooley
# Term: cooperation
# Term: coordination
# Term: copyright
# Term: copyrighted
# Term: core
# Term: corner
# Term: corp
# Term: corporate
# Term: corporation
# Term: correct
# Term: correction
# Term: correlated
# Term: correlation
# Term: cost
# Term: costly
# Term: costs
# Term: costume
# Term: could
# Term: couldn
# Term: council
# Term: counsel
# Term: count
# Term: countries
# Term: country
# Term: counts
# Term: couple
# Term: course
# Term: court
# Term: courthouse
# Term: cowen
# Term: crack
# Term: crackdown
# Term: crazy
# Term: create
# Term: created
# Term: creating
# Term: creator
# Term: creators
# Term: cref
# Term: crime
# Term: criminal
# Term: criminals
# Term: crisis
# Term: critic
# Term: criticism
# Term: criticizes
# Term: critics
# Term: cross
# Term: crowd
# Term: crucial
# Term: crude
# Term: crunch
# Term: cruz
# Term: cry
# Term: crypto
# Term: cryptocurrencies
# Term: cryptocurrency
# Term: cryptographic
# Term: cryptos
# Term: culminating
# Term: cumulative
# Term: cure
# Term: curiae
# Term: currencies
# Term: currency
# Term: current
# Term: currently
# Term: custodial
# Term: custodians
# Term: custody
# Term: customers
# Term: cut
# Term: cuts
# Term: cybercrime
# Term: cycle
# Term: cycles
# Term: cz
# Term: daily
# Term: damages
# Term: dark
# Term: dashboard
# Term: dasp
# Term: data
# Term: date
# Term: david
# Term: day
# Term: days
# Term: db
# Term: dc
# Term: de
# Term: deal
# Term: dealer
# Term: dealings
# Term: deaton
# Term: debased
# Term: debasement
# Term: debasing
# Term: debate
# Term: debt
# Term: debut
# Term: decade
# Term: decades
# Term: deceiving
# Term: december
# Term: decent
# Term: decentralized
# Term: decided
# Term: deciding
# Term: decision
# Term: decisions
# Term: decline
# Term: declining
# Term: dedicated
# Term: deduct
# Term: deemed
# Term: deems
# Term: deep
# Term: deeply
# Term: defense
# Term: defi
# Term: deficit
# Term: deflationary
# Term: defy
# Term: degree
# Term: delays
# Term: delist
# Term: deliver
# Term: demand
# Term: demanded
# Term: democrat
# Term: democratic
# Term: democratize
# Term: demographic
# Term: demonstrated
# Term: demonstrates
# Term: denominated
# Term: departed
# Term: departure
# Term: depend
# Term: dependence
# Term: depends
# Term: deposit
# Term: deposited
# Term: deposits
# Term: deputy
# Term: deribit
# Term: derivatives
# Term: deserve
# Term: design
# Term: designed
# Term: designer
# Term: designing
# Term: desk
# Term: despite
# Term: detail
# Term: detailed
# Term: details
# Term: detective
# Term: determining
# Term: devaluation
# Term: developer
# Term: developers
# Term: development
# Term: developments
# Term: device
# Term: devices
# Term: dia
# Term: diamondback
# Term: did
# Term: didn
# Term: different
# Term: differentiator
# Term: difficult
# Term: difficulty
# Term: digital
# Term: digitalx
# Term: diligence
# Term: diminish
# Term: diminished
# Term: diminishing
# Term: dipped
# Term: direct
# Term: direction
# Term: directly
# Term: director
# Term: disclosure
# Term: disclosures
# Term: discontinuing
# Term: discovered
# Term: discovery
# Term: discretion
# Term: disinflationary
# Term: dismay
# Term: display
# Term: disruption
# Term: disservice
# Term: distinguishable
# Term: distributed
# Term: distribution
# Term: distributions
# Term: district
# Term: dive
# Term: diverse
# Term: diversification
# Term: diversified
# Term: dividend
# Term: dividends
# Term: dividing
# Term: dlx
# Term: do
# Term: does
# Term: doesn
# Term: dog
# Term: doge
# Term: dogecoin
# Term: dogwifhat
# Term: doing
# Term: dollar
# Term: dollars
# Term: dominance
# Term: dominant
# Term: dominate
# Term: dominic
# Term: don
# Term: donald
# Term: done
# Term: door
# Term: doors
# Term: dorman
# Term: double
# Term: doubled
# Term: dove
# Term: dow
# Term: down
# Term: download
# Term: downturn
# Term: downturns
# Term: downward
# Term: drawbacks
# Term: drawn
# Term: drive
# Term: driven
# Term: driver
# Term: driving
# Term: drones
# Term: drop
# Term: dropped
# Term: dropping
# Term: drops
# Term: drying
# Term: due
# Term: dumb
# Term: dune
# Term: during
# Term: dust
# Term: dvol
# Term: dxy
# Term: dynamic
# Term: dynamics
# Term: each
# Term: earlier
# Term: early
# Term: earn
# Term: earned
# Term: earning
# Term: earnings
# Term: earns
# Term: earth
# Term: easily
# Term: easing
# Term: east
# Term: easy
# Term: easygoatfish351
# Term: eat
# Term: eaton
# Term: economic
# Term: economies
# Term: economy
# Term: ecosystem
# Term: ecosystems
# Term: eden
# Term: edged
# Term: editing
# Term: edt
# Term: eea
# Term: effect
# Term: effectively
# Term: effects
# Term: effort
# Term: efforts
# Term: eighth
# Term: either
# Term: el
# Term: election
# Term: electricity
# Term: electronic
# Term: elegance
# Term: eleven
# Term: eli
# Term: eligible
# Term: elizabeth
# Term: elliott
# Term: elon
# Term: else
# Term: elsewhere
# Term: email
# Term: embraced
# Term: embracing
# Term: emi
# Term: emphasizing
# Term: empire
# Term: employee
# Term: employing
# Term: employment
# Term: enable
# Term: enables
# Term: enabling
# Term: encourage
# Term: encrypted
# Term: end
# Term: ended
# Term: endorses
# Term: ends
# Term: energy
# Term: enforce
# Term: engage
# Term: engaged
# Term: engagement
# Term: engages
# Term: engaging
# Term: engineering
# Term: enhanced
# Term: enjoy
# Term: enormous
# Term: enough
# Term: enquiry
# Term: ensue
# Term: ensuring
# Term: enter
# Term: entering
# Term: enterprise
# Term: enterprises
# Term: enthusiast
# Term: enticing
# Term: entire
# Term: entirely
# Term: entities
# Term: entrepreneur
# Term: entrepreneurs
# Term: entry
# Term: environment
# Term: environmental
# Term: environments
# Term: epic
# Term: equation
# Term: equipment
# Term: equities
# Term: equity
# Term: equivalent
# Term: era
# Term: erman
# Term: error
# Term: especially
# Term: essentially
# Term: established
# Term: establishing
# Term: estate
# Term: estimate
# Term: estimated
# Term: estimates
# Term: et
# Term: etch
# Term: etf
# Term: etfs
# Term: eth
# Term: ether
# Term: ethereum
# Term: etn
# Term: eu
# Term: euphoria
# Term: europe
# Term: european
# Term: evade
# Term: evelyn
# Term: even
# Term: evening
# Term: event
# Term: events
# Term: eventually
# Term: ever
# Term: every
# Term: everything
# Term: evidence
# Term: evident
# Term: evo
# Term: evolution
# Term: evolving
# Term: ex
# Term: exactly
# Term: examination
# Term: example
# Term: examples
# Term: exceeding
# Term: except
# Term: exchange
# Term: exchanges
# Term: excitement
# Term: exciting
# Term: excluding
# Term: executes
# Term: executing
# Term: executive
# Term: exercising
# Term: exert
# Term: exhibit
# Term: exist
# Term: existed
# Term: existing
# Term: exists
# Term: exited
# Term: exodus
# Term: expand
# Term: expansion
# Term: expect
# Term: expectation
# Term: expectations
# Term: expected
# Term: expenses
# Term: expensive
# Term: experienced
# Term: experiences
# Term: experts
# Term: expire
# Term: explained
# Term: explicit
# Term: exploded
# Term: exploitation
# Term: exploration
# Term: explore
# Term: explosive
# Term: exponentially
# Term: exports
# Term: exposed
# Term: exposes
# Term: exposure
# Term: express
# Term: expressing
# Term: extent
# Term: extreme
# Term: extremely
# Term: ey
# Term: eye
# Term: eyebrows
# Term: eyes
# Term: ezbc
# Term: face
# Term: facebook
# Term: faced
# Term: facing
# Term: fact
# Term: factor
# Term: factors
# Term: fade
# Term: faded
# Term: fading
# Term: fail
# Term: failed
# Term: failla
# Term: failure
# Term: fair
# Term: fairjunco470
# Term: fairly
# Term: faith
# Term: fall
# Term: fallen
# Term: falling
# Term: falls
# Term: false
# Term: famed
# Term: familiar
# Term: family
# Term: fang
# Term: fans
# Term: far
# Term: faster
# Term: fate
# Term: favored
# Term: fbi
# Term: fbtc
# Term: fears
# Term: feat
# Term: features
# Term: february
# Term: fed
# Term: federal
# Term: fees
# Term: fell
# Term: fervently
# Term: few
# Term: fewer
# Term: fiat
# Term: fidelity
# Term: field
# Term: fierce
# Term: fight
# Term: fighting
# Term: fights
# Term: file
# Term: filed
# Term: filing
# Term: filings
# Term: fill
# Term: finally
# Term: finance
# Term: financial
# Term: financing
# Term: find
# Term: fine
# Term: finite
# Term: finiteness
# Term: fintech
# Term: firm
# Term: firms
# Term: first
# Term: fiscal
# Term: five
# Term: flagship
# Term: flat
# Term: flawed
# Term: flood
# Term: flow
# Term: flowing
# Term: flows
# Term: fluctuations
# Term: focus
# Term: focused
# Term: focuses
# Term: folk
# Term: follow
# Term: following
# Term: follows
# Term: fool
# Term: fools
# Term: football
# Term: footprint
# Term: for
# Term: foray
# Term: force
# Term: forced
# Term: forcing
# Term: forecast
# Term: forecasted
# Term: forecasts
# Term: forever
# Term: forget
# Term: form
# Term: formally
# Term: former
# Term: formerly
# Term: formidable
# Term: fortunes
# Term: forward
# Term: found
# Term: foundation
# Term: founder
# Term: founding
# Term: four
# Term: fourth
# Term: fox
# Term: fractional
# Term: fractions
# Term: frame
# Term: framework
# Term: frameworks
# Term: france
# Term: francisco
# Term: frankfurt
# Term: franklin
# Term: fraud
# Term: free
# Term: french
# Term: frenzy
# Term: fresh
# Term: friday
# Term: fried
# Term: friend
# Term: from
# Term: frozen
# Term: ftx
# Term: fuel
# Term: fueled
# Term: fueling
# Term: full
# Term: fully
# Term: fulton
# Term: fun
# Term: functions
# Term: fund
# Term: fundamental
# Term: fundamentals
# Term: funded
# Term: funding
# Term: fundraising
# Term: funds
# Term: fungible
# Term: further
# Term: furthest
# Term: future
# Term: futures
# Term: gain
# Term: gained
# Term: gains
# Term: gambling
# Term: game
# Term: games
# Term: gamut
# Term: gapping
# Term: gaps
# Term: garantex
# Term: gardens
# Term: garnered
# Term: gary
# Term: gas
# Term: gathered
# Term: gautam
# Term: gave
# Term: gbtc
# Term: gdp
# Term: ge
# Term: gehc
# Term: gen
# Term: general
# Term: generally
# Term: generate
# Term: generated
# Term: generates
# Term: generation
# Term: generational
# Term: generations
# Term: generative
# Term: gensler
# Term: geopolitical
# Term: germany
# Term: gestation
# Term: get
# Term: getting
# Term: getty
# Term: giant
# Term: gifted
# Term: ginns
# Term: give
# Term: given
# Term: gives
# Term: global
# Term: globaldata
# Term: globally
# Term: globe
# Term: gme
# Term: go
# Term: goal
# Term: godbole
# Term: goes
# Term: going
# Term: gold
# Term: goldman
# Term: gone
# Term: good
# Term: gop
# Term: got
# Term: gotten
# Term: government
# Term: governments
# Term: gpus
# Term: grab
# Term: grade
# Term: graduate
# Term: grand
# Term: granted
# Term: graph
# Term: graphic
# Term: gravity
# Term: grayscale
# Term: great
# Term: greater
# Term: greatest
# Term: greek
# Term: greenback
# Term: greenfield
# Term: grew
# Term: grewal
# Term: grips
# Term: grounds
# Term: group
# Term: groups
# Term: grow
# Term: growing
# Term: grown
# Term: grows
# Term: growth
# Term: gtbc
# Term: guarantee
# Term: guaranteed
# Term: guess
# Term: guesses
# Term: guessing
# Term: guidance
# Term: guide
# Term: guilty
# Term: hacker
# Term: hacking
# Term: hacks
# Term: had
# Term: half
# Term: hallucination
# Term: halt
# Term: halved
# Term: halving
# Term: halvings
# Term: handful
# Term: hanging
# Term: hangs
# Term: hannah
# Term: hans
# Term: happen
# Term: happened
# Term: happens
# Term: harbor
# Term: hard
# Term: harder
# Term: hardware
# Term: hardwired
# Term: harvard
# Term: has
# Term: hash
# Term: hasn
# Term: haul
# Term: have
# Term: haven
# Term: having
# Term: hawkish
# Term: he
# Term: head
# Term: headed
# Term: headquarters
# Term: headwinds
# Term: healthcare
# Term: healthy
# Term: heard
# Term: hearing
# Term: heavily
# Term: heavy
# Term: heavyweights
# Term: hedge
# Term: hedges
# Term: hedging
# Term: heels
# Term: hefty
# Term: heists
# Term: held
# Term: help
# Term: helped
# Term: helping
# Term: helps
# Term: here
# Term: hero
# Term: hester
# Term: hidden
# Term: high
# Term: higher
# Term: highest
# Term: highlights
# Term: highly
# Term: highs
# Term: hiked
# Term: him
# Term: himself
# Term: hinder
# Term: hired
# Term: his
# Term: historic
# Term: historical
# Term: historically
# Term: history
# Term: hit
# Term: hits
# Term: hitting
# Term: hobby
# Term: hockstein
# Term: hoium
# Term: hold
# Term: holder
# Term: holders
# Term: holding
# Term: holdings
# Term: holds
# Term: home
# Term: honest
# Term: hong
# Term: hood
# Term: hopes
# Term: hoping
# Term: horizon
# Term: horizons
# Term: hostile
# Term: hot
# Term: hottest
# Term: hours
# Term: household
# Term: housing
# Term: hovering
# Term: how
# Term: howcroft
# Term: however
# Term: howey
# Term: hsbc
# Term: huge
# Term: human
# Term: humanity
# Term: humans
# Term: hundreds
# Term: hype
# Term: hyperbitcoinization
# Term: hypothesis
# Term: ibit
# Term: ibkr
# Term: iceberg
# Term: icos
# Term: icp
# Term: ideas
# Term: identified
# Term: identifying
# Term: identities
# Term: identity
# Term: if
# Term: illicit
# Term: illistration
# Term: image
# Term: images
# Term: immediate
# Term: immediately
# Term: impact
# Term: impacts
# Term: impairment
# Term: impasse
# Term: implant
# Term: implants
# Term: implement
# Term: implementation
# Term: implications
# Term: implied
# Term: imply
# Term: importance
# Term: important
# Term: imposed
# Term: impossible
# Term: impressed
# Term: impressive
# Term: improve
# Term: improved
# Term: improvement
# Term: in
# Term: inbox
# Term: inc
# Term: incentives
# Term: inception
# Term: include
# Term: included
# Term: includes
# Term: including
# Term: inclusion
# Term: income
# Term: inconsistent
# Term: incorporate
# Term: incorporating
# Term: increase
# Term: increased
# Term: increases
# Term: increasing
# Term: increasingly
# Term: incredible
# Term: incredibly
# Term: incumbent
# Term: incur
# Term: incurred
# Term: indeed
# Term: independence
# Term: index
# Term: indexes
# Term: india
# Term: indicate
# Term: indicated
# Term: indicating
# Term: indices
# Term: individual
# Term: individuals
# Term: induced
# Term: induces
# Term: industrial
# Term: industries
# Term: industry
# Term: inevitably
# Term: infamous
# Term: inferred
# Term: inflated
# Term: inflating
# Term: inflation
# Term: inflationary
# Term: inflow
# Term: inflows
# Term: influence
# Term: information
# Term: informational
# Term: informed
# Term: infrastructure
# Term: inherent
# Term: initial
# Term: inject
# Term: innovation
# Term: innovative
# Term: insights
# Term: inspire
# Term: inspired
# Term: instantly
# Term: instead
# Term: institution
# Term: institutional
# Term: institutions
# Term: intangible
# Term: integrate
# Term: integrated
# Term: integrating
# Term: integrity
# Term: intelligence
# Term: intended
# Term: intensify
# Term: interactive
# Term: interconnected
# Term: interest
# Term: interested
# Term: interesting
# Term: interfaces
# Term: interfere
# Term: interlocutory
# Term: intermediaries
# Term: internet
# Term: interpretation
# Term: interpreted
# Term: intervening
# Term: intervention
# Term: interview
# Term: into
# Term: intriguing
# Term: intrinsic
# Term: introduce
# Term: introduced
# Term: introduces
# Term: introducing
# Term: introduction
# Term: invesco
# Term: invest
# Term: invested
# Term: investigation
# Term: investigator
# Term: investing
# Term: investment
# Term: investments
# Term: investor
# Term: investors
# Term: invests
# Term: involved
# Term: involvement
# Term: involves
# Term: involving
# Term: iran
# Term: iras
# Term: irrational
# Term: irresponsible
# Term: irs
# Term: is
# Term: ishares
# Term: islands
# Term: isn
# Term: israel
# Term: issuance
# Term: issue
# Term: issued
# Term: issues
# Term: it
# Term: items
# Term: its
# Term: itself
# Term: iwm
# Term: jagielski
# Term: jail
# Term: jan
# Term: janet
# Term: january
# Term: japan
# Term: japanese
# Term: jeff
# Term: jerome
# Term: john
# Term: join
# Term: joined
# Term: joining
# Term: joint
# Term: jones
# Term: journal
# Term: journalists
# Term: journey
# Term: jpm
# Term: jpmorgan
# Term: jpy
# Term: judge
# Term: judges
# Term: jump
# Term: jumped
# Term: jumping
# Term: juncture
# Term: june
# Term: jurisdictional
# Term: just
# Term: justify
# Term: k33
# Term: kazakhstan
# Term: keep
# Term: kerrisdale
# Term: kevin
# Term: key
# Term: kind
# Term: knock
# Term: know
# Term: knowledge
# Term: known
# Term: ko
# Term: kong
# Term: konstantin
# Term: korea
# Term: korean
# Term: koryo
# Term: kreiter
# Term: l2
# Term: lab
# Term: labor
# Term: labs
# Term: lack
# Term: lacking
# Term: laggard
# Term: lance
# Term: landlord
# Term: landsberg
# Term: landscape
# Term: lang
# Term: language
# Term: large
# Term: largely
# Term: larger
# Term: largest
# Term: last
# Term: late
# Term: lately
# Term: later
# Term: latest
# Term: launch
# Term: launched
# Term: launching
# Term: laundered
# Term: laundering
# Term: law
# Term: lawmakers
# Term: lawmaking
# Term: laws
# Term: lawsuit
# Term: lawsuits
# Term: lawyer
# Term: lawyers
# Term: layers
# Term: lazarus
# Term: lbc
# Term: lbry
# Term: lead
# Term: leader
# Term: leaderboard
# Term: leading
# Term: leads
# Term: leaning
# Term: learn
# Term: learning
# Term: leary
# Term: least
# Term: leaving
# Term: led
# Term: ledger
# Term: left
# Term: legal
# Term: legislation
# Term: legitimacy
# Term: legitimate
# Term: lekker
# Term: less
# Term: lesser
# Term: let
# Term: lets
# Term: letter
# Term: letting
# Term: level
# Term: levels
# Term: lex
# Term: liabilities
# Term: license
# Term: lightly
# Term: like
# Term: likely
# Term: lilly
# Term: limits
# Term: line
# Term: linked
# Term: linkedin
# Term: links
# Term: linux
# Term: liquid
# Term: liquidity
# Term: list
# Term: listed
# Term: listings
# Term: literally
# Term: litmus
# Term: little
# Term: live
# Term: ll
# Term: llc
# Term: lloyd
# Term: llp
# Term: lly
# Term: loans
# Term: local
# Term: logic
# Term: london
# Term: long
# Term: longer
# Term: longevity
# Term: look
# Term: looking
# Term: looks
# Term: lose
# Term: losing
# Term: loss
# Term: losses
# Term: lost
# Term: lot
# Term: loving
# Term: low
# Term: lower
# Term: lowering
# Term: lowest
# Term: lows
# Term: lpl
# Term: lpla
# Term: ltd
# Term: lunde
# Term: ma
# Term: mac
# Term: machine
# Term: macro
# Term: macroeconomic
# Term: made
# Term: maga
# Term: magic
# Term: magical
# Term: magnify
# Term: mahika
# Term: main
# Term: mainland
# Term: mainstream
# Term: maintain
# Term: maintained
# Term: maintains
# Term: major
# Term: majority
# Term: make
# Term: maker
# Term: makes
# Term: making
# Term: malevolent
# Term: maliciousness
# Term: man
# Term: manage
# Term: managed
# Term: management
# Term: manager
# Term: managers
# Term: managing
# Term: manhattan
# Term: mania
# Term: mansion
# Term: manufacturer
# Term: many
# Term: mar
# Term: mara
# Term: marathon
# Term: march
# Term: margins
# Term: mark
# Term: marked
# Term: marker
# Term: market
# Term: marketing
# Term: marketplace
# Term: markets
# Term: marking
# Term: marks
# Term: marshall
# Term: masks
# Term: massachusetts
# Term: mastered
# Term: masters
# Term: materialize
# Term: math
# Term: matter
# Term: matters
# Term: matures
# Term: may
# Term: mcd
# Term: mcdonald
# Term: md
# Term: me
# Term: mean
# Term: meaning
# Term: meaningless
# Term: means
# Term: meantime
# Term: meanwhile
# Term: measly
# Term: measure
# Term: measures
# Term: measuring
# Term: meat
# Term: mechanism
# Term: media
# Term: medium
# Term: mediums
# Term: meet
# Term: meeting
# Term: member
# Term: meme
# Term: memecoin
# Term: memecoins
# Term: mempool
# Term: mentioned
# Term: merge
# Term: metals
# Term: metaverse
# Term: methods
# Term: miami
# Term: mica
# Term: michael
# Term: micro
# Term: microstrategy
# Term: mid
# Term: midday
# Term: middle
# Term: middlemen
# Term: might
# Term: migrate
# Term: milestone
# Term: military
# Term: millennial
# Term: millennials
# Term: million
# Term: millionaire
# Term: millionaires
# Term: millions
# Term: mind
# Term: mindset
# Term: mine
# Term: mined
# Term: miner
# Term: miners
# Term: minimal
# Term: mining
# Term: mint
# Term: minutes
# Term: miss
# Term: mission
# Term: misunderstanding
# Term: mitigate
# Term: mix
# Term: mixer
# Term: mixers
# Term: mixing
# Term: mmm
# Term: mode
# Term: modeled
# Term: modest
# Term: modestly
# Term: modi
# Term: mojo
# Term: moment
# Term: momentum
# Term: monday
# Term: monetary
# Term: money
# Term: monitor
# Term: monochrome
# Term: monster
# Term: month
# Term: monthly
# Term: months
# Term: monumental
# Term: moon
# Term: more
# Term: moreover
# Term: morgan
# Term: morning
# Term: mortgage
# Term: most
# Term: mostly
# Term: motion
# Term: motley
# Term: mounting
# Term: mounts
# Term: move
# Term: movement
# Term: mover
# Term: movers
# Term: moves
# Term: movie2k
# Term: moving
# Term: mpc
# Term: mstr
# Term: much
# Term: mulling
# Term: multibillion
# Term: musk
# Term: must
# Term: my
# Term: nakamoto
# Term: name
# Term: names
# Term: narrative
# Term: narratives
# Term: narrowed
# Term: nasdaq
# Term: nation
# Term: national
# Term: nations
# Term: natively
# Term: natural
# Term: nature
# Term: navigate
# Term: navigated
# Term: nayib
# Term: naysayers
# Term: nba
# Term: nbcuniversal
# Term: near
# Term: nearly
# Term: necessarily
# Term: necessary
# Term: need
# Term: needed
# Term: needs
# Term: negating
# Term: negative
# Term: neighborhoods
# Term: neil
# Term: neither
# Term: net
# Term: netherlands
# Term: network
# Term: networked
# Term: networks
# Term: neural
# Term: neuralink
# Term: neurotech
# Term: never
# Term: new
# Term: newest
# Term: news
# Term: newsletter
# Term: next
# Term: nft
# Term: nftpulse
# Term: nfts
# Term: nightmare
# Term: nihilism
# Term: nine
# Term: no
# Term: noah
# Term: noelle
# Term: nominee
# Term: non
# Term: nonsense
# Term: nonzero
# Term: normal
# Term: norms
# Term: north
# Term: not
# Term: notable
# Term: note
# Term: noted
# Term: notes
# Term: nothing
# Term: nothingness
# Term: notorious
# Term: novelty
# Term: november
# Term: now
# Term: nowhere
# Term: number
# Term: numbers
# Term: numerous
# Term: nvda
# Term: nvidia
# Term: nyse
# Term: obligations
# Term: obliged
# Term: obscure
# Term: observers
# Term: obtain
# Term: obtained
# Term: occasional
# Term: occur
# Term: occurred
# Term: occurring
# Term: occurs
# Term: ocean
# Term: october
# Term: odds
# Term: oecd
# Term: of
# Term: off
# Term: offer
# Term: offering
# Term: offerings
# Term: offers
# Term: officer
# Term: officially
# Term: officials
# Term: offloaded
# Term: offset
# Term: offshore
# Term: often
# Term: oil
# Term: oke
# Term: old
# Term: oliver
# Term: omkar
# Term: on
# Term: once
# Term: one
# Term: oneok
# Term: ones
# Term: ongoing
# Term: online
# Term: only
# Term: onshore
# Term: onto
# Term: open
# Term: opendelta
# Term: opening
# Term: opens
# Term: operate
# Term: operates
# Term: operating
# Term: operations
# Term: operators
# Term: opinions
# Term: opportunism
# Term: opportunities
# Term: opportunity
# Term: opposing
# Term: optimism
# Term: option
# Term: options
# Term: or
# Term: ordeal
# Term: order
# Term: ordered
# Term: ordinary
# Term: org
# Term: organization
# Term: organizations
# Term: organized
# Term: oriented
# Term: origin
# Term: original
# Term: originally
# Term: origins
# Term: orthodoxy
# Term: oscillated
# Term: other
# Term: others
# Term: our
# Term: ournetwork
# Term: ourselves
# Term: ousa
# Term: ousm
# Term: out
# Term: outcome
# Term: outcompete
# Term: outflow
# Term: outflows
# Term: outlaw
# Term: outlook
# Term: outpacing
# Term: outperform
# Term: outperformance
# Term: outperformed
# Term: outside
# Term: outsider
# Term: outweigh
# Term: over
# Term: overall
# Term: overbought
# Term: overlap
# Term: oversee
# Term: oversight
# Term: overwhelming
# Term: owed
# Term: owing
# Term: own
# Term: owned
# Term: owner
# Term: owners
# Term: ownership
# Term: owning
# Term: owns
# Term: p2p
# Term: pace
# Term: pacific
# Term: package
# Term: paid
# Term: paint
# Term: pair
# Term: paolo
# Term: paper
# Term: paradigm
# Term: paramount
# Term: parliament
# Term: parliamentary
# Term: part
# Term: participants
# Term: particular
# Term: particularly
# Term: partly
# Term: partner
# Term: parts
# Term: pass
# Term: passed
# Term: passes
# Term: passing
# Term: passive
# Term: passports
# Term: past
# Term: patel
# Term: path
# Term: pattern
# Term: patterns
# Term: paul
# Term: pause
# Term: pay
# Term: paying
# Term: payment
# Term: payments
# Term: payout
# Term: payouts
# Term: paypal
# Term: pays
# Term: pce
# Term: pdvsa
# Term: peak
# Term: peaked
# Term: peer
# Term: peers
# Term: pegged
# Term: peirce
# Term: penalties
# Term: penny
# Term: pension
# Term: pent
# Term: people
# Term: per
# Term: percent
# Term: percentage
# Term: perfectly
# Term: perform
# Term: performance
# Term: performed
# Term: perhaps
# Term: peril
# Term: period
# Term: periods
# Term: permalink
# Term: permission
# Term: perpetuity
# Term: perseverance
# Term: persistent
# Term: persists
# Term: person
# Term: perused
# Term: peter
# Term: petroleum
# Term: pharmaceutical
# Term: philadelphia
# Term: philippines
# Term: philosophy
# Term: photo
# Term: picked
# Term: picks
# Term: picture
# Term: pie
# Term: piece
# Term: piling
# Term: pinpoint
# Term: pins
# Term: pinterest
# Term: pitch
# Term: pivot
# Term: pivotal
# Term: place
# Term: places
# Term: plain
# Term: plan
# Term: planet
# Term: planned
# Term: plans
# Term: plant
# Term: platform
# Term: platforms
# Term: play
# Term: player
# Term: players
# Term: playground
# Term: plays
# Term: playstation
# Term: plc
# Term: pleaded
# Term: plenary
# Term: plenty
# Term: plotted
# Term: pltr
# Term: plummeted
# Term: plunged
# Term: plustoken
# Term: pocketed
# Term: pockets
# Term: podcast
# Term: point
# Term: points
# Term: poised
# Term: policy
# Term: policymakers
# Term: political
# Term: polkadot
# Term: polygon
# Term: pompliano
# Term: ponzi
# Term: pool
# Term: pools
# Term: poorer
# Term: popular
# Term: popularity
# Term: population
# Term: portfolio
# Term: portfolios
# Term: portion
# Term: portrait
# Term: posed
# Term: poses
# Term: position
# Term: positioned
# Term: positions
# Term: positive
# Term: possession
# Term: possibility
# Term: possible
# Term: possibly
# Term: post
# Term: posted
# Term: posts
# Term: potential
# Term: potentially
# Term: pour
# Term: power
# Term: powered
# Term: powerful
# Term: powers
# Term: pre
# Term: precedent
# Term: precious
# Term: predetermined
# Term: predict
# Term: prediction
# Term: predicts
# Term: prefer
# Term: preferences
# Term: preferred
# Term: prefers
# Term: premium
# Term: preparing
# Term: presently
# Term: preservation
# Term: preserve
# Term: president
# Term: presidential
# Term: presiding
# Term: press
# Term: pressing
# Term: pressure
# Term: pressured
# Term: pressures
# Term: presumably
# Term: pretend
# Term: pretty
# Term: prevent
# Term: previous
# Term: previously
# Term: price
# Term: priced
# Term: prices
# Term: prigent
# Term: primarily
# Term: primary
# Term: print
# Term: printing
# Term: prior
# Term: prioritizes
# Term: privacy
# Term: private
# Term: pro
# Term: probability
# Term: problem
# Term: problems
# Term: proceedings
# Term: proceeds
# Term: process
# Term: processed
# Term: processes
# Term: processing
# Term: processor
# Term: produce
# Term: produced
# Term: producing
# Term: product
# Term: production
# Term: products
# Term: professional
# Term: professionals
# Term: professor
# Term: profile
# Term: profit
# Term: profitability
# Term: profitable
# Term: profitably
# Term: profits
# Term: profound
# Term: program
# Term: programmatically
# Term: programmed
# Term: progress
# Term: prohibitive
# Term: project
# Term: projects
# Term: prominent
# Term: promise
# Term: promises
# Term: pronounced
# Term: proof
# Term: prop
# Term: propelling
# Term: properties
# Term: proposed
# Term: proposition
# Term: prosecutors
# Term: proshares
# Term: prospects
# Term: prosthetic
# Term: protecting
# Term: protocol
# Term: protocols
# Term: prove
# Term: proven
# Term: proves
# Term: provide
# Term: provided
# Term: provider
# Term: providers
# Term: provides
# Term: providing
# Term: pru
# Term: prudent
# Term: prudential
# Term: pseudonymous
# Term: psychological
# Term: public
# Term: publicly
# Term: published
# Term: pull
# Term: pullback
# Term: pulled
# Term: pulling
# Term: pulpit
# Term: purchase
# Term: purchased
# Term: purchases
# Term: purchasing
# Term: purely
# Term: purpose
# Term: purposes
# Term: pursue
# Term: pursuing
# Term: purview
# Term: pushing
# Term: put
# Term: putting
# Term: pypl
# Term: q1
# Term: qcp
# Term: qqq
# Term: quadrennial
# Term: quadrupled
# Term: qualifies
# Term: quality
# Term: quantities
# Term: quarter
# Term: quarterly
# Term: question
# Term: questionable
# Term: questioning
# Term: questions
# Term: quick
# Term: quickly
# Term: quinn
# Term: quote
# Term: race
# Term: raise
# Term: raised
# Term: raises
# Term: raising
# Term: rallied
# Term: rallies
# Term: rally
# Term: randomly
# Term: range
# Term: rank
# Term: rapid
# Term: rapidly
# Term: rate
# Term: rates
# Term: ratio
# Term: re
# Term: reach
# Term: reached
# Term: reaches
# Term: reaching
# Term: reacting
# Term: read
# Term: real
# Term: reality
# Term: realize
# Term: realized
# Term: really
# Term: realm
# Term: rearing
# Term: reason
# Term: reasons
# Term: reassured
# Term: rebel
# Term: rebellion
# Term: rebrand
# Term: receipt
# Term: receive
# Term: received
# Term: receives
# Term: receiving
# Term: recent
# Term: recently
# Term: recession
# Term: recognize
# Term: recognized
# Term: recognizing
# Term: recommendation
# Term: recommendations
# Term: recommends
# Term: record
# Term: recorded
# Term: recovery
# Term: reduce
# Term: reduced
# Term: reduces
# Term: reducing
# Term: reduction
# Term: referenced
# Term: referred
# Term: refers
# Term: refraining
# Term: refuge
# Term: refunding
# Term: regarded
# Term: regarding
# Term: region
# Term: registered
# Term: registering
# Term: registries
# Term: regular
# Term: regulate
# Term: regulated
# Term: regulating
# Term: regulation
# Term: regulators
# Term: regulatory
# Term: reimpose
# Term: reintroduction
# Term: rejoin
# Term: relate
# Term: related
# Term: relation
# Term: relative
# Term: relatively
# Term: release
# Term: released
# Term: releases
# Term: relentless
# Term: relevance
# Term: relevant
# Term: reliability
# Term: reliable
# Term: reliance
# Term: relief
# Term: relies
# Term: rely
# Term: remain
# Term: remained
# Term: remaining
# Term: remains
# Term: remember
# Term: reminded
# Term: remove
# Term: renaissancere
# Term: renewed
# Term: renowned
# Term: rent
# Term: rental
# Term: rentals
# Term: repay
# Term: repeating
# Term: replace
# Term: report
# Term: reported
# Term: reportedly
# Term: reporting
# Term: reports
# Term: represent
# Term: representation
# Term: represented
# Term: represents
# Term: republican
# Term: reputation
# Term: request
# Term: requests
# Term: require
# Term: required
# Term: requirements
# Term: requires
# Term: research
# Term: resemblance
# Term: resemble
# Term: reserve
# Term: reserved
# Term: reserves
# Term: reside
# Term: residents
# Term: resilience
# Term: resilient
# Term: resist
# Term: resistant
# Term: resolve
# Term: resort
# Term: resources
# Term: respectively
# Term: respects
# Term: respond
# Term: response
# Term: responses
# Term: responsible
# Term: rest
# Term: restrict
# Term: result
# Term: resulted
# Term: resulting
# Term: results
# Term: retail
# Term: retain
# Term: retired
# Term: retirement
# Term: retraced
# Term: return
# Term: returns
# Term: reuters
# Term: revealed
# Term: reveals
# Term: revenue
# Term: review
# Term: reviving
# Term: reward
# Term: rewards
# Term: rich
# Term: richer
# Term: riddle
# Term: ride
# Term: ridiculed
# Term: right
# Term: rights
# Term: riot
# Term: ripple
# Term: rise
# Term: risen
# Term: rises
# Term: rising
# Term: risk
# Term: riskier
# Term: riskiest
# Term: risking
# Term: risks
# Term: risky
# Term: ritchie
# Term: rival
# Term: rj
# Term: rnr
# Term: road
# Term: robinhood
# Term: robust
# Term: rocket
# Term: rodarmor
# Term: rodrigo
# Term: roger
# Term: role
# Term: roll
# Term: rollup
# Term: rooted
# Term: rose
# Term: roughly
# Term: round
# Term: royalties
# Term: rugs
# Term: rule
# Term: rulebook
# Term: ruled
# Term: rules
# Term: ruling
# Term: run
# Term: runes
# Term: running
# Term: runs
# Term: rushed
# Term: russell
# Term: russia
# Term: russian
# Term: sachs
# Term: sadie
# Term: safe
# Term: said
# Term: salary
# Term: sale
# Term: sales
# Term: salvador
# Term: sam
# Term: same
# Term: samourai
# Term: san
# Term: sanctioned
# Term: sanctions
# Term: sapra
# Term: sat
# Term: satiate
# Term: satisfy
# Term: satoshi
# Term: satoshis
# Term: saturation
# Term: saw
# Term: say
# Term: saying
# Term: saylor
# Term: says
# Term: sbux
# Term: scale
# Term: scales
# Term: scarcity
# Term: scenario
# Term: scheduled
# Term: scheme
# Term: schiff
# Term: scholes
# Term: school
# Term: scope
# Term: scratched
# Term: scratching
# Term: scrutiny
# Term: sdig
# Term: sea
# Term: seal
# Term: search
# Term: seattle
# Term: sec
# Term: second
# Term: secondary
# Term: secrecy
# Term: secret
# Term: secretary
# Term: sector
# Term: sectors
# Term: secure
# Term: securely
# Term: securities
# Term: security
# Term: see
# Term: seed
# Term: seeing
# Term: seek
# Term: seekers
# Term: seeking
# Term: seem
# Term: seems
# Term: seen
# Term: sees
# Term: seira
# Term: seized
# Term: seizing
# Term: select
# Term: self
# Term: sell
# Term: selling
# Term: sells
# Term: semiconductor
# Term: sen
# Term: senate
# Term: senator
# Term: senators
# Term: send
# Term: sending
# Term: sensational
# Term: sense
# Term: sent
# Term: sentence
# Term: sentencing
# Term: sentiment
# Term: september
# Term: serve
# Term: service
# Term: services
# Term: session
# Term: set
# Term: seth
# Term: sets
# Term: setting
# Term: settle
# Term: seven
# Term: several
# Term: seychelles
# Term: share
# Term: shared
# Term: shareholder
# Term: shares
# Term: sharing
# Term: shark
# Term: sharp
# Term: sharply
# Term: she
# Term: sheets
# Term: shift
# Term: shock
# Term: shoes
# Term: shoot
# Term: short
# Term: shortage
# Term: shorter
# Term: shorting
# Term: should
# Term: show
# Term: showing
# Term: shows
# Term: shrink
# Term: shut
# Term: shutterstock
# Term: side
# Term: sides
# Term: significance
# Term: significant
# Term: significantly
# Term: silk
# Term: similar
# Term: similarly
# Term: simple
# Term: simply
# Term: since
# Term: singapore
# Term: single
# Term: sister
# Term: sit
# Term: site
# Term: sites
# Term: sits
# Term: sitting
# Term: situation
# Term: six
# Term: sizable
# Term: size
# Term: skeptic
# Term: skeptical
# Term: skeptically
# Term: skepticism
# Term: skyrocketed
# Term: skyrocketing
# Term: skyrockets
# Term: skyworks
# Term: slashes
# Term: slid
# Term: slide
# Term: slight
# Term: slightly
# Term: slipped
# Term: slowdown
# Term: slowed
# Term: slower
# Term: slowing
# Term: sluggish
# Term: slumped
# Term: small
# Term: smaller
# Term: smallest
# Term: smart
# Term: smci
# Term: sneaker
# Term: sneakers
# Term: snowballed
# Term: snuffing
# Term: so
# Term: soar
# Term: soared
# Term: soaring
# Term: soars
# Term: social
# Term: society
# Term: software
# Term: sokolin
# Term: sol
# Term: solana
# Term: sold
# Term: sole
# Term: solely
# Term: solid
# Term: solidified
# Term: solidifies
# Term: solo
# Term: solutions
# Term: solve
# Term: solving
# Term: some
# Term: someone
# Term: something
# Term: sometime
# Term: sometimes
# Term: somewhere
# Term: sonali
# Term: soon
# Term: sophisticated
# Term: sought
# Term: sound
# Term: sounds
# Term: source
# Term: sources
# Term: south
# Term: southern
# Term: sovereign
# Term: sovereignty
# Term: space
# Term: spades
# Term: spanned
# Term: spark
# Term: sparked
# Term: sparks
# Term: spat
# Term: spdr
# Term: speaker
# Term: special
# Term: specialist
# Term: specific
# Term: specifically
# Term: speculation
# Term: speculative
# Term: speculators
# Term: speed
# Term: spent
# Term: spiral
# Term: spirits
# Term: sports
# Term: spot
# Term: spread
# Term: spree
# Term: spy
# Term: squeeze
# Term: stability
# Term: stable
# Term: stablecoin
# Term: stacked
# Term: stage
# Term: stages
# Term: stagflation
# Term: stagflationary
# Term: stake
# Term: stalled
# Term: stamp
# Term: stance
# Term: stand
# Term: standing
# Term: standout
# Term: stands
# Term: stanley
# Term: star
# Term: starbucks
# Term: start
# Term: started
# Term: starting
# Term: stash
# Term: state
# Term: stated
# Term: statement
# Term: statements
# Term: states
# Term: stating
# Term: statistics
# Term: status
# Term: stay
# Term: staying
# Term: stays
# Term: steady
# Term: step
# Term: steps
# Term: sticking
# Term: sticky
# Term: still
# Term: stimulate
# Term: stock
# Term: stocks
# Term: stolen
# Term: stonks
# Term: stop
# Term: stopped
# Term: stopping
# Term: store
# Term: stored
# Term: stories
# Term: story
# Term: straight
# Term: strain
# Term: strategic
# Term: strategies
# Term: strategy
# Term: streak
# Term: stream
# Term: street
# Term: strength
# Term: strengthening
# Term: strict
# Term: strike
# Term: stripe
# Term: strong
# Term: stronger
# Term: strongest
# Term: stronghold
# Term: struck
# Term: structured
# Term: stryker
# Term: stubbornly
# Term: stuck
# Term: subject
# Term: subscribe
# Term: subscriptions
# Term: subsides
# Term: substantial
# Term: substantially
# Term: succeed
# Term: success
# Term: successful
# Term: successfully
# Term: such
# Term: sudden
# Term: sued
# Term: suffer
# Term: suffered
# Term: sufficient
# Term: suggest
# Term: suitable
# Term: suited
# Term: sum
# Term: sumitomo
# Term: summer
# Term: sums
# Term: sunday
# Term: super
# Term: supercharge
# Term: superior
# Term: supply
# Term: support
# Term: supporters
# Term: supporting
# Term: supports
# Term: supposed
# Term: supreme
# Term: sure
# Term: surface
# Term: surge
# Term: surged
# Term: surging
# Term: surpass
# Term: surpassed
# Term: surpasses
# Term: surpassing
# Term: surprise
# Term: surprising
# Term: surveyed
# Term: survival
# Term: survive
# Term: suspected
# Term: suspicion
# Term: suspicious
# Term: sustainable
# Term: sustained
# Term: sutor
# Term: suzanne
# Term: swap
# Term: swiftly
# Term: swings
# Term: swks
# Term: sword
# Term: syk
# Term: system
# Term: systems
# Term: tailwind
# Term: tailwinds
# Term: take
# Term: takeaway
# Term: taken
# Term: takes
# Term: taking
# Term: talented
# Term: tame
# Term: tank
# Term: tanked
# Term: target
# Term: targeting
# Term: targets
# Term: tax
# Term: taxed
# Term: taxes
# Term: taxpayer
# Term: td
# Term: teachers
# Term: team
# Term: tech
# Term: technical
# Term: techno
# Term: technologies
# Term: technologists
# Term: technology
# Term: telecom
# Term: television
# Term: tell
# Term: tells
# Term: tempered
# Term: templeton
# Term: temporary
# Term: tend
# Term: tender
# Term: tends
# Term: tens
# Term: tensions
# Term: tensor
# Term: tentative
# Term: tepid
# Term: terawatt
# Term: term
# Term: terms
# Term: terrorist
# Term: tesla
# Term: test
# Term: testifies
# Term: testing
# Term: tether
# Term: texas
# Term: texts
# Term: than
# Term: thank
# Term: thanked
# Term: that
# Term: the
# Term: thefts
# Term: their
# Term: them
# Term: themed
# Term: themselves
# Term: then
# Term: theory
# Term: there
# Term: thereby
# Term: therefore
# Term: these
# Term: they
# Term: things
# Term: think
# Term: thinking
# Term: thinks
# Term: third
# Term: this
# Term: thompson
# Term: thorn
# Term: those
# Term: though
# Term: thousand
# Term: threat
# Term: three
# Term: threshold
# Term: thrive
# Term: thriving
# Term: through
# Term: throw
# Term: thursday
# Term: thus
# Term: tiaa
# Term: tight
# Term: tightening
# Term: tiktok
# Term: till
# Term: time
# Term: timeline
# Term: times
# Term: tiny
# Term: tip
# Term: titled
# Term: to
# Term: today
# Term: together
# Term: token
# Term: tokenized
# Term: tokenomics
# Term: tokens
# Term: told
# Term: tolerance
# Term: tonkin
# Term: too
# Term: took
# Term: tool
# Term: tools
# Term: top
# Term: topic
# Term: torn
# Term: tornado
# Term: torres
# Term: total
# Term: totaled
# Term: touch
# Term: toward
# Term: track
# Term: tracked
# Term: tracking
# Term: tracks
# Term: trade
# Term: traded
# Term: trader
# Term: traders
# Term: trades
# Term: tradfi
# Term: trading
# Term: tradingview
# Term: traditional
# Term: trail
# Term: traits
# Term: trajectory
# Term: trane
# Term: transaction
# Term: transactions
# Term: transfer
# Term: transfers
# Term: transform
# Term: transformation
# Term: transition
# Term: translates
# Term: transparency
# Term: travel
# Term: travis
# Term: treading
# Term: treasuries
# Term: treasury
# Term: treating
# Term: tremendous
# Term: trend
# Term: trending
# Term: trezor
# Term: trial
# Term: tricking
# Term: tried
# Term: trillion
# Term: true
# Term: truly
# Term: trump
# Term: trust
# Term: trying
# Term: tsla
# Term: tt
# Term: tuesday
# Term: tumble
# Term: tumbled
# Term: tumbles
# Term: tune
# ...
# Term: stated, TF-IDF: 0.03323968398182599
# Term: statement, TF-IDF: 0.0
# Term: statements, TF-IDF: 0.0
# Term: states, TF-IDF: 0.0
# Term: stating, TF-IDF: 0.037020251588197016
# Term: statistics, TF-IDF: 0.0
# Term: status, TF-IDF: 0.0
# Term: stay, TF-IDF: 0.0
# Term: staying, TF-IDF: 0.0
# Term: stays, TF-IDF: 0.0
# Term: steady, TF-IDF: 0.06647936796365198
# Term: step, TF-IDF: 0.0
# Term: steps, TF-IDF: 0.0
# Term: sticking, TF-IDF: 0.0
# Term: sticky, TF-IDF: 0.0
# Term: still, TF-IDF: 0.0
# Term: stimulate, TF-IDF: 0.0
# Term: stock, TF-IDF: 0.0
# Term: stocks, TF-IDF: 0.016533270353837334
# Term: stolen, TF-IDF: 0.0
# Term: stonks, TF-IDF: 0.0
# Term: stop, TF-IDF: 0.0
# Term: stopped, TF-IDF: 0.0
# Term: stopping, TF-IDF: 0.0
# Term: store, TF-IDF: 0.0
# Term: stored, TF-IDF: 0.0
# Term: stories, TF-IDF: 0.0
# Term: story, TF-IDF: 0.0
# Term: straight, TF-IDF: 0.0
# Term: strain, TF-IDF: 0.0
# Term: strategic, TF-IDF: 0.0
# Term: strategies, TF-IDF: 0.0
# Term: strategy, TF-IDF: 0.05067891174746471
# Term: streak, TF-IDF: 0.0
# Term: stream, TF-IDF: 0.037020251588197016
# Term: street, TF-IDF: 0.0
# Term: strength, TF-IDF: 0.0
# Term: strengthening, TF-IDF: 0.0
# Term: strict, TF-IDF: 0.0
# Term: strike, TF-IDF: 0.0
# Term: stripe, TF-IDF: 0.0
# Term: strong, TF-IDF: 0.026776760971017177
# Term: stronger, TF-IDF: 0.0
# Term: strongest, TF-IDF: 0.0
# Term: stronghold, TF-IDF: 0.0
# Term: struck, TF-IDF: 0.0
# Term: structured, TF-IDF: 0.0
# Term: stryker, TF-IDF: 0.0
# Term: stubbornly, TF-IDF: 0.0
# Term: stuck, TF-IDF: 0.0
# Term: subject, TF-IDF: 0.0
# Term: subscribe, TF-IDF: 0.0
# Term: subscriptions, TF-IDF: 0.0
# Term: subsides, TF-IDF: 0.0
# Term: substantial, TF-IDF: 0.0
# Term: substantially, TF-IDF: 0.0
# Term: succeed, TF-IDF: 0.0
# Term: success, TF-IDF: 0.0
# Term: successful, TF-IDF: 0.0
# Term: successfully, TF-IDF: 0.0
# Term: such, TF-IDF: 0.0
# Term: sudden, TF-IDF: 0.0
# Term: sued, TF-IDF: 0.0
# Term: suffer, TF-IDF: 0.0
# Term: suffered, TF-IDF: 0.0
# Term: sufficient, TF-IDF: 0.0
# Term: suggest, TF-IDF: 0.0
# Term: suitable, TF-IDF: 0.0
# Term: suited, TF-IDF: 0.0
# Term: sum, TF-IDF: 0.0
# Term: sumitomo, TF-IDF: 0.0
# Term: summer, TF-IDF: 0.0
# Term: sums, TF-IDF: 0.0
# Term: sunday, TF-IDF: 0.0
# Term: super, TF-IDF: 0.0
# Term: supercharge, TF-IDF: 0.0
# Term: superior, TF-IDF: 0.0
# Term: supply, TF-IDF: 0.0
# Term: support, TF-IDF: 0.0
# Term: supporters, TF-IDF: 0.0
# Term: supporting, TF-IDF: 0.0
# Term: supports, TF-IDF: 0.0
# Term: supposed, TF-IDF: 0.0
# Term: supreme, TF-IDF: 0.0
# Term: sure, TF-IDF: 0.03323968398182599
# Term: surface, TF-IDF: 0.0
# Term: surge, TF-IDF: 0.0
# Term: surged, TF-IDF: 0.0
# Term: surging, TF-IDF: 0.0
# Term: surpass, TF-IDF: 0.0
# Term: surpassed, TF-IDF: 0.0
# Term: surpasses, TF-IDF: 0.0
# Term: surpassing, TF-IDF: 0.0
# Term: surprise, TF-IDF: 0.0
# Term: surprising, TF-IDF: 0.0
# Term: surveyed, TF-IDF: 0.0
# Term: survival, TF-IDF: 0.0
# Term: survive, TF-IDF: 0.0
# Term: suspected, TF-IDF: 0.0
# Term: suspicion, TF-IDF: 0.0
# Term: suspicious, TF-IDF: 0.0
# Term: sustainable, TF-IDF: 0.0
# Term: sustained, TF-IDF: 0.0
# Term: sutor, TF-IDF: 0.0
# Term: suzanne, TF-IDF: 0.0
# Term: swap, TF-IDF: 0.0
# Term: swiftly, TF-IDF: 0.0
# Term: swings, TF-IDF: 0.0
# Term: swks, TF-IDF: 0.0
# Term: sword, TF-IDF: 0.0
# Term: syk, TF-IDF: 0.0
# Term: system, TF-IDF: 0.0
# Term: systems, TF-IDF: 0.0
# Term: tailwind, TF-IDF: 0.0
# Term: tailwinds, TF-IDF: 0.0
# Term: take, TF-IDF: 0.0
# Term: takeaway, TF-IDF: 0.0
# Term: taken, TF-IDF: 0.0
# Term: takes, TF-IDF: 0.0
# Term: taking, TF-IDF: 0.0
# Term: talented, TF-IDF: 0.0
# Term: tame, TF-IDF: 0.0
# Term: tank, TF-IDF: 0.14808100635278806
# Term: tanked, TF-IDF: 0.0
# Term: target, TF-IDF: 0.0
# Term: targeting, TF-IDF: 0.03323968398182599
# Term: targets, TF-IDF: 0.0
# Term: tax, TF-IDF: 0.0
# Term: taxed, TF-IDF: 0.0
# Term: taxes, TF-IDF: 0.0
# Term: taxpayer, TF-IDF: 0.0
# Term: td, TF-IDF: 0.0
# Term: teachers, TF-IDF: 0.0
# Term: team, TF-IDF: 0.0
# Term: tech, TF-IDF: 0.0
# Term: technical, TF-IDF: 0.0
# Term: techno, TF-IDF: 0.0
# Term: technologies, TF-IDF: 0.0
# Term: technologists, TF-IDF: 0.0
# Term: technology, TF-IDF: 0.0
# Term: telecom, TF-IDF: 0.037020251588197016
# Term: television, TF-IDF: 0.0
# Term: tell, TF-IDF: 0.0
# Term: tells, TF-IDF: 0.0
# Term: tempered, TF-IDF: 0.0
# Term: templeton, TF-IDF: 0.0
# Term: temporary, TF-IDF: 0.0
# Term: tend, TF-IDF: 0.0
# Term: tender, TF-IDF: 0.0
# Term: tends, TF-IDF: 0.0
# Term: tens, TF-IDF: 0.0
# Term: tensions, TF-IDF: 0.0
# Term: tensor, TF-IDF: 0.0
# Term: tentative, TF-IDF: 0.0
# Term: tepid, TF-IDF: 0.0
# Term: terawatt, TF-IDF: 0.0
# Term: term, TF-IDF: 0.058702552783562664
# Term: terms, TF-IDF: 0.0
# Term: terrorist, TF-IDF: 0.0
# Term: tesla, TF-IDF: 0.0
# Term: test, TF-IDF: 0.0
# Term: testifies, TF-IDF: 0.0
# Term: testing, TF-IDF: 0.0
# Term: tether, TF-IDF: 0.0
# Term: texas, TF-IDF: 0.0
# Term: texts, TF-IDF: 0.0
# Term: than, TF-IDF: 0.013470289571223822
# Term: thank, TF-IDF: 0.0
# Term: thanked, TF-IDF: 0.0
# Term: that, TF-IDF: 0.04028138937211408
# Term: the, TF-IDF: 0.15850845861479776
# Term: thefts, TF-IDF: 0.0
# Term: their, TF-IDF: 0.0
# Term: them, TF-IDF: 0.0
# Term: themed, TF-IDF: 0.0
# Term: themselves, TF-IDF: 0.0
# Term: then, TF-IDF: 0.0
# Term: theory, TF-IDF: 0.0
# Term: there, TF-IDF: 0.0
# Term: thereby, TF-IDF: 0.0
# Term: therefore, TF-IDF: 0.0
# Term: these, TF-IDF: 0.031101772126994397
# Term: they, TF-IDF: 0.014662211375786448
# Term: things, TF-IDF: 0.0
# Term: think, TF-IDF: 0.0
# Term: thinking, TF-IDF: 0.0
# Term: thinks, TF-IDF: 0.0
# Term: third, TF-IDF: 0.0
# Term: this, TF-IDF: 0.03099904007952406
# Term: thompson, TF-IDF: 0.0
# Term: thorn, TF-IDF: 0.0
# Term: those, TF-IDF: 0.022013809074306008
# Term: though, TF-IDF: 0.0
# Term: thousand, TF-IDF: 0.0
# Term: threat, TF-IDF: 0.0
# Term: three, TF-IDF: 0.02112513438659526
# Term: threshold, TF-IDF: 0.0
# Term: thrive, TF-IDF: 0.0
# Term: thriving, TF-IDF: 0.0
# Term: through, TF-IDF: 0.039135035189041774
# Term: throw, TF-IDF: 0.0
# Term: thursday, TF-IDF: 0.0
# Term: thus, TF-IDF: 0.0
# Term: tiaa, TF-IDF: 0.0
# Term: tight, TF-IDF: 0.0
# Term: tightening, TF-IDF: 0.0
# Term: tiktok, TF-IDF: 0.0
# Term: till, TF-IDF: 0.0
# Term: time, TF-IDF: 0.0
# Term: timeline, TF-IDF: 0.0
# Term: times, TF-IDF: 0.0
# Term: tiny, TF-IDF: 0.0
# Term: tip, TF-IDF: 0.0
# Term: titled, TF-IDF: 0.0
# Term: to, TF-IDF: 0.10256429675075149
# Term: today, TF-IDF: 0.0
# Term: together, TF-IDF: 0.0
# Term: token, TF-IDF: 0.0
# Term: tokenized, TF-IDF: 0.0
# Term: tokenomics, TF-IDF: 0.0
# Term: tokens, TF-IDF: 0.0
# Term: told, TF-IDF: 0.0
# Term: tolerance, TF-IDF: 0.0
# Term: tonkin, TF-IDF: 0.0
# Term: too, TF-IDF: 0.0
# Term: took, TF-IDF: 0.0
# Term: tool, TF-IDF: 0.0
# Term: tools, TF-IDF: 0.0
# Term: top, TF-IDF: 0.0
# Term: topic, TF-IDF: 0.0
# Term: torn, TF-IDF: 0.0
# Term: tornado, TF-IDF: 0.0
# Term: torres, TF-IDF: 0.0
# Term: total, TF-IDF: 0.0
# Term: totaled, TF-IDF: 0.0
# Term: touch, TF-IDF: 0.0
# Term: toward, TF-IDF: 0.0
# Term: track, TF-IDF: 0.0
# Term: tracked, TF-IDF: 0.0
# Term: tracking, TF-IDF: 0.0
# Term: tracks, TF-IDF: 0.0
# Term: trade, TF-IDF: 0.0
# Term: traded, TF-IDF: 0.0
# Term: trader, TF-IDF: 0.0
# Term: traders, TF-IDF: 0.0
# Term: trades, TF-IDF: 0.0
# Term: tradfi, TF-IDF: 0.0
# Term: trading, TF-IDF: 0.0
# Term: tradingview, TF-IDF: 0.0
# Term: traditional, TF-IDF: 0.0
# Term: trail, TF-IDF: 0.0
# Term: traits, TF-IDF: 0.0
# Term: trajectory, TF-IDF: 0.0
# Term: trane, TF-IDF: 0.0
# Term: transaction, TF-IDF: 0.0
# Term: transactions, TF-IDF: 0.0
# Term: transfer, TF-IDF: 0.0
# Term: transfers, TF-IDF: 0.0
# Term: transform, TF-IDF: 0.0
# Term: transformation, TF-IDF: 0.0
# Term: transition, TF-IDF: 0.0
# Term: translates, TF-IDF: 0.0
# Term: transparency, TF-IDF: 0.0
# Term: travel, TF-IDF: 0.0
# Term: travis, TF-IDF: 0.0
# Term: treading, TF-IDF: 0.0
# Term: treasuries, TF-IDF: 0.0
# Term: treasury, TF-IDF: 0.0
# Term: treating, TF-IDF: 0.0
# Term: tremendous, TF-IDF: 0.0
# Term: trend, TF-IDF: 0.0
# Term: trending, TF-IDF: 0.0
# Term: trezor, TF-IDF: 0.0
# Term: trial, TF-IDF: 0.0
# Term: tricking, TF-IDF: 0.0
# Term: tried, TF-IDF: 0.0
# Term: trillion, TF-IDF: 0.0
# Term: true, TF-IDF: 0.0
# Term: truly, TF-IDF: 0.0
# Term: trump, TF-IDF: 0.0
# Term: trust, TF-IDF: 0.0
# Term: trying, TF-IDF: 0.0
# Term: tsla, TF-IDF: 0.0
# Term: tt, TF-IDF: 0.0
# Term: tuesday, TF-IDF: 0.0
# Term: tumble, TF-IDF: 0.0
# Term: tumbled, TF-IDF: 0.0
# Term: tumbles, TF-IDF: 0.0
# Term: tune, TF-IDF: 0.0
# Term: turbulence, TF-IDF: 0.0
# Term: turmoil, TF-IDF: 0.0
# Term: turn, TF-IDF: 0.0
# Term: turnaround, TF-IDF: 0.0
# Term: turned, TF-IDF: 0.0
# Term: tv, TF-IDF: 0.0
# Term: tweeted, TF-IDF: 0.0
# Term: twitter, TF-IDF: 0.0
# Term: two, TF-IDF: 0.0
# Term: type, TF-IDF: 0.0
# Term: types, TF-IDF: 0.0
# Term: typical, TF-IDF: 0.0
# Term: typically, TF-IDF: 0.0
# Term: tysons, TF-IDF: 0.0
# Term: uk, TF-IDF: 0.0
# Term: ultimately, TF-IDF: 0.0
# Term: unauthorised, TF-IDF: 0.0
# Term: unbelievable, TF-IDF: 0.0
# Term: uncertain, TF-IDF: 0.037020251588197016
# Term: uncertainty, TF-IDF: 0.0
# Term: unclear, TF-IDF: 0.0
# Term: uncommon, TF-IDF: 0.0
# Term: uncovered, TF-IDF: 0.0
# Term: under, TF-IDF: 0.0
# Term: underlying, TF-IDF: 0.0
# Term: undermine, TF-IDF: 0.0
# Term: underperformed, TF-IDF: 0.0
# Term: underperforming, TF-IDF: 0.0
# Term: underpins, TF-IDF: 0.0
# Term: understand, TF-IDF: 0.0
# Term: understandable, TF-IDF: 0.0
# Term: understands, TF-IDF: 0.0
# Term: undervalued, TF-IDF: 0.0
# Term: underway, TF-IDF: 0.0
# Term: undoubtedly, TF-IDF: 0.0
# Term: unexpectedly, TF-IDF: 0.0
# Term: unfairly, TF-IDF: 0.0
# Term: unfamiliar, TF-IDF: 0.0
# Term: unfiltered, TF-IDF: 0.0
# Term: unfortunate, TF-IDF: 0.0
# Term: unfortunately, TF-IDF: 0.0
# Term: unheard, TF-IDF: 0.0
# Term: uni, TF-IDF: 0.0
# Term: union, TF-IDF: 0.0
# Term: unions, TF-IDF: 0.0
# Term: unique, TF-IDF: 0.0
# Term: uniquely, TF-IDF: 0.0
# Term: uniswap, TF-IDF: 0.0
# Term: unit, TF-IDF: 0.0
# Term: united, TF-IDF: 0.0
# Term: units, TF-IDF: 0.0
# Term: unless, TF-IDF: 0.0
# Term: unlike, TF-IDF: 0.0
# Term: unlikely, TF-IDF: 0.0
# Term: unlimited, TF-IDF: 0.0
# Term: unlocked, TF-IDF: 0.0
# Term: unm, TF-IDF: 0.0
# Term: unnamed, TF-IDF: 0.0
# Term: unparalleled, TF-IDF: 0.0
# Term: unprecedented, TF-IDF: 0.0
# Term: unprofitable, TF-IDF: 0.0
# Term: unregistered, TF-IDF: 0.0
# Term: unregulated, TF-IDF: 0.0
# Term: unsc, TF-IDF: 0.0
# Term: unseat, TF-IDF: 0.0
# Term: until, TF-IDF: 0.0
# Term: untouched, TF-IDF: 0.0
# Term: unum, TF-IDF: 0.0
# Term: up, TF-IDF: 0.013850914949399547
# Term: update, TF-IDF: 0.0
# Term: updated, TF-IDF: 0.0
# Term: updates, TF-IDF: 0.0
# Term: upfront, TF-IDF: 0.0
# Term: upgrades, TF-IDF: 0.0
# Term: ups, TF-IDF: 0.0
# Term: upside, TF-IDF: 0.0
# Term: upstart, TF-IDF: 0.0
# Term: uptick, TF-IDF: 0.0
# Term: upward, TF-IDF: 0.0
# Term: urban, TF-IDF: 0.0
# Term: us, TF-IDF: 0.060941513880625096
# Term: usage, TF-IDF: 0.0
# Term: usd, TF-IDF: 0.0
# Term: usdc, TF-IDF: 0.0
# Term: usdo, TF-IDF: 0.0
# Term: usdt, TF-IDF: 0.0
# Term: use, TF-IDF: 0.0
# Term: used, TF-IDF: 0.0
# Term: useful, TF-IDF: 0.0
# Term: usernames, TF-IDF: 0.0
# Term: users, TF-IDF: 0.026776760971017177
# Term: uses, TF-IDF: 0.0
# Term: using, TF-IDF: 0.0
# Term: usual, TF-IDF: 0.0
# Term: usually, TF-IDF: 0.0
# Term: utc, TF-IDF: 0.0
# Term: utilities, TF-IDF: 0.0
# Term: utility, TF-IDF: 0.0
# Term: utilizing, TF-IDF: 0.0
# Term: uup, TF-IDF: 0.0
# Term: uyeda, TF-IDF: 0.0
# Term: validate, TF-IDF: 0.0
# Term: validates, TF-IDF: 0.0
# Term: validating, TF-IDF: 0.0
# Term: validation, TF-IDF: 0.0
# Term: valuable, TF-IDF: 0.0
# Term: valuation, TF-IDF: 0.0
# Term: value, TF-IDF: 0.0
# Term: values, TF-IDF: 0.0
# Term: valuing, TF-IDF: 0.0
# Term: vaneck, TF-IDF: 0.0
# Term: vaporware, TF-IDF: 0.0
# Term: varied, TF-IDF: 0.0
# Term: variety, TF-IDF: 0.0
# Term: various, TF-IDF: 0.0
# Term: vasps, TF-IDF: 0.0
# Term: vast, TF-IDF: 0.0
# Term: ve, TF-IDF: 0.030557328577388205
# Term: vehicle, TF-IDF: 0.0
# Term: venezuela, TF-IDF: 0.0
# Term: venture, TF-IDF: 0.028476732085114826
# Term: ventures, TF-IDF: 0.0
# Term: verdict, TF-IDF: 0.0
# Term: verify, TF-IDF: 0.0
# Term: verizon, TF-IDF: 0.14808100635278806
# Term: versus, TF-IDF: 0.0
# Term: very, TF-IDF: 0.0
# Term: vestberg, TF-IDF: 0.037020251588197016
# Term: vetle, TF-IDF: 0.0
# Term: via, TF-IDF: 0.0
# Term: viability, TF-IDF: 0.0
# Term: viable, TF-IDF: 0.0
# Term: viabtc, TF-IDF: 0.0
# Term: vibes, TF-IDF: 0.0
# Term: view, TF-IDF: 0.018648053954682088
# Term: viewable, TF-IDF: 0.0
# Term: viewed, TF-IDF: 0.0
# Term: views, TF-IDF: 0.0
# Term: violating, TF-IDF: 0.0
# Term: virgin, TF-IDF: 0.0
# Term: virginia, TF-IDF: 0.0
# Term: virtual, TF-IDF: 0.0
# Term: virtually, TF-IDF: 0.0
# Term: vision, TF-IDF: 0.0
# Term: visit, TF-IDF: 0.0
# Term: vitanza, TF-IDF: 0.0
# Term: voice, TF-IDF: 0.0
# Term: voiced, TF-IDF: 0.0
# Term: voices, TF-IDF: 0.0
# Term: volatile, TF-IDF: 0.0
# Term: volatility, TF-IDF: 0.02112513438659526
# Term: volcano, TF-IDF: 0.0
# Term: volume, TF-IDF: 0.0
# Term: volumes, TF-IDF: 0.0
# Term: von, TF-IDF: 0.0
# Term: vote, TF-IDF: 0.0
# Term: voted, TF-IDF: 0.0
# Term: vulnerability, TF-IDF: 0.0
# Term: vz, TF-IDF: 0.07404050317639403
# Term: wage, TF-IDF: 0.0
# Term: waitlisters, TF-IDF: 0.0
# Term: wake, TF-IDF: 0.0
# Term: wall, TF-IDF: 0.0
# Term: walled, TF-IDF: 0.0
# Term: wallet, TF-IDF: 0.0
# Term: wallets, TF-IDF: 0.0
# Term: waning, TF-IDF: 0.0
# Term: want, TF-IDF: 0.0
# Term: warner, TF-IDF: 0.0
# Term: warns, TF-IDF: 0.0
# Term: warranty, TF-IDF: 0.0
# Term: warren, TF-IDF: 0.0
# Term: was, TF-IDF: 0.0
# Term: wasabi, TF-IDF: 0.0
# Term: washington, TF-IDF: 0.0
# Term: wasn, TF-IDF: 0.0
# Term: watch, TF-IDF: 0.0
# Term: watchers, TF-IDF: 0.0
# Term: water, TF-IDF: 0.0
# Term: watershed, TF-IDF: 0.0
# Term: wave, TF-IDF: 0.0
# Term: way, TF-IDF: 0.0
# Term: ways, TF-IDF: 0.0
# Term: wbd, TF-IDF: 0.0
# Term: we, TF-IDF: 0.0
# Term: weak, TF-IDF: 0.0
# Term: weakened, TF-IDF: 0.0
# Term: weakening, TF-IDF: 0.0
# Term: weaker, TF-IDF: 0.0
# Term: weakest, TF-IDF: 0.0
# Term: weakness, TF-IDF: 0.0
# Term: wealth, TF-IDF: 0.0
# Term: weapon, TF-IDF: 0.0
# Term: weapons, TF-IDF: 0.0
# Term: wear, TF-IDF: 0.0
# Term: weather, TF-IDF: 0.037020251588197016
# Term: web, TF-IDF: 0.0
# Term: web3, TF-IDF: 0.0
# Term: website, TF-IDF: 0.0
# Term: wednesday, TF-IDF: 0.0
# Term: week, TF-IDF: 0.0
# Term: weekend, TF-IDF: 0.0
# Term: weeks, TF-IDF: 0.0
# Term: weighting, TF-IDF: 0.0
# Term: welcomed, TF-IDF: 0.0
# Term: well, TF-IDF: 0.02112513438659526
# Term: went, TF-IDF: 0.0
# Term: were, TF-IDF: 0.0
# Term: western, TF-IDF: 0.0
# Term: weth, TF-IDF: 0.0
# Term: whales, TF-IDF: 0.0
# Term: what, TF-IDF: 0.0
# Term: when, TF-IDF: 0.0
# Term: where, TF-IDF: 0.0
# Term: whether, TF-IDF: 0.0
# Term: which, TF-IDF: 0.0
# Term: while, TF-IDF: 0.014247741942385633
# Term: whilst, TF-IDF: 0.0
# Term: who, TF-IDF: 0.0
# Term: whose, TF-IDF: 0.0
# Term: why, TF-IDF: 0.0
# Term: wide, TF-IDF: 0.0
# Term: widely, TF-IDF: 0.0
# Term: wider, TF-IDF: 0.0
# Term: widespread, TF-IDF: 0.0
# Term: wif, TF-IDF: 0.0
# Term: wild, TF-IDF: 0.0
# Term: wildly, TF-IDF: 0.0
# Term: will, TF-IDF: 0.0
# Term: windows, TF-IDF: 0.0
# Term: winning, TF-IDF: 0.0
# Term: wins, TF-IDF: 0.0
# Term: wisdom, TF-IDF: 0.037020251588197016
# Term: wise, TF-IDF: 0.0
# Term: wishing, TF-IDF: 0.0
# Term: with, TF-IDF: 0.058889271411282425
# Term: within, TF-IDF: 0.0
# Term: without, TF-IDF: 0.0
# Term: woburn, TF-IDF: 0.0
# Term: woes, TF-IDF: 0.0
# Term: won, TF-IDF: 0.0
# Term: wonder, TF-IDF: 0.0
# Term: wood, TF-IDF: 0.0
# Term: words, TF-IDF: 0.0
# Term: work, TF-IDF: 0.0
# Term: worked, TF-IDF: 0.0
# Term: worker, TF-IDF: 0.0
# Term: working, TF-IDF: 0.0
# Term: works, TF-IDF: 0.0
# Term: world, TF-IDF: 0.0
# Term: worldwide, TF-IDF: 0.0
# Term: worrying, TF-IDF: 0.0
# Term: worst, TF-IDF: 0.0
# Term: worth, TF-IDF: 0.0
# Term: worthless, TF-IDF: 0.0
# Term: would, TF-IDF: 0.0
# Term: wouldn, TF-IDF: 0.0
# Term: wrap, TF-IDF: 0.0
# Term: wrapped, TF-IDF: 0.0
# Term: write, TF-IDF: 0.0
# Term: writing, TF-IDF: 0.0
# Term: writte, TF-IDF: 0.0
# Term: wrote, TF-IDF: 0.0
# Term: wünscher, TF-IDF: 0.0
# Term: xle, TF-IDF: 0.0
# Term: xlu, TF-IDF: 0.0
# Term: xrp, TF-IDF: 0.0
# Term: yahoo, TF-IDF: 0.037020251588197016
# Term: year, TF-IDF: 0.05540365979759819
# Term: years, TF-IDF: 0.015095965256552516
# Term: yellen, TF-IDF: 0.0
# Term: yen, TF-IDF: 0.0
# Term: yesterday, TF-IDF: 0.0
# Term: yet, TF-IDF: 0.0
# Term: yield, TF-IDF: 0.21390130004171742
# Term: yields, TF-IDF: 0.030557328577388205
# Term: york, TF-IDF: 0.0
# Term: you, TF-IDF: 0.07331105687893225
# Term: younger, TF-IDF: 0.0
# Term: your, TF-IDF: 0.04062767592041673
# Term: zach, TF-IDF: 0.0
# Term: zachxbt, TF-IDF: 0.0
# Term: zacks, TF-IDF: 0.0
# Term: zero, TF-IDF: 0.0
# Term: zhao, TF-IDF: 0.0
# Term: zooming, TF-IDF: 0.0

# %%
analysis.print_doc_freq()
# Out:
# Term: 00, Document Frequency: 1
# Term: 000, Document Frequency: 23
# Term: 000th, Document Frequency: 1
# Term: 000x, Document Frequency: 1
# Term: 01, Document Frequency: 2
# Term: 02, Document Frequency: 1
# Term: 03, Document Frequency: 3
# Term: 06, Document Frequency: 1
# Term: 07, Document Frequency: 1
# Term: 070, Document Frequency: 1
# Term: 075, Document Frequency: 2
# Term: 08, Document Frequency: 1
# Term: 10, Document Frequency: 19
# Term: 100, Document Frequency: 13
# Term: 100x, Document Frequency: 1
# Term: 103, Document Frequency: 1
# Term: 104, Document Frequency: 1
# Term: 105, Document Frequency: 1
# Term: 107, Document Frequency: 1
# Term: 10x, Document Frequency: 1
# Term: 11, Document Frequency: 5
# Term: 110, Document Frequency: 1
# Term: 115, Document Frequency: 1
# Term: 12, Document Frequency: 6
# Term: 122, Document Frequency: 1
# Term: 125, Document Frequency: 2
# Term: 13, Document Frequency: 4
# Term: 13bn, Document Frequency: 1
# Term: 14, Document Frequency: 10
# Term: 141, Document Frequency: 1
# Term: 147, Document Frequency: 1
# Term: 15, Document Frequency: 14
# Term: 150, Document Frequency: 2
# Term: 16, Document Frequency: 1
# Term: 160, Document Frequency: 2
# Term: 164, Document Frequency: 1
# Term: 17, Document Frequency: 6
# Term: 170, Document Frequency: 1
# Term: 176, Document Frequency: 1
# Term: 18, Document Frequency: 3
# Term: 182, Document Frequency: 1
# Term: 19, Document Frequency: 5
# Term: 190, Document Frequency: 1
# Term: 1930, Document Frequency: 1
# Term: 1946, Document Frequency: 1
# Term: 195, Document Frequency: 1
# Term: 196, Document Frequency: 1
# Term: 1990, Document Frequency: 2
# Term: 1m, Document Frequency: 2
# Term: 20, Document Frequency: 12
# Term: 200, Document Frequency: 3
# Term: 2000, Document Frequency: 2
# Term: 2002, Document Frequency: 8
# Term: 2005, Document Frequency: 8
# Term: 2008, Document Frequency: 1
# Term: 2009, Document Frequency: 2
# Term: 2011, Document Frequency: 1
# Term: 2013, Document Frequency: 2
# Term: 2014, Document Frequency: 1
# Term: 2018, Document Frequency: 2
# Term: 2019, Document Frequency: 7
# Term: 2020, Document Frequency: 6
# Term: 2021, Document Frequency: 6
# Term: 2022, Document Frequency: 5
# Term: 2023, Document Frequency: 9
# Term: 2024, Document Frequency: 24
# Term: 2025, Document Frequency: 6
# Term: 2028, Document Frequency: 1
# Term: 2030, Document Frequency: 2
# Term: 21, Document Frequency: 6
# Term: 210, Document Frequency: 4
# Term: 214, Document Frequency: 2
# Term: 2140, Document Frequency: 1
# Term: 217, Document Frequency: 1
# Term: 21shares, Document Frequency: 2
# Term: 22, Document Frequency: 14
# Term: 23, Document Frequency: 3
# Term: 237, Document Frequency: 2
# Term: 23m, Document Frequency: 1
# Term: 24, Document Frequency: 3
# Term: 244, Document Frequency: 1
# Term: 25, Document Frequency: 8
# Term: 250, Document Frequency: 2
# Term: 26, Document Frequency: 2
# Term: 27, Document Frequency: 5
# Term: 28, Document Frequency: 3
# Term: 280, Document Frequency: 1
# Term: 29, Document Frequency: 4
# Term: 291, Document Frequency: 5
# Term: 30, Document Frequency: 6
# Term: 300, Document Frequency: 2
# Term: 305, Document Frequency: 1
# Term: 31, Document Frequency: 3
# Term: 33, Document Frequency: 2
# Term: 332, Document Frequency: 1
# Term: 34, Document Frequency: 3
# Term: 345, Document Frequency: 1
# Term: 350, Document Frequency: 2
# Term: 355, Document Frequency: 1
# Term: 36, Document Frequency: 2
# Term: 366m, Document Frequency: 1
# Term: 36bn, Document Frequency: 1
# Term: 37, Document Frequency: 3
# Term: 370, Document Frequency: 1
# Term: 379, Document Frequency: 1
# Term: 38, Document Frequency: 1
# Term: 380m, Document Frequency: 1
# Term: 38m, Document Frequency: 1
# Term: 39, Document Frequency: 1
# Term: 390, Document Frequency: 2
# Term: 399, Document Frequency: 1
# Term: 3m, Document Frequency: 1
# Term: 40, Document Frequency: 3
# Term: 400, Document Frequency: 3
# Term: 401, Document Frequency: 3
# Term: 41, Document Frequency: 2
# Term: 422, Document Frequency: 1
# Term: 428, Document Frequency: 1
# Term: 44, Document Frequency: 1
# Term: 45, Document Frequency: 6
# Term: 450, Document Frequency: 1
# Term: 450m, Document Frequency: 1
# Term: 46, Document Frequency: 1
# Term: 461, Document Frequency: 1
# Term: 480, Document Frequency: 1
# Term: 49, Document Frequency: 2
# Term: 50, Document Frequency: 5
# Term: 500, Document Frequency: 13
# Term: 505, Document Frequency: 1
# Term: 506, Document Frequency: 5
# Term: 518, Document Frequency: 1
# Term: 53, Document Frequency: 2
# Term: 537, Document Frequency: 3
# Term: 55, Document Frequency: 1
# Term: 553, Document Frequency: 1
# Term: 557, Document Frequency: 2
# Term: 559, Document Frequency: 1
# Term: 56, Document Frequency: 2
# Term: 567, Document Frequency: 1
# Term: 575, Document Frequency: 1
# Term: 580, Document Frequency: 3
# Term: 588, Document Frequency: 1
# Term: 59, Document Frequency: 1
# Term: 5g, Document Frequency: 1
# Term: 60, Document Frequency: 8
# Term: 600, Document Frequency: 2
# Term: 600bn, Document Frequency: 1
# Term: 61, Document Frequency: 3
# Term: 62, Document Frequency: 1
# Term: 63, Document Frequency: 1
# Term: 64, Document Frequency: 3
# Term: 644, Document Frequency: 1
# Term: 64k, Document Frequency: 1
# Term: 65, Document Frequency: 2
# Term: 66, Document Frequency: 2
# Term: 68, Document Frequency: 3
# Term: 685, Document Frequency: 1
# Term: 69, Document Frequency: 2
# Term: 692, Document Frequency: 1
# Term: 6bn, Document Frequency: 1
# Term: 6th, Document Frequency: 1
# Term: 70, Document Frequency: 1
# Term: 700, Document Frequency: 4
# Term: 701, Document Frequency: 1
# Term: 71, Document Frequency: 1
# Term: 72, Document Frequency: 1
# Term: 73, Document Frequency: 2
# Term: 74, Document Frequency: 2
# Term: 75, Document Frequency: 1
# Term: 750, Document Frequency: 3
# Term: 76, Document Frequency: 2
# Term: 765, Document Frequency: 1
# Term: 78, Document Frequency: 1
# Term: 79, Document Frequency: 1
# Term: 790, Document Frequency: 1
# Term: 7936, Document Frequency: 1
# Term: 80, Document Frequency: 1
# Term: 800, Document Frequency: 2
# Term: 82, Document Frequency: 1
# Term: 84, Document Frequency: 3
# Term: 85, Document Frequency: 1
# Term: 850, Document Frequency: 1
# Term: 875, Document Frequency: 1
# Term: 89, Document Frequency: 2
# Term: 90, Document Frequency: 3
# Term: 900, Document Frequency: 1
# Term: 923, Document Frequency: 1
# Term: 93, Document Frequency: 1
# Term: 94, Document Frequency: 2
# Term: 95, Document Frequency: 1
# Term: 97, Document Frequency: 1
# Term: 982, Document Frequency: 1
# Term: 983, Document Frequency: 2
# Term: 99, Document Frequency: 2
# Term: 990, Document Frequency: 1
# Term: 992, Document Frequency: 1
# Term: aapl, Document Frequency: 3
# Term: abandoned, Document Frequency: 1
# Term: ability, Document Frequency: 1
# Term: able, Document Frequency: 4
# Term: about, Document Frequency: 19
# Term: above, Document Frequency: 4
# Term: academics, Document Frequency: 1
# Term: accelerating, Document Frequency: 1
# Term: accept, Document Frequency: 3
# Term: acceptable, Document Frequency: 1
# Term: acceptance, Document Frequency: 1
# Term: accepted, Document Frequency: 1
# Term: access, Document Frequency: 3
# Term: accessibility, Document Frequency: 1
# Term: accomplish, Document Frequency: 1
# Term: according, Document Frequency: 14
# Term: account, Document Frequency: 6
# Term: accountably, Document Frequency: 1
# Term: accounted, Document Frequency: 1
# Term: accounting, Document Frequency: 1
# Term: accounts, Document Frequency: 4
# Term: accumulate, Document Frequency: 1
# Term: accumulating, Document Frequency: 2
# Term: accuracy, Document Frequency: 1
# Term: acgl, Document Frequency: 1
# Term: acheson, Document Frequency: 1
# Term: acpr, Document Frequency: 1
# Term: acquire, Document Frequency: 1
# Term: acquired, Document Frequency: 1
# Term: acquisition, Document Frequency: 1
# Term: across, Document Frequency: 5
# Term: act, Document Frequency: 2
# Term: acted, Document Frequency: 1
# Term: action, Document Frequency: 3
# Term: actions, Document Frequency: 1
# Term: active, Document Frequency: 8
# Term: actively, Document Frequency: 1
# Term: activities, Document Frequency: 3
# Term: activity, Document Frequency: 2
# Term: actual, Document Frequency: 2
# Term: actually, Document Frequency: 3
# Term: add, Document Frequency: 5
# Term: added, Document Frequency: 5
# Term: adding, Document Frequency: 3
# Term: addition, Document Frequency: 2
# Term: additional, Document Frequency: 4
# Term: additionally, Document Frequency: 4
# Term: address, Document Frequency: 7
# Term: addresses, Document Frequency: 4
# Term: adds, Document Frequency: 2
# Term: adjunct, Document Frequency: 1
# Term: administration, Document Frequency: 1
# Term: adopt, Document Frequency: 3
# Term: adopted, Document Frequency: 1
# Term: adopting, Document Frequency: 1
# Term: adoption, Document Frequency: 3
# Term: adult, Document Frequency: 5
# Term: advance, Document Frequency: 1
# Term: advanced, Document Frequency: 1
# Term: advancing, Document Frequency: 1
# Term: advantages, Document Frequency: 1
# Term: advertised, Document Frequency: 1
# Term: advice, Document Frequency: 10
# Term: advisor, Document Frequency: 8
# Term: advocate, Document Frequency: 1
# Term: affairs, Document Frequency: 1
# Term: affect, Document Frequency: 1
# Term: affected, Document Frequency: 1
# Term: affiliated, Document Frequency: 1
# Term: afloat, Document Frequency: 1
# Term: africa, Document Frequency: 1
# Term: after, Document Frequency: 21
# Term: afternoon, Document Frequency: 1
# Term: again, Document Frequency: 6
# Term: against, Document Frequency: 6
# Term: age, Document Frequency: 2
# Term: agency, Document Frequency: 2
# Term: agent, Document Frequency: 2
# Term: agents, Document Frequency: 2
# Term: aggregates, Document Frequency: 1
# Term: ago, Document Frequency: 3
# Term: ahead, Document Frequency: 5
# Term: ai, Document Frequency: 2
# Term: aid, Document Frequency: 1
# Term: aided, Document Frequency: 1
# Term: aim, Document Frequency: 1
# Term: aimed, Document Frequency: 1
# Term: aiming, Document Frequency: 2
# Term: algorithm, Document Frequency: 1
# Term: aligns, Document Frequency: 1
# Term: all, Document Frequency: 19
# Term: allegations, Document Frequency: 1
# Term: allegedly, Document Frequency: 2
# Term: alleges, Document Frequency: 1
# Term: allocating, Document Frequency: 1
# Term: allocation, Document Frequency: 2
# Term: allocations, Document Frequency: 1
# Term: allow, Document Frequency: 5
# Term: allowed, Document Frequency: 1
# Term: allowing, Document Frequency: 3
# Term: allows, Document Frequency: 3
# Term: ally, Document Frequency: 1
# Term: almost, Document Frequency: 4
# Term: alone, Document Frequency: 3
# Term: along, Document Frequency: 1
# Term: alps, Document Frequency: 1
# Term: already, Document Frequency: 8
# Term: also, Document Frequency: 21
# Term: altcoins, Document Frequency: 2
# Term: alternative, Document Frequency: 2
# Term: alternatives, Document Frequency: 1
# Term: alters, Document Frequency: 1
# Term: although, Document Frequency: 2
# Term: altogether, Document Frequency: 1
# Term: alts, Document Frequency: 1
# Term: always, Document Frequency: 2
# Term: amass, Document Frequency: 1
# Term: amazon, Document Frequency: 2
# Term: amd, Document Frequency: 1
# Term: america, Document Frequency: 1
# Term: americas, Document Frequency: 2
# Term: amf, Document Frequency: 1
# Term: amicus, Document Frequency: 1
# Term: amid, Document Frequency: 2
# Term: among, Document Frequency: 7
# Term: amount, Document Frequency: 8
# Term: amounts, Document Frequency: 2
# Term: amzn, Document Frequency: 1
# Term: an, Document Frequency: 28
# Term: analysing, Document Frequency: 1
# Term: analysis, Document Frequency: 9
# Term: analyst, Document Frequency: 12
# Term: analysts, Document Frequency: 13
# Term: analytics, Document Frequency: 1
# Term: analyzing, Document Frequency: 1
# Term: anarchist, Document Frequency: 1
# Term: and, Document Frequency: 37
# Term: andvaneck, Document Frequency: 1
# Term: animal, Document Frequency: 1
# Term: announced, Document Frequency: 2
# Term: announcement, Document Frequency: 1
# Term: annualized, Document Frequency: 1
# Term: anonymity, Document Frequency: 1
# Term: anonymous, Document Frequency: 2
# Term: another, Document Frequency: 10
# Term: answer, Document Frequency: 1
# Term: anthony, Document Frequency: 1
# Term: anti, Document Frequency: 3
# Term: anticipated, Document Frequency: 3
# Term: anticipation, Document Frequency: 3
# Term: any, Document Frequency: 13
# Term: anyone, Document Frequency: 3
# Term: anything, Document Frequency: 2
# Term: anytime, Document Frequency: 1
# Term: app, Document Frequency: 2
# Term: apparent, Document Frequency: 1
# Term: appeal, Document Frequency: 2
# Term: appealing, Document Frequency: 1
# Term: appeals, Document Frequency: 1
# Term: appear, Document Frequency: 1
# Term: appeared, Document Frequency: 9
# Term: appears, Document Frequency: 2
# Term: appellate, Document Frequency: 1
# Term: appetite, Document Frequency: 1
# Term: apple, Document Frequency: 4
# Term: application, Document Frequency: 2
# Term: applications, Document Frequency: 4
# Term: applied, Document Frequency: 1
# Term: apply, Document Frequency: 2
# Term: applying, Document Frequency: 2
# Term: appointed, Document Frequency: 1
# Term: appointment, Document Frequency: 1
# Term: appreciate, Document Frequency: 1
# Term: appreciated, Document Frequency: 1
# Term: appreciation, Document Frequency: 5
# Term: apprehension, Document Frequency: 1
# Term: approach, Document Frequency: 2
# Term: approval, Document Frequency: 8
# Term: approvals, Document Frequency: 2
# Term: approved, Document Frequency: 8
# Term: approving, Document Frequency: 1
# Term: approximately, Document Frequency: 4
# Term: apr, Document Frequency: 2
# Term: april, Document Frequency: 18
# Term: apy, Document Frequency: 1
# Term: arca, Document Frequency: 1
# Term: arch, Document Frequency: 1
# Term: architecture, Document Frequency: 1
# Term: ardoino, Document Frequency: 1
# Term: are, Document Frequency: 29
# Term: aren, Document Frequency: 4
# Term: arguably, Document Frequency: 1
# Term: argued, Document Frequency: 1
# Term: argues, Document Frequency: 1
# Term: arguing, Document Frequency: 1
# Term: argument, Document Frequency: 2
# Term: arise, Document Frequency: 1
# Term: ark, Document Frequency: 4
# Term: arkb, Document Frequency: 2
# Term: arkham, Document Frequency: 1
# Term: arkw, Document Frequency: 2
# Term: arm, Document Frequency: 1
# Term: arms, Document Frequency: 2
# Term: around, Document Frequency: 18
# Term: arrests, Document Frequency: 1
# Term: arrival, Document Frequency: 2
# Term: arrive, Document Frequency: 2
# Term: arrived, Document Frequency: 1
# Term: article, Document Frequency: 21
# Term: artificial, Document Frequency: 2
# Term: as, Document Frequency: 34
# Term: asap, Document Frequency: 1
# Term: asia, Document Frequency: 2
# Term: asian, Document Frequency: 1
# Term: asic, Document Frequency: 1
# Term: asics, Document Frequency: 1
# Term: aside, Document Frequency: 1
# Term: asked, Document Frequency: 1
# Term: asking, Document Frequency: 2
# Term: aspect, Document Frequency: 1
# Term: assault, Document Frequency: 1
# Term: assert, Document Frequency: 1
# Term: assessment, Document Frequency: 1
# Term: assessments, Document Frequency: 1
# Term: asset, Document Frequency: 20
# Term: assets, Document Frequency: 19
# Term: assistance, Document Frequency: 1
# Term: associated, Document Frequency: 1
# Term: association, Document Frequency: 2
# Term: astounding, Document Frequency: 1
# Term: astronomically, Document Frequency: 1
# Term: asx, Document Frequency: 2
# Term: at, Document Frequency: 30
# Term: ath, Document Frequency: 2
# Term: aths, Document Frequency: 2
# Term: atop, Document Frequency: 1
# Term: attempting, Document Frequency: 2
# Term: attention, Document Frequency: 2
# Term: attract, Document Frequency: 3
# Term: attracted, Document Frequency: 3
# Term: attracting, Document Frequency: 1
# Term: attractive, Document Frequency: 2
# Term: attributes, Document Frequency: 1
# Term: attuned, Document Frequency: 1
# Term: auctioned, Document Frequency: 1
# Term: august, Document Frequency: 4
# Term: aum, Document Frequency: 1
# Term: auspicious, Document Frequency: 1
# Term: austin, Document Frequency: 3
# Term: australia, Document Frequency: 2
# Term: australian, Document Frequency: 2
# Term: author, Document Frequency: 1
# Term: authorities, Document Frequency: 3
# Term: authority, Document Frequency: 2
# Term: authorization, Document Frequency: 2
# Term: authorized, Document Frequency: 1
# Term: automated, Document Frequency: 1
# Term: automatically, Document Frequency: 1
# Term: availability, Document Frequency: 1
# Term: available, Document Frequency: 7
# Term: avenue, Document Frequency: 2
# Term: average, Document Frequency: 3
# Term: awaiting, Document Frequency: 1
# Term: awarded, Document Frequency: 3
# Term: aware, Document Frequency: 1
# Term: away, Document Frequency: 4
# Term: back, Document Frequency: 9
# Term: backed, Document Frequency: 2
# Term: backing, Document Frequency: 1
# Term: backlash, Document Frequency: 1
# Term: bad, Document Frequency: 1
# Term: bahamas, Document Frequency: 1
# Term: balance, Document Frequency: 3
# Term: balanced, Document Frequency: 1
# Term: balances, Document Frequency: 1
# Term: ballooned, Document Frequency: 1
# Term: bank, Document Frequency: 6
# Term: bankers, Document Frequency: 1
# Term: banking, Document Frequency: 2
# Term: bankman, Document Frequency: 1
# Term: bankrate, Document Frequency: 1
# Term: banks, Document Frequency: 6
# Term: barely, Document Frequency: 1
# Term: barriers, Document Frequency: 1
# Term: basak, Document Frequency: 1
# Term: base, Document Frequency: 3
# Term: based, Document Frequency: 9
# Term: basic, Document Frequency: 2
# Term: basics, Document Frequency: 1
# Term: basis, Document Frequency: 3
# Term: basulto, Document Frequency: 1
# Term: bat, Document Frequency: 1
# Term: batch, Document Frequency: 1
# Term: bats, Document Frequency: 1
# Term: battle, Document Frequency: 1
# Term: bcb, Document Frequency: 1
# Term: be, Document Frequency: 28
# Term: beach, Document Frequency: 1
# Term: bear, Document Frequency: 1
# Term: bearing, Document Frequency: 1
# Term: bearish, Document Frequency: 1
# Term: because, Document Frequency: 12
# Term: become, Document Frequency: 6
# Term: becomes, Document Frequency: 2
# Term: becoming, Document Frequency: 1
# Term: bedroom, Document Frequency: 1
# Term: been, Document Frequency: 25
# Term: before, Document Frequency: 14
# Term: began, Document Frequency: 1
# Term: beginning, Document Frequency: 6
# Term: begs, Document Frequency: 1
# Term: begun, Document Frequency: 1
# Term: behalf, Document Frequency: 1
# Term: behave, Document Frequency: 1
# Term: behemoth, Document Frequency: 1
# Term: behind, Document Frequency: 7
# Term: being, Document Frequency: 8
# Term: belief, Document Frequency: 3
# Term: believe, Document Frequency: 9
# Term: believer, Document Frequency: 1
# Term: believes, Document Frequency: 2
# Term: belong, Document Frequency: 1
# Term: below, Document Frequency: 4
# Term: benchmark, Document Frequency: 1
# Term: beneficial, Document Frequency: 1
# Term: beneficiaries, Document Frequency: 2
# Term: beneficiary, Document Frequency: 1
# Term: benefit, Document Frequency: 2
# Term: benefited, Document Frequency: 1
# Term: benefits, Document Frequency: 1
# Term: benzinga, Document Frequency: 7
# Term: berkrot, Document Frequency: 1
# Term: bernstein, Document Frequency: 1
# Term: best, Document Frequency: 11
# Term: beta, Document Frequency: 1
# Term: betashares, Document Frequency: 1
# Term: better, Document Frequency: 4
# Term: between, Document Frequency: 9
# Term: beyond, Document Frequency: 1
# Term: bezos, Document Frequency: 1
# Term: biden, Document Frequency: 3
# Term: big, Document Frequency: 1
# Term: bigger, Document Frequency: 2
# Term: biggest, Document Frequency: 5
# Term: bill, Document Frequency: 1
# Term: billion, Document Frequency: 12
# Term: billions, Document Frequency: 2
# Term: binance, Document Frequency: 2
# Term: bitb, Document Frequency: 1
# Term: bitcoin, Document Frequency: 31
# Term: bitcoins, Document Frequency: 8
# Term: bitcointreasuries, Document Frequency: 1
# Term: bito, Document Frequency: 2
# Term: bitwise, Document Frequency: 1
# Term: black, Document Frequency: 2
# Term: blackrock, Document Frequency: 2
# Term: blamed, Document Frequency: 1
# Term: blk, Document Frequency: 1
# Term: bloc, Document Frequency: 2
# Term: block, Document Frequency: 5
# Term: blockchain, Document Frequency: 16
# Term: blockchains, Document Frequency: 1
# Term: blocks, Document Frequency: 5
# Term: blog, Document Frequency: 1
# Term: bloomberg, Document Frequency: 4
# Term: blow, Document Frequency: 1
# Term: blueprint, Document Frequency: 8
# Term: board, Document Frequency: 1
# Term: boj, Document Frequency: 1
# Term: bonds, Document Frequency: 7
# Term: bonk, Document Frequency: 1
# Term: bonuses, Document Frequency: 1
# Term: book, Document Frequency: 2
# Term: boom, Document Frequency: 3
# Term: boost, Document Frequency: 1
# Term: born, Document Frequency: 1
# Term: boston, Document Frequency: 1
# Term: both, Document Frequency: 4
# Term: bottom, Document Frequency: 1
# Term: bought, Document Frequency: 3
# Term: bound, Document Frequency: 1
# Term: boutique, Document Frequency: 1
# Term: bradford, Document Frequency: 1
# Term: brain, Document Frequency: 1
# Term: brand, Document Frequency: 1
# Term: breach, Document Frequency: 2
# Term: breached, Document Frequency: 1
# Term: breaking, Document Frequency: 1
# Term: brexit, Document Frequency: 1
# Term: bridges, Document Frequency: 1
# Term: brief, Document Frequency: 1
# Term: briefs, Document Frequency: 1
# Term: brilliant, Document Frequency: 1
# Term: bring, Document Frequency: 5
# Term: brings, Document Frequency: 2
# Term: british, Document Frequency: 1
# Term: broad, Document Frequency: 2
# Term: broader, Document Frequency: 2
# Term: brody, Document Frequency: 1
# Term: broker, Document Frequency: 3
# Term: brokerages, Document Frequency: 1
# Term: brokers, Document Frequency: 2
# Term: bros, Document Frequency: 1
# Term: brought, Document Frequency: 2
# Term: btc, Document Frequency: 19
# Term: bucket, Document Frequency: 1
# Term: buckle, Document Frequency: 1
# Term: budgetary, Document Frequency: 1
# Term: buffett, Document Frequency: 1
# Term: bug, Document Frequency: 1
# Term: build, Document Frequency: 3
# Term: builder, Document Frequency: 1
# Term: building, Document Frequency: 11
# Term: built, Document Frequency: 5
# Term: bukele, Document Frequency: 1
# Term: bull, Document Frequency: 2
# Term: bullish, Document Frequency: 3
# Term: bulls, Document Frequency: 1
# Term: bully, Document Frequency: 1
# Term: bureau, Document Frequency: 1
# Term: burgeoning, Document Frequency: 1
# Term: business, Document Frequency: 7
# Term: businesses, Document Frequency: 2
# Term: businessweek, Document Frequency: 2
# Term: busy, Document Frequency: 1
# Term: but, Document Frequency: 22
# Term: buy, Document Frequency: 18
# Term: buyers, Document Frequency: 3
# Term: buying, Document Frequency: 6
# Term: buys, Document Frequency: 1
# Term: by, Document Frequency: 33
# Term: california, Document Frequency: 1
# Term: call, Document Frequency: 2
# Term: called, Document Frequency: 6
# Term: calm, Document Frequency: 1
# Term: calpers, Document Frequency: 1
# Term: cambridge, Document Frequency: 1
# Term: came, Document Frequency: 4
# Term: campaign, Document Frequency: 2
# Term: campbell, Document Frequency: 1
# Term: can, Document Frequency: 22
# Term: candidate, Document Frequency: 1
# Term: cap, Document Frequency: 6
# Term: capabilities, Document Frequency: 1
# Term: capability, Document Frequency: 1
# Term: capable, Document Frequency: 1
# Term: capital, Document Frequency: 10
# Term: capitalist, Document Frequency: 1
# Term: capitalization, Document Frequency: 1
# Term: caps, Document Frequency: 1
# Term: carbon, Document Frequency: 2
# Term: cards, Document Frequency: 2
# Term: carefully, Document Frequency: 1
# Term: carries, Document Frequency: 2
# Term: case, Document Frequency: 3
# Term: cases, Document Frequency: 2
# Term: casey, Document Frequency: 1
# Term: cash, Document Frequency: 8
# Term: cashflows, Document Frequency: 1
# Term: casino, Document Frequency: 1
# Term: cat, Document Frequency: 1
# Term: catalyst, Document Frequency: 1
# Term: catching, Document Frequency: 2
# Term: categories, Document Frequency: 1
# Term: category, Document Frequency: 1
# Term: caterpillar, Document Frequency: 1
# Term: cathedrals, Document Frequency: 1
# Term: cathie, Document Frequency: 3
# Term: caught, Document Frequency: 1
# Term: cause, Document Frequency: 3
# Term: causes, Document Frequency: 1
# Term: cboe, Document Frequency: 2
# Term: cd20, Document Frequency: 2
# Term: celebrated, Document Frequency: 1
# Term: center, Document Frequency: 2
# Term: centers, Document Frequency: 2
# Term: central, Document Frequency: 5
# Term: centralized, Document Frequency: 1
# Term: centric, Document Frequency: 1
# Term: cents, Document Frequency: 1
# Term: century, Document Frequency: 1
# Term: ceo, Document Frequency: 6
# Term: certainly, Document Frequency: 2
# Term: chain, Document Frequency: 4
# Term: chair, Document Frequency: 1
# Term: chairman, Document Frequency: 2
# Term: challenge, Document Frequency: 1
# Term: challenger, Document Frequency: 1
# Term: challenging, Document Frequency: 1
# Term: chance, Document Frequency: 4
# Term: change, Document Frequency: 5
# Term: changed, Document Frequency: 1
# Term: changer, Document Frequency: 2
# Term: changing, Document Frequency: 2
# Term: changpeng, Document Frequency: 1
# Term: characteristics, Document Frequency: 1
# Term: charges, Document Frequency: 4
# Term: chart, Document Frequency: 6
# Term: charting, Document Frequency: 1
# Term: chase, Document Frequency: 1
# Term: check, Document Frequency: 2
# Term: checks, Document Frequency: 2
# Term: chesapeake, Document Frequency: 1
# Term: chg, Document Frequency: 1
# Term: chhugani, Document Frequency: 1
# Term: chief, Document Frequency: 2
# Term: china, Document Frequency: 5
# Term: chipmixer, Document Frequency: 1
# Term: chk, Document Frequency: 1
# Term: choice, Document Frequency: 1
# Term: choices, Document Frequency: 1
# Term: choose, Document Frequency: 2
# Term: chooses, Document Frequency: 1
# Term: choppy, Document Frequency: 1
# Term: chunk, Document Frequency: 1
# Term: cifr, Document Frequency: 1
# Term: cipher, Document Frequency: 2
# Term: circle, Document Frequency: 1
# Term: circuits, Document Frequency: 1
# Term: circulation, Document Frequency: 5
# Term: circumvent, Document Frequency: 1
# Term: cited, Document Frequency: 1
# Term: cites, Document Frequency: 1
# Term: citing, Document Frequency: 2
# Term: citizens, Document Frequency: 1
# Term: cityfunds, Document Frequency: 1
# Term: civil, Document Frequency: 1
# Term: claiming, Document Frequency: 1
# Term: claims, Document Frequency: 1
# Term: clarity, Document Frequency: 2
# Term: classic, Document Frequency: 1
# Term: classification, Document Frequency: 1
# Term: cleanspark, Document Frequency: 4
# Term: clear, Document Frequency: 9
# Term: clearing, Document Frequency: 1
# Term: clearly, Document Frequency: 1
# Term: click, Document Frequency: 8
# Term: clients, Document Frequency: 2
# Term: climate, Document Frequency: 1
# Term: climbs, Document Frequency: 1
# Term: clorox, Document Frequency: 1
# Term: close, Document Frequency: 2
# Term: closed, Document Frequency: 2
# Term: closely, Document Frequency: 1
# Term: closer, Document Frequency: 3
# Term: closest, Document Frequency: 1
# Term: closing, Document Frequency: 3
# Term: cloud, Document Frequency: 1
# Term: clsk, Document Frequency: 3
# Term: clubs, Document Frequency: 2
# Term: clx, Document Frequency: 1
# Term: cmcsa, Document Frequency: 1
# Term: co, Document Frequency: 5
# Term: coca, Document Frequency: 1
# Term: code, Document Frequency: 1
# Term: cohorts, Document Frequency: 1
# Term: coin, Document Frequency: 8
# Term: coinbase, Document Frequency: 5
# Term: coincided, Document Frequency: 1
# Term: coindesk, Document Frequency: 5
# Term: coinfund, Document Frequency: 1
# Term: coingecko, Document Frequency: 2
# Term: coinkite, Document Frequency: 1
# Term: coins, Document Frequency: 8
# Term: cola, Document Frequency: 1
# Term: collaborate, Document Frequency: 1
# Term: collapse, Document Frequency: 1
# Term: collapsed, Document Frequency: 1
# Term: collateral, Document Frequency: 1
# Term: collateralized, Document Frequency: 1
# Term: collection, Document Frequency: 1
# Term: collective, Document Frequency: 2
# Term: collectively, Document Frequency: 1
# Term: collison, Document Frequency: 1
# Term: columbia, Document Frequency: 1
# Term: columnist, Document Frequency: 1
# Term: com, Document Frequency: 10
# Term: combination, Document Frequency: 1
# Term: combined, Document Frequency: 3
# Term: comcast, Document Frequency: 1
# Term: come, Document Frequency: 8
# Term: comes, Document Frequency: 4
# Term: coming, Document Frequency: 12
# Term: command, Document Frequency: 1
# Term: commensurate, Document Frequency: 1
# Term: comment, Document Frequency: 3
# Term: comments, Document Frequency: 38
# Term: commercial, Document Frequency: 1
# Term: commercialization, Document Frequency: 1
# Term: commission, Document Frequency: 5
# Term: commissioners, Document Frequency: 1
# Term: committed, Document Frequency: 1
# Term: committee, Document Frequency: 2
# Term: commodities, Document Frequency: 3
# Term: commodity, Document Frequency: 2
# Term: communication, Document Frequency: 1
# Term: community, Document Frequency: 3
# Term: companies, Document Frequency: 13
# Term: company, Document Frequency: 11
# Term: compared, Document Frequency: 5
# Term: comparison, Document Frequency: 1
# Term: compelling, Document Frequency: 4
# Term: compete, Document Frequency: 2
# Term: competent, Document Frequency: 2
# Term: competition, Document Frequency: 1
# Term: competitor, Document Frequency: 1
# Term: competitors, Document Frequency: 1
# Term: compiled, Document Frequency: 2
# Term: complete, Document Frequency: 3
# Term: completeness, Document Frequency: 1
# Term: complex, Document Frequency: 3
# Term: complexity, Document Frequency: 1
# Term: compliance, Document Frequency: 1
# Term: complicated, Document Frequency: 1
# Term: component, Document Frequency: 1
# Term: compute, Document Frequency: 1
# Term: computer, Document Frequency: 3
# Term: computers, Document Frequency: 2
# Term: computing, Document Frequency: 2
# Term: con, Document Frequency: 1
# Term: conceal, Document Frequency: 1
# Term: concentrated, Document Frequency: 1
# Term: concern, Document Frequency: 4
# Term: concerned, Document Frequency: 1
# Term: concerning, Document Frequency: 1
# Term: concerns, Document Frequency: 3
# Term: concluded, Document Frequency: 1
# Term: condition, Document Frequency: 1
# Term: conditions, Document Frequency: 1
# Term: condo, Document Frequency: 1
# Term: conference, Document Frequency: 3
# Term: confidence, Document Frequency: 3
# Term: confirmation, Document Frequency: 1
# Term: confiscated, Document Frequency: 1
# Term: conflate, Document Frequency: 1
# Term: confuse, Document Frequency: 1
# Term: congress, Document Frequency: 1
# Term: congressional, Document Frequency: 1
# Term: congressman, Document Frequency: 1
# Term: connected, Document Frequency: 1
# Term: consecutive, Document Frequency: 2
# Term: consensus, Document Frequency: 3
# Term: consensys, Document Frequency: 2
# Term: conservative, Document Frequency: 1
# Term: consider, Document Frequency: 9
# Term: considerable, Document Frequency: 3
# Term: considerably, Document Frequency: 2
# Term: considerations, Document Frequency: 1
# Term: considered, Document Frequency: 2
# Term: consistent, Document Frequency: 3
# Term: consistently, Document Frequency: 1
# Term: consists, Document Frequency: 1
# Term: constant, Document Frequency: 2
# Term: constitutes, Document Frequency: 1
# Term: consultant, Document Frequency: 1
# Term: consume, Document Frequency: 1
# Term: consumer, Document Frequency: 2
# Term: consumers, Document Frequency: 2
# Term: consumes, Document Frequency: 1
# Term: consumption, Document Frequency: 1
# Term: contained, Document Frequency: 1
# Term: contender, Document Frequency: 1
# Term: content, Document Frequency: 2
# Term: contest, Document Frequency: 1
# Term: context, Document Frequency: 4
# Term: continue, Document Frequency: 7
# Term: continued, Document Frequency: 5
# Term: continues, Document Frequency: 7
# Term: continuing, Document Frequency: 1
# Term: continuously, Document Frequency: 1
# Term: contract, Document Frequency: 2
# Term: contribute, Document Frequency: 2
# Term: contributing, Document Frequency: 1
# Term: control, Document Frequency: 4
# Term: controlled, Document Frequency: 1
# Term: controlling, Document Frequency: 1
# Term: controls, Document Frequency: 1
# Term: conundrum, Document Frequency: 1
# Term: convenient, Document Frequency: 1
# Term: conventional, Document Frequency: 1
# Term: convert, Document Frequency: 1
# Term: converted, Document Frequency: 1
# Term: convertible, Document Frequency: 1
# Term: cool, Document Frequency: 1
# Term: cooled, Document Frequency: 1
# Term: cooley, Document Frequency: 1
# Term: cooperation, Document Frequency: 1
# Term: coordination, Document Frequency: 1
# Term: copyright, Document Frequency: 1
# Term: copyrighted, Document Frequency: 1
# Term: core, Document Frequency: 3
# Term: corner, Document Frequency: 1
# Term: corp, Document Frequency: 1
# Term: corporate, Document Frequency: 3
# Term: corporation, Document Frequency: 2
# Term: correct, Document Frequency: 1
# Term: correction, Document Frequency: 1
# Term: correlated, Document Frequency: 1
# Term: correlation, Document Frequency: 2
# Term: cost, Document Frequency: 2
# Term: costly, Document Frequency: 1
# Term: costs, Document Frequency: 3
# Term: costume, Document Frequency: 1
# Term: could, Document Frequency: 19
# Term: couldn, Document Frequency: 1
# Term: council, Document Frequency: 2
# Term: counsel, Document Frequency: 1
# Term: count, Document Frequency: 2
# Term: countries, Document Frequency: 3
# Term: country, Document Frequency: 3
# Term: counts, Document Frequency: 1
# Term: couple, Document Frequency: 1
# Term: course, Document Frequency: 1
# Term: court, Document Frequency: 3
# Term: courthouse, Document Frequency: 1
# Term: cowen, Document Frequency: 1
# Term: crack, Document Frequency: 1
# Term: crackdown, Document Frequency: 1
# Term: crazy, Document Frequency: 1
# Term: create, Document Frequency: 7
# Term: created, Document Frequency: 6
# Term: creating, Document Frequency: 4
# Term: creator, Document Frequency: 2
# Term: creators, Document Frequency: 2
# Term: cref, Document Frequency: 1
# Term: crime, Document Frequency: 1
# Term: criminal, Document Frequency: 1
# Term: criminals, Document Frequency: 1
# Term: crisis, Document Frequency: 1
# Term: critic, Document Frequency: 1
# Term: criticism, Document Frequency: 2
# Term: criticizes, Document Frequency: 1
# Term: critics, Document Frequency: 1
# Term: cross, Document Frequency: 1
# Term: crowd, Document Frequency: 1
# Term: crucial, Document Frequency: 2
# Term: crude, Document Frequency: 1
# Term: crunch, Document Frequency: 1
# Term: cruz, Document Frequency: 1
# Term: cry, Document Frequency: 1
# Term: crypto, Document Frequency: 31
# Term: cryptocurrencies, Document Frequency: 15
# Term: cryptocurrency, Document Frequency: 21
# Term: cryptographic, Document Frequency: 1
# Term: cryptos, Document Frequency: 2
# Term: culminating, Document Frequency: 1
# Term: cumulative, Document Frequency: 1
# Term: cure, Document Frequency: 1
# Term: curiae, Document Frequency: 1
# Term: currencies, Document Frequency: 8
# Term: currency, Document Frequency: 8
# Term: current, Document Frequency: 9
# Term: currently, Document Frequency: 9
# Term: custodial, Document Frequency: 1
# Term: custodians, Document Frequency: 1
# Term: custody, Document Frequency: 1
# Term: customers, Document Frequency: 6
# Term: cut, Document Frequency: 9
# Term: cuts, Document Frequency: 2
# Term: cybercrime, Document Frequency: 1
# Term: cycle, Document Frequency: 6
# Term: cycles, Document Frequency: 2
# Term: cz, Document Frequency: 2
# Term: daily, Document Frequency: 6
# Term: damages, Document Frequency: 1
# Term: dark, Document Frequency: 1
# Term: dashboard, Document Frequency: 1
# Term: dasp, Document Frequency: 1
# Term: data, Document Frequency: 12
# Term: date, Document Frequency: 3
# Term: david, Document Frequency: 1
# Term: day, Document Frequency: 16
# Term: days, Document Frequency: 8
# Term: db, Document Frequency: 1
# Term: dc, Document Frequency: 1
# Term: de, Document Frequency: 1
# Term: deal, Document Frequency: 4
# Term: dealer, Document Frequency: 1
# Term: dealings, Document Frequency: 1
# Term: deaton, Document Frequency: 1
# Term: debased, Document Frequency: 1
# Term: debasement, Document Frequency: 1
# Term: debasing, Document Frequency: 1
# Term: debate, Document Frequency: 1
# Term: debt, Document Frequency: 3
# Term: debut, Document Frequency: 1
# Term: decade, Document Frequency: 5
# Term: decades, Document Frequency: 1
# Term: deceiving, Document Frequency: 1
# Term: december, Document Frequency: 2
# Term: decent, Document Frequency: 1
# Term: decentralized, Document Frequency: 8
# Term: decided, Document Frequency: 1
# Term: deciding, Document Frequency: 1
# Term: decision, Document Frequency: 4
# Term: decisions, Document Frequency: 1
# Term: decline, Document Frequency: 3
# Term: declining, Document Frequency: 1
# Term: dedicated, Document Frequency: 2
# Term: deduct, Document Frequency: 1
# Term: deemed, Document Frequency: 1
# Term: deems, Document Frequency: 2
# Term: deep, Document Frequency: 2
# Term: deeply, Document Frequency: 1
# Term: defense, Document Frequency: 1
# Term: defi, Document Frequency: 2
# Term: deficit, Document Frequency: 1
# Term: deflationary, Document Frequency: 1
# Term: defy, Document Frequency: 2
# Term: degree, Document Frequency: 1
# Term: delays, Document Frequency: 1
# Term: delist, Document Frequency: 1
# Term: deliver, Document Frequency: 2
# Term: demand, Document Frequency: 11
# Term: demanded, Document Frequency: 1
# Term: democrat, Document Frequency: 1
# Term: democratic, Document Frequency: 1
# Term: democratize, Document Frequency: 1
# Term: demographic, Document Frequency: 1
# Term: demonstrated, Document Frequency: 1
# Term: demonstrates, Document Frequency: 1
# Term: denominated, Document Frequency: 2
# Term: departed, Document Frequency: 1
# Term: departure, Document Frequency: 1
# Term: depend, Document Frequency: 1
# Term: dependence, Document Frequency: 1
# Term: depends, Document Frequency: 1
# Term: deposit, Document Frequency: 1
# Term: deposited, Document Frequency: 1
# Term: deposits, Document Frequency: 1
# Term: deputy, Document Frequency: 1
# Term: deribit, Document Frequency: 1
# Term: derivatives, Document Frequency: 1
# Term: deserve, Document Frequency: 1
# Term: design, Document Frequency: 2
# Term: designed, Document Frequency: 2
# Term: designer, Document Frequency: 1
# Term: designing, Document Frequency: 1
# Term: desk, Document Frequency: 2
# Term: despite, Document Frequency: 7
# Term: detail, Document Frequency: 1
# Term: detailed, Document Frequency: 1
# Term: details, Document Frequency: 1
# Term: detective, Document Frequency: 1
# Term: determining, Document Frequency: 1
# Term: devaluation, Document Frequency: 1
# Term: developer, Document Frequency: 2
# Term: developers, Document Frequency: 2
# Term: development, Document Frequency: 2
# Term: developments, Document Frequency: 2
# Term: device, Document Frequency: 1
# Term: devices, Document Frequency: 2
# Term: dia, Document Frequency: 1
# Term: diamondback, Document Frequency: 1
# Term: did, Document Frequency: 8
# Term: didn, Document Frequency: 4
# Term: different, Document Frequency: 5
# Term: differentiator, Document Frequency: 1
# Term: difficult, Document Frequency: 4
# Term: difficulty, Document Frequency: 1
# Term: digital, Document Frequency: 24
# Term: digitalx, Document Frequency: 1
# Term: diligence, Document Frequency: 3
# Term: diminish, Document Frequency: 1
# Term: diminished, Document Frequency: 1
# Term: diminishing, Document Frequency: 1
# Term: dipped, Document Frequency: 3
# Term: direct, Document Frequency: 1
# Term: direction, Document Frequency: 1
# Term: directly, Document Frequency: 2
# Term: director, Document Frequency: 2
# Term: disclosure, Document Frequency: 8
# Term: disclosures, Document Frequency: 1
# Term: discontinuing, Document Frequency: 1
# Term: discovered, Document Frequency: 1
# Term: discovery, Document Frequency: 1
# Term: discretion, Document Frequency: 1
# Term: disinflationary, Document Frequency: 1
# Term: dismay, Document Frequency: 1
# Term: display, Document Frequency: 1
# Term: disruption, Document Frequency: 1
# Term: disservice, Document Frequency: 1
# Term: distinguishable, Document Frequency: 1
# Term: distributed, Document Frequency: 1
# Term: distribution, Document Frequency: 1
# Term: distributions, Document Frequency: 1
# Term: district, Document Frequency: 1
# Term: dive, Document Frequency: 1
# Term: diverse, Document Frequency: 1
# Term: diversification, Document Frequency: 1
# Term: diversified, Document Frequency: 1
# Term: dividend, Document Frequency: 1
# Term: dividends, Document Frequency: 1
# Term: dividing, Document Frequency: 1
# Term: dlx, Document Frequency: 1
# Term: do, Document Frequency: 9
# Term: does, Document Frequency: 11
# Term: doesn, Document Frequency: 4
# Term: dog, Document Frequency: 2
# Term: doge, Document Frequency: 7
# Term: dogecoin, Document Frequency: 7
# Term: dogwifhat, Document Frequency: 1
# Term: doing, Document Frequency: 4
# Term: dollar, Document Frequency: 9
# Term: dollars, Document Frequency: 4
# Term: dominance, Document Frequency: 1
# Term: dominant, Document Frequency: 1
# Term: dominate, Document Frequency: 1
# Term: dominic, Document Frequency: 1
# Term: don, Document Frequency: 6
# Term: donald, Document Frequency: 2
# Term: done, Document Frequency: 5
# Term: door, Document Frequency: 1
# Term: doors, Document Frequency: 1
# Term: dorman, Document Frequency: 1
# Term: double, Document Frequency: 2
# Term: doubled, Document Frequency: 1
# Term: dove, Document Frequency: 1
# Term: dow, Document Frequency: 1
# Term: down, Document Frequency: 15
# Term: download, Document Frequency: 3
# Term: downturn, Document Frequency: 1
# Term: downturns, Document Frequency: 1
# Term: downward, Document Frequency: 2
# Term: drawbacks, Document Frequency: 1
# Term: drawn, Document Frequency: 1
# Term: drive, Document Frequency: 3
# Term: driven, Document Frequency: 3
# Term: driver, Document Frequency: 1
# Term: driving, Document Frequency: 3
# Term: drones, Document Frequency: 1
# Term: drop, Document Frequency: 2
# Term: dropped, Document Frequency: 3
# Term: dropping, Document Frequency: 2
# Term: drops, Document Frequency: 1
# Term: drying, Document Frequency: 1
# Term: due, Document Frequency: 8
# Term: dumb, Document Frequency: 1
# Term: dune, Document Frequency: 1
# Term: during, Document Frequency: 12
# Term: dust, Document Frequency: 1
# Term: dvol, Document Frequency: 1
# Term: dxy, Document Frequency: 1
# Term: dynamic, Document Frequency: 3
# Term: dynamics, Document Frequency: 3
# Term: each, Document Frequency: 12
# Term: earlier, Document Frequency: 6
# Term: early, Document Frequency: 6
# Term: earn, Document Frequency: 2
# Term: earned, Document Frequency: 2
# Term: earning, Document Frequency: 2
# Term: earnings, Document Frequency: 5
# Term: earns, Document Frequency: 1
# Term: earth, Document Frequency: 1
# Term: easily, Document Frequency: 1
# Term: easing, Document Frequency: 1
# Term: east, Document Frequency: 1
# Term: easy, Document Frequency: 8
# Term: easygoatfish351, Document Frequency: 1
# Term: eat, Document Frequency: 1
# Term: eaton, Document Frequency: 1
# Term: economic, Document Frequency: 6
# Term: economies, Document Frequency: 2
# Term: economy, Document Frequency: 6
# Term: ecosystem, Document Frequency: 5
# Term: ecosystems, Document Frequency: 1
# Term: eden, Document Frequency: 1
# Term: edged, Document Frequency: 1
# Term: editing, Document Frequency: 2
# Term: edt, Document Frequency: 1
# Term: eea, Document Frequency: 1
# Term: effect, Document Frequency: 3
# Term: effectively, Document Frequency: 2
# Term: effects, Document Frequency: 3
# Term: effort, Document Frequency: 2
# Term: efforts, Document Frequency: 3
# Term: eighth, Document Frequency: 1
# Term: either, Document Frequency: 1
# Term: el, Document Frequency: 1
# Term: election, Document Frequency: 2
# Term: electricity, Document Frequency: 1
# Term: electronic, Document Frequency: 2
# Term: elegance, Document Frequency: 1
# Term: eleven, Document Frequency: 1
# Term: eli, Document Frequency: 1
# Term: eligible, Document Frequency: 1
# Term: elizabeth, Document Frequency: 3
# Term: elliott, Document Frequency: 1
# Term: elon, Document Frequency: 6
# Term: else, Document Frequency: 7
# Term: elsewhere, Document Frequency: 2
# Term: email, Document Frequency: 1
# Term: embraced, Document Frequency: 1
# Term: embracing, Document Frequency: 1
# Term: emi, Document Frequency: 1
# Term: emphasizing, Document Frequency: 1
# Term: empire, Document Frequency: 1
# Term: employee, Document Frequency: 1
# Term: employing, Document Frequency: 1
# Term: employment, Document Frequency: 1
# Term: enable, Document Frequency: 2
# Term: enables, Document Frequency: 1
# Term: enabling, Document Frequency: 1
# Term: encourage, Document Frequency: 1
# Term: encrypted, Document Frequency: 1
# Term: end, Document Frequency: 8
# Term: ended, Document Frequency: 1
# Term: endorses, Document Frequency: 1
# Term: ends, Document Frequency: 1
# Term: energy, Document Frequency: 4
# Term: enforce, Document Frequency: 1
# Term: engage, Document Frequency: 1
# Term: engaged, Document Frequency: 1
# Term: engagement, Document Frequency: 4
# Term: engages, Document Frequency: 1
# Term: engaging, Document Frequency: 1
# Term: engineering, Document Frequency: 1
# Term: enhanced, Document Frequency: 2
# Term: enjoy, Document Frequency: 1
# Term: enormous, Document Frequency: 3
# Term: enough, Document Frequency: 2
# Term: enquiry, Document Frequency: 1
# Term: ensue, Document Frequency: 1
# Term: ensuring, Document Frequency: 1
# Term: enter, Document Frequency: 1
# Term: entering, Document Frequency: 1
# Term: enterprise, Document Frequency: 1
# Term: enterprises, Document Frequency: 1
# Term: enthusiast, Document Frequency: 1
# Term: enticing, Document Frequency: 1
# Term: entire, Document Frequency: 4
# Term: entirely, Document Frequency: 4
# Term: entities, Document Frequency: 6
# Term: entrepreneur, Document Frequency: 1
# Term: entrepreneurs, Document Frequency: 1
# Term: entry, Document Frequency: 1
# Term: environment, Document Frequency: 3
# Term: environmental, Document Frequency: 1
# Term: environments, Document Frequency: 1
# Term: epic, Document Frequency: 1
# Term: equation, Document Frequency: 1
# Term: equipment, Document Frequency: 2
# Term: equities, Document Frequency: 1
# Term: equity, Document Frequency: 4
# Term: equivalent, Document Frequency: 2
# Term: era, Document Frequency: 2
# Term: erman, Document Frequency: 1
# Term: error, Document Frequency: 1
# Term: especially, Document Frequency: 1
# Term: essentially, Document Frequency: 1
# Term: established, Document Frequency: 2
# Term: establishing, Document Frequency: 1
# Term: estate, Document Frequency: 7
# Term: estimate, Document Frequency: 3
# Term: estimated, Document Frequency: 3
# Term: estimates, Document Frequency: 1
# Term: et, Document Frequency: 1
# Term: etch, Document Frequency: 1
# Term: etf, Document Frequency: 13
# Term: etfs, Document Frequency: 17
# Term: eth, Document Frequency: 5
# Term: ether, Document Frequency: 2
# Term: ethereum, Document Frequency: 11
# Term: etn, Document Frequency: 1
# Term: eu, Document Frequency: 3
# Term: euphoria, Document Frequency: 1
# Term: europe, Document Frequency: 1
# Term: european, Document Frequency: 5
# Term: evade, Document Frequency: 1
# Term: evelyn, Document Frequency: 1
# Term: even, Document Frequency: 19
# Term: evening, Document Frequency: 1
# Term: event, Document Frequency: 5
# Term: events, Document Frequency: 6
# Term: eventually, Document Frequency: 2
# Term: ever, Document Frequency: 5
# Term: every, Document Frequency: 11
# Term: everything, Document Frequency: 7
# Term: evidence, Document Frequency: 1
# Term: evident, Document Frequency: 1
# Term: evo, Document Frequency: 1
# Term: evolution, Document Frequency: 1
# Term: evolving, Document Frequency: 1
# Term: ex, Document Frequency: 1
# Term: exactly, Document Frequency: 2
# Term: examination, Document Frequency: 1
# Term: example, Document Frequency: 4
# Term: examples, Document Frequency: 1
# Term: exceeding, Document Frequency: 1
# Term: except, Document Frequency: 1
# Term: exchange, Document Frequency: 19
# Term: exchanges, Document Frequency: 7
# Term: excitement, Document Frequency: 2
# Term: exciting, Document Frequency: 1
# Term: excluding, Document Frequency: 1
# Term: executes, Document Frequency: 1
# Term: executing, Document Frequency: 1
# Term: executive, Document Frequency: 1
# Term: exercising, Document Frequency: 1
# Term: exert, Document Frequency: 1
# Term: exhibit, Document Frequency: 1
# Term: exist, Document Frequency: 2
# Term: existed, Document Frequency: 1
# Term: existing, Document Frequency: 2
# Term: exists, Document Frequency: 1
# Term: exited, Document Frequency: 1
# Term: exodus, Document Frequency: 1
# Term: expand, Document Frequency: 1
# Term: expansion, Document Frequency: 1
# Term: expect, Document Frequency: 4
# Term: expectation, Document Frequency: 2
# Term: expectations, Document Frequency: 5
# Term: expected, Document Frequency: 10
# Term: expenses, Document Frequency: 3
# Term: expensive, Document Frequency: 3
# ...
# Term: technologies, Document Frequency: 2
# Term: technologists, Document Frequency: 2
# Term: technology, Document Frequency: 7
# Term: telecom, Document Frequency: 1
# Term: television, Document Frequency: 1
# Term: tell, Document Frequency: 1
# Term: tells, Document Frequency: 1
# Term: tempered, Document Frequency: 1
# Term: templeton, Document Frequency: 1
# Term: temporary, Document Frequency: 1
# Term: tend, Document Frequency: 2
# Term: tender, Document Frequency: 1
# Term: tends, Document Frequency: 1
# Term: tens, Document Frequency: 1
# Term: tensions, Document Frequency: 1
# Term: tensor, Document Frequency: 1
# Term: tentative, Document Frequency: 2
# Term: tepid, Document Frequency: 1
# Term: terawatt, Document Frequency: 1
# Term: term, Document Frequency: 12
# Term: terms, Document Frequency: 3
# Term: terrorist, Document Frequency: 2
# Term: tesla, Document Frequency: 5
# Term: test, Document Frequency: 3
# Term: testifies, Document Frequency: 1
# Term: testing, Document Frequency: 1
# Term: tether, Document Frequency: 3
# Term: texas, Document Frequency: 1
# Term: texts, Document Frequency: 1
# Term: than, Document Frequency: 24
# Term: thank, Document Frequency: 1
# Term: thanked, Document Frequency: 1
# Term: that, Document Frequency: 35
# Term: the, Document Frequency: 38
# Term: thefts, Document Frequency: 1
# Term: their, Document Frequency: 14
# Term: them, Document Frequency: 16
# Term: themed, Document Frequency: 1
# Term: themselves, Document Frequency: 1
# Term: then, Document Frequency: 9
# Term: theory, Document Frequency: 3
# Term: there, Document Frequency: 14
# Term: thereby, Document Frequency: 2
# Term: therefore, Document Frequency: 2
# Term: these, Document Frequency: 19
# Term: they, Document Frequency: 21
# Term: things, Document Frequency: 2
# Term: think, Document Frequency: 8
# Term: thinking, Document Frequency: 2
# Term: thinks, Document Frequency: 2
# Term: third, Document Frequency: 2
# Term: this, Document Frequency: 34
# Term: thompson, Document Frequency: 1
# Term: thorn, Document Frequency: 1
# Term: those, Document Frequency: 9
# Term: though, Document Frequency: 10
# Term: thousand, Document Frequency: 3
# Term: threat, Document Frequency: 1
# Term: three, Document Frequency: 10
# Term: threshold, Document Frequency: 1
# Term: thrive, Document Frequency: 1
# Term: thriving, Document Frequency: 1
# Term: through, Document Frequency: 12
# Term: throw, Document Frequency: 1
# Term: thursday, Document Frequency: 4
# Term: thus, Document Frequency: 3
# Term: tiaa, Document Frequency: 1
# Term: tight, Document Frequency: 2
# Term: tightening, Document Frequency: 2
# Term: tiktok, Document Frequency: 1
# Term: till, Document Frequency: 1
# Term: time, Document Frequency: 19
# Term: timeline, Document Frequency: 1
# Term: times, Document Frequency: 3
# Term: tiny, Document Frequency: 1
# Term: tip, Document Frequency: 1
# Term: titled, Document Frequency: 1
# Term: to, Document Frequency: 38
# Term: today, Document Frequency: 14
# Term: together, Document Frequency: 2
# Term: token, Document Frequency: 8
# Term: tokenized, Document Frequency: 2
# Term: tokenomics, Document Frequency: 1
# Term: tokens, Document Frequency: 9
# Term: told, Document Frequency: 3
# Term: tolerance, Document Frequency: 1
# Term: tonkin, Document Frequency: 1
# Term: too, Document Frequency: 2
# Term: took, Document Frequency: 3
# Term: tool, Document Frequency: 7
# Term: tools, Document Frequency: 1
# Term: top, Document Frequency: 8
# Term: topic, Document Frequency: 1
# Term: torn, Document Frequency: 1
# Term: tornado, Document Frequency: 2
# Term: torres, Document Frequency: 1
# Term: total, Document Frequency: 8
# Term: totaled, Document Frequency: 1
# Term: touch, Document Frequency: 1
# Term: toward, Document Frequency: 1
# Term: track, Document Frequency: 1
# Term: tracked, Document Frequency: 1
# Term: tracking, Document Frequency: 1
# Term: tracks, Document Frequency: 2
# Term: trade, Document Frequency: 5
# Term: traded, Document Frequency: 12
# Term: trader, Document Frequency: 2
# Term: traders, Document Frequency: 5
# Term: trades, Document Frequency: 5
# Term: tradfi, Document Frequency: 1
# Term: trading, Document Frequency: 18
# Term: tradingview, Document Frequency: 2
# Term: traditional, Document Frequency: 9
# Term: trail, Document Frequency: 1
# Term: traits, Document Frequency: 1
# Term: trajectory, Document Frequency: 2
# Term: trane, Document Frequency: 1
# Term: transaction, Document Frequency: 5
# Term: transactions, Document Frequency: 11
# Term: transfer, Document Frequency: 2
# Term: transfers, Document Frequency: 1
# Term: transform, Document Frequency: 1
# Term: transformation, Document Frequency: 1
# Term: transition, Document Frequency: 1
# Term: translates, Document Frequency: 1
# Term: transparency, Document Frequency: 1
# Term: travel, Document Frequency: 2
# Term: travis, Document Frequency: 2
# Term: treading, Document Frequency: 1
# Term: treasuries, Document Frequency: 1
# Term: treasury, Document Frequency: 5
# Term: treating, Document Frequency: 1
# Term: tremendous, Document Frequency: 1
# Term: trend, Document Frequency: 7
# Term: trending, Document Frequency: 5
# Term: trezor, Document Frequency: 1
# Term: trial, Document Frequency: 6
# Term: tricking, Document Frequency: 1
# Term: tried, Document Frequency: 1
# Term: trillion, Document Frequency: 7
# Term: true, Document Frequency: 2
# Term: truly, Document Frequency: 1
# Term: trump, Document Frequency: 2
# Term: trust, Document Frequency: 2
# Term: trying, Document Frequency: 2
# Term: tsla, Document Frequency: 4
# Term: tt, Document Frequency: 1
# Term: tuesday, Document Frequency: 2
# Term: tumble, Document Frequency: 1
# Term: tumbled, Document Frequency: 2
# Term: tumbles, Document Frequency: 1
# Term: tune, Document Frequency: 1
# Term: turbulence, Document Frequency: 1
# Term: turmoil, Document Frequency: 1
# Term: turn, Document Frequency: 3
# Term: turnaround, Document Frequency: 1
# Term: turned, Document Frequency: 2
# Term: tv, Document Frequency: 1
# Term: tweeted, Document Frequency: 5
# Term: twitter, Document Frequency: 2
# Term: two, Document Frequency: 17
# Term: type, Document Frequency: 1
# Term: types, Document Frequency: 1
# Term: typical, Document Frequency: 1
# Term: typically, Document Frequency: 2
# Term: tysons, Document Frequency: 1
# Term: uk, Document Frequency: 1
# Term: ultimately, Document Frequency: 4
# Term: unauthorised, Document Frequency: 1
# Term: unbelievable, Document Frequency: 1
# Term: uncertain, Document Frequency: 1
# Term: uncertainty, Document Frequency: 3
# Term: unclear, Document Frequency: 1
# Term: uncommon, Document Frequency: 1
# Term: uncovered, Document Frequency: 1
# Term: under, Document Frequency: 4
# Term: underlying, Document Frequency: 4
# Term: undermine, Document Frequency: 1
# Term: underperformed, Document Frequency: 1
# Term: underperforming, Document Frequency: 1
# Term: underpins, Document Frequency: 1
# Term: understand, Document Frequency: 2
# Term: understandable, Document Frequency: 1
# Term: understands, Document Frequency: 1
# Term: undervalued, Document Frequency: 1
# Term: underway, Document Frequency: 1
# Term: undoubtedly, Document Frequency: 1
# Term: unexpectedly, Document Frequency: 1
# Term: unfairly, Document Frequency: 1
# Term: unfamiliar, Document Frequency: 1
# Term: unfiltered, Document Frequency: 1
# Term: unfortunate, Document Frequency: 1
# Term: unfortunately, Document Frequency: 1
# Term: unheard, Document Frequency: 1
# Term: uni, Document Frequency: 1
# Term: union, Document Frequency: 2
# Term: unions, Document Frequency: 2
# Term: unique, Document Frequency: 3
# Term: uniquely, Document Frequency: 1
# Term: uniswap, Document Frequency: 1
# Term: unit, Document Frequency: 1
# Term: united, Document Frequency: 5
# Term: units, Document Frequency: 3
# Term: unless, Document Frequency: 1
# Term: unlike, Document Frequency: 4
# Term: unlikely, Document Frequency: 2
# Term: unlimited, Document Frequency: 1
# Term: unlocked, Document Frequency: 1
# Term: unm, Document Frequency: 1
# Term: unnamed, Document Frequency: 1
# Term: unparalleled, Document Frequency: 1
# Term: unprecedented, Document Frequency: 3
# Term: unprofitable, Document Frequency: 1
# Term: unregistered, Document Frequency: 1
# Term: unregulated, Document Frequency: 1
# Term: unsc, Document Frequency: 1
# Term: unseat, Document Frequency: 1
# Term: until, Document Frequency: 2
# Term: untouched, Document Frequency: 1
# Term: unum, Document Frequency: 1
# Term: up, Document Frequency: 23
# Term: update, Document Frequency: 2
# Term: updated, Document Frequency: 1
# Term: updates, Document Frequency: 8
# Term: upfront, Document Frequency: 1
# Term: upgrades, Document Frequency: 1
# Term: ups, Document Frequency: 1
# Term: upside, Document Frequency: 3
# Term: upstart, Document Frequency: 1
# Term: uptick, Document Frequency: 1
# Term: upward, Document Frequency: 2
# Term: urban, Document Frequency: 1
# Term: us, Document Frequency: 11
# Term: usage, Document Frequency: 1
# Term: usd, Document Frequency: 4
# Term: usdc, Document Frequency: 1
# Term: usdo, Document Frequency: 1
# Term: usdt, Document Frequency: 1
# Term: use, Document Frequency: 8
# Term: used, Document Frequency: 8
# Term: useful, Document Frequency: 1
# Term: usernames, Document Frequency: 1
# Term: users, Document Frequency: 5
# Term: uses, Document Frequency: 3
# Term: using, Document Frequency: 4
# Term: usual, Document Frequency: 1
# Term: usually, Document Frequency: 1
# Term: utc, Document Frequency: 1
# Term: utilities, Document Frequency: 1
# Term: utility, Document Frequency: 4
# Term: utilizing, Document Frequency: 1
# Term: uup, Document Frequency: 1
# Term: uyeda, Document Frequency: 1
# Term: validate, Document Frequency: 1
# Term: validates, Document Frequency: 1
# Term: validating, Document Frequency: 1
# Term: validation, Document Frequency: 1
# Term: valuable, Document Frequency: 1
# Term: valuation, Document Frequency: 1
# Term: value, Document Frequency: 16
# Term: values, Document Frequency: 3
# Term: valuing, Document Frequency: 1
# Term: vaneck, Document Frequency: 1
# Term: vaporware, Document Frequency: 1
# Term: varied, Document Frequency: 1
# Term: variety, Document Frequency: 1
# Term: various, Document Frequency: 7
# Term: vasps, Document Frequency: 1
# Term: vast, Document Frequency: 2
# Term: ve, Document Frequency: 3
# Term: vehicle, Document Frequency: 1
# Term: venezuela, Document Frequency: 1
# Term: venture, Document Frequency: 4
# Term: ventures, Document Frequency: 2
# Term: verdict, Document Frequency: 1
# Term: verify, Document Frequency: 1
# Term: verizon, Document Frequency: 1
# Term: versus, Document Frequency: 1
# Term: very, Document Frequency: 6
# Term: vestberg, Document Frequency: 1
# Term: vetle, Document Frequency: 1
# Term: via, Document Frequency: 1
# Term: viability, Document Frequency: 1
# Term: viable, Document Frequency: 1
# Term: viabtc, Document Frequency: 1
# Term: vibes, Document Frequency: 1
# Term: view, Document Frequency: 38
# Term: viewable, Document Frequency: 2
# Term: viewed, Document Frequency: 1
# Term: views, Document Frequency: 1
# Term: violating, Document Frequency: 2
# Term: virgin, Document Frequency: 1
# Term: virginia, Document Frequency: 1
# Term: virtual, Document Frequency: 6
# Term: virtually, Document Frequency: 1
# Term: vision, Document Frequency: 3
# Term: visit, Document Frequency: 1
# Term: vitanza, Document Frequency: 1
# Term: voice, Document Frequency: 1
# Term: voiced, Document Frequency: 1
# Term: voices, Document Frequency: 1
# Term: volatile, Document Frequency: 6
# Term: volatility, Document Frequency: 10
# Term: volcano, Document Frequency: 1
# Term: volume, Document Frequency: 3
# Term: volumes, Document Frequency: 1
# Term: von, Document Frequency: 1
# Term: vote, Document Frequency: 2
# Term: voted, Document Frequency: 2
# Term: vulnerability, Document Frequency: 1
# Term: vz, Document Frequency: 1
# Term: wage, Document Frequency: 1
# Term: waitlisters, Document Frequency: 1
# Term: wake, Document Frequency: 1
# Term: wall, Document Frequency: 4
# Term: walled, Document Frequency: 1
# Term: wallet, Document Frequency: 8
# Term: wallets, Document Frequency: 3
# Term: waning, Document Frequency: 1
# Term: want, Document Frequency: 6
# Term: warner, Document Frequency: 1
# Term: warns, Document Frequency: 1
# Term: warranty, Document Frequency: 1
# Term: warren, Document Frequency: 2
# Term: was, Document Frequency: 19
# Term: wasabi, Document Frequency: 1
# Term: washington, Document Frequency: 1
# Term: wasn, Document Frequency: 8
# Term: watch, Document Frequency: 2
# Term: watchers, Document Frequency: 3
# Term: water, Document Frequency: 1
# Term: watershed, Document Frequency: 1
# Term: wave, Document Frequency: 1
# Term: way, Document Frequency: 8
# Term: ways, Document Frequency: 3
# Term: wbd, Document Frequency: 1
# Term: we, Document Frequency: 17
# Term: weak, Document Frequency: 1
# Term: weakened, Document Frequency: 2
# Term: weakening, Document Frequency: 1
# Term: weaker, Document Frequency: 2
# Term: weakest, Document Frequency: 1
# Term: weakness, Document Frequency: 1
# Term: wealth, Document Frequency: 3
# Term: weapon, Document Frequency: 6
# Term: weapons, Document Frequency: 2
# Term: wear, Document Frequency: 1
# Term: weather, Document Frequency: 1
# Term: web, Document Frequency: 1
# Term: web3, Document Frequency: 2
# Term: website, Document Frequency: 2
# Term: wednesday, Document Frequency: 1
# Term: week, Document Frequency: 8
# Term: weekend, Document Frequency: 1
# Term: weeks, Document Frequency: 6
# Term: weighting, Document Frequency: 1
# Term: welcomed, Document Frequency: 1
# Term: well, Document Frequency: 10
# Term: went, Document Frequency: 2
# Term: were, Document Frequency: 14
# Term: western, Document Frequency: 1
# Term: weth, Document Frequency: 1
# Term: whales, Document Frequency: 1
# Term: what, Document Frequency: 18
# Term: when, Document Frequency: 18
# Term: where, Document Frequency: 7
# Term: whether, Document Frequency: 8
# Term: which, Document Frequency: 23
# Term: while, Document Frequency: 22
# Term: whilst, Document Frequency: 1
# Term: who, Document Frequency: 7
# Term: whose, Document Frequency: 1
# Term: why, Document Frequency: 10
# Term: wide, Document Frequency: 1
# Term: widely, Document Frequency: 4
# Term: wider, Document Frequency: 1
# Term: widespread, Document Frequency: 1
# Term: wif, Document Frequency: 1
# Term: wild, Document Frequency: 1
# Term: wildly, Document Frequency: 1
# Term: will, Document Frequency: 24
# Term: windows, Document Frequency: 1
# Term: winning, Document Frequency: 1
# Term: wins, Document Frequency: 2
# Term: wisdom, Document Frequency: 1
# Term: wise, Document Frequency: 3
# Term: wishing, Document Frequency: 1
# Term: with, Document Frequency: 36
# Term: within, Document Frequency: 2
# Term: without, Document Frequency: 4
# Term: woburn, Document Frequency: 1
# Term: woes, Document Frequency: 1
# Term: won, Document Frequency: 6
# Term: wonder, Document Frequency: 1
# Term: wood, Document Frequency: 3
# Term: words, Document Frequency: 3
# Term: work, Document Frequency: 2
# Term: worked, Document Frequency: 1
# Term: worker, Document Frequency: 1
# Term: working, Document Frequency: 3
# Term: works, Document Frequency: 2
# Term: world, Document Frequency: 9
# Term: worldwide, Document Frequency: 1
# Term: worrying, Document Frequency: 1
# Term: worst, Document Frequency: 2
# Term: worth, Document Frequency: 9
# Term: worthless, Document Frequency: 1
# Term: would, Document Frequency: 17
# Term: wouldn, Document Frequency: 1
# Term: wrap, Document Frequency: 1
# Term: wrapped, Document Frequency: 1
# Term: write, Document Frequency: 1
# Term: writing, Document Frequency: 5
# Term: writte, Document Frequency: 1
# Term: wrote, Document Frequency: 2
# Term: wünscher, Document Frequency: 1
# Term: xle, Document Frequency: 1
# Term: xlu, Document Frequency: 1
# Term: xrp, Document Frequency: 1
# Term: yahoo, Document Frequency: 1
# Term: year, Document Frequency: 23
# Term: years, Document Frequency: 20
# Term: yellen, Document Frequency: 2
# Term: yen, Document Frequency: 2
# Term: yesterday, Document Frequency: 1
# Term: yet, Document Frequency: 4
# Term: yield, Document Frequency: 3
# Term: yields, Document Frequency: 3
# Term: york, Document Frequency: 4
# Term: you, Document Frequency: 21
# Term: younger, Document Frequency: 2
# Term: your, Document Frequency: 11
# Term: zach, Document Frequency: 1
# Term: zachxbt, Document Frequency: 1
# Term: zacks, Document Frequency: 2
# Term: zero, Document Frequency: 3
# Term: zhao, Document Frequency: 1
# Term: zooming, Document Frequency: 1

# %%
analysis.print_tf_Idf()
# Out:
# Term: 00, TF-IDF: 0.0
# Term: 000, TF-IDF: 0.013850914949399547
# Term: 000th, TF-IDF: 0.0
# Term: 000x, TF-IDF: 0.0
# Term: 01, TF-IDF: 0.0
# Term: 02, TF-IDF: 0.0
# Term: 03, TF-IDF: 0.0
# Term: 06, TF-IDF: 0.0
# Term: 07, TF-IDF: 0.0
# Term: 070, TF-IDF: 0.0
# Term: 075, TF-IDF: 0.0
# Term: 08, TF-IDF: 0.0
# Term: 10, TF-IDF: 0.0
# Term: 100, TF-IDF: 0.01887653286292354
# Term: 100x, TF-IDF: 0.0
# Term: 103, TF-IDF: 0.0
# Term: 104, TF-IDF: 0.0
# Term: 105, TF-IDF: 0.0
# Term: 107, TF-IDF: 0.0
# Term: 10x, TF-IDF: 0.0
# Term: 11, TF-IDF: 0.0
# Term: 110, TF-IDF: 0.0
# Term: 115, TF-IDF: 0.0
# Term: 12, TF-IDF: 0.0
# Term: 122, TF-IDF: 0.0
# Term: 125, TF-IDF: 0.0
# Term: 13, TF-IDF: 0.0
# Term: 13bn, TF-IDF: 0.0
# Term: 14, TF-IDF: 0.0
# Term: 141, TF-IDF: 0.0
# Term: 147, TF-IDF: 0.0
# Term: 15, TF-IDF: 0.0
# Term: 150, TF-IDF: 0.0
# Term: 16, TF-IDF: 0.0
# Term: 160, TF-IDF: 0.0
# Term: 164, TF-IDF: 0.0
# Term: 17, TF-IDF: 0.025339455873732354
# Term: 170, TF-IDF: 0.0
# Term: 176, TF-IDF: 0.0
# Term: 18, TF-IDF: 0.0
# Term: 182, TF-IDF: 0.0
# Term: 19, TF-IDF: 0.0
# Term: 190, TF-IDF: 0.0
# Term: 1930, TF-IDF: 0.0
# Term: 1946, TF-IDF: 0.0
# Term: 195, TF-IDF: 0.0
# Term: 196, TF-IDF: 0.0
# Term: 1990, TF-IDF: 0.0
# Term: 1m, TF-IDF: 0.0
# Term: 20, TF-IDF: 0.0
# Term: 200, TF-IDF: 0.0
# Term: 2000, TF-IDF: 0.03323968398182599
# Term: 2002, TF-IDF: 0.0
# Term: 2005, TF-IDF: 0.0
# Term: 2008, TF-IDF: 0.0
# Term: 2009, TF-IDF: 0.0
# Term: 2011, TF-IDF: 0.0
# Term: 2013, TF-IDF: 0.0
# Term: 2014, TF-IDF: 0.0
# Term: 2018, TF-IDF: 0.0
# Term: 2019, TF-IDF: 0.0
# Term: 2020, TF-IDF: 0.0
# Term: 2021, TF-IDF: 0.0
# Term: 2022, TF-IDF: 0.0
# Term: 2023, TF-IDF: 0.022013809074306008
# Term: 2024, TF-IDF: 0.013470289571223822
# Term: 2025, TF-IDF: 0.0
# Term: 2028, TF-IDF: 0.0
# Term: 2030, TF-IDF: 0.0
# Term: 21, TF-IDF: 0.0
# Term: 210, TF-IDF: 0.0
# Term: 214, TF-IDF: 0.0
# Term: 2140, TF-IDF: 0.0
# Term: 217, TF-IDF: 0.0
# Term: 21shares, TF-IDF: 0.0
# Term: 22, TF-IDF: 0.0
# Term: 23, TF-IDF: 0.0
# Term: 237, TF-IDF: 0.0
# Term: 23m, TF-IDF: 0.0
# Term: 24, TF-IDF: 0.0
# Term: 244, TF-IDF: 0.0
# Term: 25, TF-IDF: 0.022996193364646148
# Term: 250, TF-IDF: 0.0
# Term: 26, TF-IDF: 0.0
# Term: 27, TF-IDF: 0.0
# Term: 28, TF-IDF: 0.0
# Term: 280, TF-IDF: 0.0
# Term: 29, TF-IDF: 0.0
# Term: 291, TF-IDF: 0.0
# Term: 30, TF-IDF: 0.0
# Term: 300, TF-IDF: 0.0
# Term: 305, TF-IDF: 0.0
# Term: 31, TF-IDF: 0.0
# Term: 33, TF-IDF: 0.0
# Term: 332, TF-IDF: 0.0
# Term: 34, TF-IDF: 0.0
# Term: 345, TF-IDF: 0.0
# Term: 350, TF-IDF: 0.0
# Term: 355, TF-IDF: 0.0
# Term: 36, TF-IDF: 0.0
# Term: 366m, TF-IDF: 0.0
# Term: 36bn, TF-IDF: 0.0
# Term: 37, TF-IDF: 0.0
# Term: 370, TF-IDF: 0.037020251588197016
# Term: 379, TF-IDF: 0.0
# Term: 38, TF-IDF: 0.0
# Term: 380m, TF-IDF: 0.0
# Term: 38m, TF-IDF: 0.0
# Term: 39, TF-IDF: 0.0
# Term: 390, TF-IDF: 0.0
# Term: 399, TF-IDF: 0.0
# Term: 3m, TF-IDF: 0.0
# Term: 40, TF-IDF: 0.0
# Term: 400, TF-IDF: 0.030557328577388205
# Term: 401, TF-IDF: 0.0
# Term: 41, TF-IDF: 0.0
# Term: 422, TF-IDF: 0.0
# Term: 428, TF-IDF: 0.0
# Term: 44, TF-IDF: 0.0
# Term: 45, TF-IDF: 0.0
# Term: 450, TF-IDF: 0.0
# Term: 450m, TF-IDF: 0.0
# Term: 46, TF-IDF: 0.0
# Term: 461, TF-IDF: 0.0
# Term: 480, TF-IDF: 0.0
# Term: 49, TF-IDF: 0.0
# Term: 50, TF-IDF: 0.0
# Term: 500, TF-IDF: 0.01887653286292354
# Term: 505, TF-IDF: 0.0
# Term: 506, TF-IDF: 0.0
# Term: 518, TF-IDF: 0.0
# Term: 53, TF-IDF: 0.0
# Term: 537, TF-IDF: 0.0
# Term: 55, TF-IDF: 0.0
# Term: 553, TF-IDF: 0.0
# Term: 557, TF-IDF: 0.0
# Term: 559, TF-IDF: 0.0
# Term: 56, TF-IDF: 0.0
# Term: 567, TF-IDF: 0.0
# Term: 575, TF-IDF: 0.0
# Term: 580, TF-IDF: 0.030557328577388205
# Term: 588, TF-IDF: 0.0
# Term: 59, TF-IDF: 0.0
# Term: 5g, TF-IDF: 0.037020251588197016
# Term: 60, TF-IDF: 0.0
# Term: 600, TF-IDF: 0.0
# Term: 600bn, TF-IDF: 0.0
# Term: 61, TF-IDF: 0.0
# Term: 62, TF-IDF: 0.0
# Term: 63, TF-IDF: 0.0
# Term: 64, TF-IDF: 0.0
# Term: 644, TF-IDF: 0.0
# Term: 64k, TF-IDF: 0.0
# Term: 65, TF-IDF: 0.0
# Term: 66, TF-IDF: 0.0
# Term: 68, TF-IDF: 0.0
# Term: 685, TF-IDF: 0.0
# Term: 69, TF-IDF: 0.03323968398182599
# Term: 692, TF-IDF: 0.0
# Term: 6bn, TF-IDF: 0.0
# Term: 6th, TF-IDF: 0.0
# Term: 70, TF-IDF: 0.0
# Term: 700, TF-IDF: 0.0
# Term: 701, TF-IDF: 0.0
# Term: 71, TF-IDF: 0.0
# Term: 72, TF-IDF: 0.0
# Term: 73, TF-IDF: 0.0
# Term: 74, TF-IDF: 0.0
# Term: 75, TF-IDF: 0.0
# Term: 750, TF-IDF: 0.0
# Term: 76, TF-IDF: 0.0
# Term: 765, TF-IDF: 0.0
# Term: 78, TF-IDF: 0.0
# Term: 79, TF-IDF: 0.0
# Term: 790, TF-IDF: 0.0
# Term: 7936, TF-IDF: 0.0
# Term: 80, TF-IDF: 0.0
# Term: 800, TF-IDF: 0.0
# Term: 82, TF-IDF: 0.0
# Term: 84, TF-IDF: 0.0
# Term: 85, TF-IDF: 0.0
# Term: 850, TF-IDF: 0.0
# Term: 875, TF-IDF: 0.0
# Term: 89, TF-IDF: 0.0
# Term: 90, TF-IDF: 0.0
# Term: 900, TF-IDF: 0.0
# Term: 923, TF-IDF: 0.0
# Term: 93, TF-IDF: 0.037020251588197016
# Term: 94, TF-IDF: 0.0
# Term: 95, TF-IDF: 0.0
# Term: 97, TF-IDF: 0.0
# Term: 982, TF-IDF: 0.0
# Term: 983, TF-IDF: 0.0
# Term: 99, TF-IDF: 0.0
# Term: 990, TF-IDF: 0.0
# Term: 992, TF-IDF: 0.0
# Term: aapl, TF-IDF: 0.0
# Term: abandoned, TF-IDF: 0.0
# Term: ability, TF-IDF: 0.0
# Term: able, TF-IDF: 0.0
# Term: about, TF-IDF: 0.015550886063497199
# Term: above, TF-IDF: 0.0
# Term: academics, TF-IDF: 0.0
# Term: accelerating, TF-IDF: 0.0
# Term: accept, TF-IDF: 0.0
# Term: acceptable, TF-IDF: 0.0
# Term: acceptance, TF-IDF: 0.0
# Term: accepted, TF-IDF: 0.0
# Term: access, TF-IDF: 0.0
# Term: accessibility, TF-IDF: 0.0
# Term: accomplish, TF-IDF: 0.0
# Term: according, TF-IDF: 0.0
# Term: account, TF-IDF: 0.0
# Term: accountably, TF-IDF: 0.0
# Term: accounted, TF-IDF: 0.0
# Term: accounting, TF-IDF: 0.0
# Term: accounts, TF-IDF: 0.0
# Term: accumulate, TF-IDF: 0.0
# Term: accumulating, TF-IDF: 0.0
# Term: accuracy, TF-IDF: 0.0
# Term: acgl, TF-IDF: 0.0
# Term: acheson, TF-IDF: 0.0
# Term: acpr, TF-IDF: 0.0
# Term: acquire, TF-IDF: 0.0
# Term: acquired, TF-IDF: 0.0
# Term: acquisition, TF-IDF: 0.0
# Term: across, TF-IDF: 0.0
# Term: act, TF-IDF: 0.0
# Term: acted, TF-IDF: 0.0
# Term: action, TF-IDF: 0.0
# Term: actions, TF-IDF: 0.0
# Term: active, TF-IDF: 0.0
# Term: actively, TF-IDF: 0.0
# Term: activities, TF-IDF: 0.0
# Term: activity, TF-IDF: 0.0
# Term: actual, TF-IDF: 0.0
# Term: actually, TF-IDF: 0.0
# Term: add, TF-IDF: 0.026776760971017177
# Term: added, TF-IDF: 0.0
# Term: adding, TF-IDF: 0.0
# Term: addition, TF-IDF: 0.0
# Term: additional, TF-IDF: 0.0
# Term: additionally, TF-IDF: 0.0
# Term: address, TF-IDF: 0.0
# Term: addresses, TF-IDF: 0.0
# Term: adds, TF-IDF: 0.0
# Term: adjunct, TF-IDF: 0.0
# Term: administration, TF-IDF: 0.0
# Term: adopt, TF-IDF: 0.0
# Term: adopted, TF-IDF: 0.0
# Term: adopting, TF-IDF: 0.0
# Term: adoption, TF-IDF: 0.0
# Term: adult, TF-IDF: 0.0
# Term: advance, TF-IDF: 0.0
# Term: advanced, TF-IDF: 0.0
# Term: advancing, TF-IDF: 0.0
# Term: advantages, TF-IDF: 0.0
# Term: advertised, TF-IDF: 0.0
# Term: advice, TF-IDF: 0.0
# Term: advisor, TF-IDF: 0.0
# Term: advocate, TF-IDF: 0.0
# Term: affairs, TF-IDF: 0.0
# Term: affect, TF-IDF: 0.0
# Term: affected, TF-IDF: 0.0
# Term: affiliated, TF-IDF: 0.0
# Term: afloat, TF-IDF: 0.0
# Term: africa, TF-IDF: 0.0
# Term: after, TF-IDF: 0.0
# Term: afternoon, TF-IDF: 0.0
# Term: again, TF-IDF: 0.0
# Term: against, TF-IDF: 0.0
# Term: age, TF-IDF: 0.0
# Term: agency, TF-IDF: 0.0
# Term: agent, TF-IDF: 0.0
# Term: agents, TF-IDF: 0.0
# Term: aggregates, TF-IDF: 0.0
# Term: ago, TF-IDF: 0.0
# Term: ahead, TF-IDF: 0.0
# Term: ai, TF-IDF: 0.0
# Term: aid, TF-IDF: 0.0
# Term: aided, TF-IDF: 0.0
# Term: aim, TF-IDF: 0.0
# Term: aimed, TF-IDF: 0.0
# Term: aiming, TF-IDF: 0.0
# Term: algorithm, TF-IDF: 0.0
# Term: aligns, TF-IDF: 0.0
# Term: all, TF-IDF: 0.0
# Term: allegations, TF-IDF: 0.0
# Term: allegedly, TF-IDF: 0.0
# Term: alleges, TF-IDF: 0.0
# Term: allocating, TF-IDF: 0.0
# Term: allocation, TF-IDF: 0.0
# Term: allocations, TF-IDF: 0.0
# Term: allow, TF-IDF: 0.0
# Term: allowed, TF-IDF: 0.0
# Term: allowing, TF-IDF: 0.0
# Term: allows, TF-IDF: 0.030557328577388205
# Term: ally, TF-IDF: 0.0
# Term: almost, TF-IDF: 0.0
# Term: alone, TF-IDF: 0.030557328577388205
# Term: along, TF-IDF: 0.0
# Term: alps, TF-IDF: 0.07404050317639403
# Term: already, TF-IDF: 0.022996193364646148
# Term: also, TF-IDF: 0.0
# Term: altcoins, TF-IDF: 0.0
# Term: alternative, TF-IDF: 0.0
# Term: alternatives, TF-IDF: 0.0
# Term: alters, TF-IDF: 0.0
# Term: although, TF-IDF: 0.0
# Term: altogether, TF-IDF: 0.0
# Term: alts, TF-IDF: 0.0
# Term: always, TF-IDF: 0.0
# Term: amass, TF-IDF: 0.0
# Term: amazon, TF-IDF: 0.03323968398182599
# Term: amd, TF-IDF: 0.0
# Term: america, TF-IDF: 0.0
# Term: americas, TF-IDF: 0.0
# Term: amf, TF-IDF: 0.0
# Term: amicus, TF-IDF: 0.0
# Term: amid, TF-IDF: 0.0
# Term: among, TF-IDF: 0.0
# Term: amount, TF-IDF: 0.0
# Term: amounts, TF-IDF: 0.0
# Term: amzn, TF-IDF: 0.0
# Term: an, TF-IDF: 0.036259252318571834
# Term: analysing, TF-IDF: 0.0
# Term: analysis, TF-IDF: 0.0
# Term: analyst, TF-IDF: 0.0
# Term: analysts, TF-IDF: 0.0
# Term: analytics, TF-IDF: 0.0
# Term: analyzing, TF-IDF: 0.0
# Term: anarchist, TF-IDF: 0.0
# Term: and, TF-IDF: 0.19132446226629204
# Term: andvaneck, TF-IDF: 0.0
# Term: animal, TF-IDF: 0.0
# Term: announced, TF-IDF: 0.0
# Term: announcement, TF-IDF: 0.0
# Term: annualized, TF-IDF: 0.0
# Term: anonymity, TF-IDF: 0.0
# Term: anonymous, TF-IDF: 0.0
# Term: another, TF-IDF: 0.02112513438659526
# Term: answer, TF-IDF: 0.0
# Term: anthony, TF-IDF: 0.0
# Term: anti, TF-IDF: 0.0
# Term: anticipated, TF-IDF: 0.0
# Term: anticipation, TF-IDF: 0.0
# Term: any, TF-IDF: 0.01887653286292354
# Term: anyone, TF-IDF: 0.0
# Term: anything, TF-IDF: 0.0
# Term: anytime, TF-IDF: 0.0
# Term: app, TF-IDF: 0.0
# Term: apparent, TF-IDF: 0.0
# Term: appeal, TF-IDF: 0.0
# Term: appealing, TF-IDF: 0.0
# Term: appeals, TF-IDF: 0.0
# Term: appear, TF-IDF: 0.0
# Term: appeared, TF-IDF: 0.022013809074306008
# Term: appears, TF-IDF: 0.0
# Term: appellate, TF-IDF: 0.0
# Term: appetite, TF-IDF: 0.0
# Term: apple, TF-IDF: 0.0
# Term: application, TF-IDF: 0.0
# Term: applications, TF-IDF: 0.0
# Term: applied, TF-IDF: 0.0
# Term: apply, TF-IDF: 0.0
# Term: applying, TF-IDF: 0.0
# Term: appointed, TF-IDF: 0.0
# Term: appointment, TF-IDF: 0.0
# Term: appreciate, TF-IDF: 0.0
# Term: appreciated, TF-IDF: 0.0
# Term: appreciation, TF-IDF: 0.026776760971017177
# Term: apprehension, TF-IDF: 0.0
# Term: approach, TF-IDF: 0.03323968398182599
# Term: approval, TF-IDF: 0.0
# Term: approvals, TF-IDF: 0.0
# Term: approved, TF-IDF: 0.0
# Term: approving, TF-IDF: 0.0
# Term: approximately, TF-IDF: 0.0
# Term: apr, TF-IDF: 0.0
# Term: april, TF-IDF: 0.0
# Term: apy, TF-IDF: 0.037020251588197016
# Term: arca, TF-IDF: 0.0
# Term: arch, TF-IDF: 0.0
# Term: architecture, TF-IDF: 0.0
# Term: ardoino, TF-IDF: 0.0
# Term: are, TF-IDF: 0.03531095537137851
# Term: aren, TF-IDF: 0.0
# Term: arguably, TF-IDF: 0.0
# Term: argued, TF-IDF: 0.0
# Term: argues, TF-IDF: 0.0
# Term: arguing, TF-IDF: 0.0
# Term: argument, TF-IDF: 0.0
# Term: arise, TF-IDF: 0.0
# Term: ark, TF-IDF: 0.0
# Term: arkb, TF-IDF: 0.0
# Term: arkham, TF-IDF: 0.0
# Term: arkw, TF-IDF: 0.0
# Term: arm, TF-IDF: 0.0
# Term: arms, TF-IDF: 0.0
# Term: around, TF-IDF: 0.0
# Term: arrests, TF-IDF: 0.0
# Term: arrival, TF-IDF: 0.0
# Term: arrive, TF-IDF: 0.0
# Term: arrived, TF-IDF: 0.07404050317639403
# Term: article, TF-IDF: 0.029324422751572897
# Term: artificial, TF-IDF: 0.0
# Term: as, TF-IDF: 0.04133205343936541
# Term: asap, TF-IDF: 0.0
# Term: asia, TF-IDF: 0.0
# Term: asian, TF-IDF: 0.0
# Term: asic, TF-IDF: 0.0
# Term: asics, TF-IDF: 0.0
# Term: aside, TF-IDF: 0.0
# Term: asked, TF-IDF: 0.0
# Term: asking, TF-IDF: 0.0
# Term: aspect, TF-IDF: 0.0
# Term: assault, TF-IDF: 0.0
# Term: assert, TF-IDF: 0.0
# Term: assessment, TF-IDF: 0.0
# Term: assessments, TF-IDF: 0.0
# Term: asset, TF-IDF: 0.0
# Term: assets, TF-IDF: 0.0466526581904916
# Term: assistance, TF-IDF: 0.0
# Term: associated, TF-IDF: 0.0
# Term: association, TF-IDF: 0.0
# Term: astounding, TF-IDF: 0.0
# Term: astronomically, TF-IDF: 0.0
# Term: asx, TF-IDF: 0.0
# Term: at, TF-IDF: 0.0
# Term: ath, TF-IDF: 0.0
# Term: aths, TF-IDF: 0.0
# Term: atop, TF-IDF: 0.0
# Term: attempting, TF-IDF: 0.0
# Term: attention, TF-IDF: 0.0
# Term: attract, TF-IDF: 0.0
# Term: attracted, TF-IDF: 0.0
# Term: attracting, TF-IDF: 0.0
# Term: attractive, TF-IDF: 0.03323968398182599
# Term: attributes, TF-IDF: 0.0
# Term: attuned, TF-IDF: 0.0
# Term: auctioned, TF-IDF: 0.0
# Term: august, TF-IDF: 0.0
# Term: aum, TF-IDF: 0.0
# Term: auspicious, TF-IDF: 0.0
# Term: austin, TF-IDF: 0.0
# Term: australia, TF-IDF: 0.0
# Term: australian, TF-IDF: 0.0
# Term: author, TF-IDF: 0.0
# Term: authorities, TF-IDF: 0.0
# Term: authority, TF-IDF: 0.0
# Term: authorization, TF-IDF: 0.0
# Term: authorized, TF-IDF: 0.0
# Term: automated, TF-IDF: 0.0
# Term: automatically, TF-IDF: 0.0
# Term: availability, TF-IDF: 0.0
# Term: available, TF-IDF: 0.02409440556657939
# Term: avenue, TF-IDF: 0.0
# Term: average, TF-IDF: 0.0
# Term: awaiting, TF-IDF: 0.0
# Term: awarded, TF-IDF: 0.0
# Term: aware, TF-IDF: 0.0
# Term: away, TF-IDF: 0.0
# Term: back, TF-IDF: 0.0
# Term: backed, TF-IDF: 0.09971905194547798
# Term: backing, TF-IDF: 0.0
# Term: backlash, TF-IDF: 0.0
# Term: bad, TF-IDF: 0.0
# Term: bahamas, TF-IDF: 0.0
# Term: balance, TF-IDF: 0.0
# Term: balanced, TF-IDF: 0.037020251588197016
# Term: balances, TF-IDF: 0.0
# Term: ballooned, TF-IDF: 0.0
# Term: bank, TF-IDF: 0.0
# Term: bankers, TF-IDF: 0.0
# Term: banking, TF-IDF: 0.0
# Term: bankman, TF-IDF: 0.0
# Term: bankrate, TF-IDF: 0.0
# Term: banks, TF-IDF: 0.0
# Term: barely, TF-IDF: 0.0
# Term: barriers, TF-IDF: 0.0
# Term: basak, TF-IDF: 0.0
# Term: base, TF-IDF: 0.030557328577388205
# Term: based, TF-IDF: 0.0
# Term: basic, TF-IDF: 0.0
# Term: basics, TF-IDF: 0.0
# Term: basis, TF-IDF: 0.0
# Term: basulto, TF-IDF: 0.0
# Term: bat, TF-IDF: 0.0
# Term: batch, TF-IDF: 0.0
# Term: bats, TF-IDF: 0.07404050317639403
# Term: battle, TF-IDF: 0.0
# Term: bcb, TF-IDF: 0.0
# Term: be, TF-IDF: 0.02417283487904789
# Term: beach, TF-IDF: 0.0
# Term: bear, TF-IDF: 0.0
# Term: bearing, TF-IDF: 0.0
# Term: bearish, TF-IDF: 0.0
# Term: because, TF-IDF: 0.0
# Term: become, TF-IDF: 0.025339455873732354
# Term: becomes, TF-IDF: 0.0
# Term: becoming, TF-IDF: 0.0
# Term: bedroom, TF-IDF: 0.0
# Term: been, TF-IDF: 0.013104594583712072
# Term: before, TF-IDF: 0.0
# Term: began, TF-IDF: 0.0
# Term: beginning, TF-IDF: 0.0
# Term: begs, TF-IDF: 0.0
# Term: begun, TF-IDF: 0.0
# Term: behalf, TF-IDF: 0.0
# Term: behave, TF-IDF: 0.0
# Term: behemoth, TF-IDF: 0.0
# Term: behind, TF-IDF: 0.0
# Term: being, TF-IDF: 0.0
# Term: belief, TF-IDF: 0.0
# Term: believe, TF-IDF: 0.0
# Term: believer, TF-IDF: 0.0
# Term: believes, TF-IDF: 0.0
# Term: belong, TF-IDF: 0.0
# Term: below, TF-IDF: 0.028476732085114826
# Term: benchmark, TF-IDF: 0.0
# Term: beneficial, TF-IDF: 0.0
# Term: beneficiaries, TF-IDF: 0.0
# Term: beneficiary, TF-IDF: 0.0
# Term: benefit, TF-IDF: 0.0
# Term: benefited, TF-IDF: 0.0
# Term: benefits, TF-IDF: 0.0
# Term: benzinga, TF-IDF: 0.04818881113315878
# Term: berkrot, TF-IDF: 0.0
# Term: bernstein, TF-IDF: 0.0
# Term: best, TF-IDF: 0.0
# Term: beta, TF-IDF: 0.0
# Term: betashares, TF-IDF: 0.0
# Term: better, TF-IDF: 0.0
# Term: between, TF-IDF: 0.0
# Term: beyond, TF-IDF: 0.0
# Term: bezos, TF-IDF: 0.037020251588197016
# Term: biden, TF-IDF: 0.0
# Term: big, TF-IDF: 0.0
# Term: bigger, TF-IDF: 0.0
# Term: biggest, TF-IDF: 0.0
# Term: bill, TF-IDF: 0.0
# Term: billion, TF-IDF: 0.019567517594520887
# Term: billions, TF-IDF: 0.0
# Term: binance, TF-IDF: 0.0
# Term: bitb, TF-IDF: 0.0
# Term: bitcoin, TF-IDF: 0.044674238179847045
# Term: bitcoins, TF-IDF: 0.0
# Term: bitcointreasuries, TF-IDF: 0.0
# Term: bito, TF-IDF: 0.0
# Term: bitwise, TF-IDF: 0.0
# Term: black, TF-IDF: 0.0
# Term: blackrock, TF-IDF: 0.0
# Term: blamed, TF-IDF: 0.0
# Term: blk, TF-IDF: 0.0
# Term: bloc, TF-IDF: 0.0
# Term: block, TF-IDF: 0.0
# Term: blockchain, TF-IDF: 0.0
# Term: blockchains, TF-IDF: 0.0
# Term: blocks, TF-IDF: 0.0
# Term: blog, TF-IDF: 0.0
# Term: bloomberg, TF-IDF: 0.0
# Term: blow, TF-IDF: 0.0
# Term: blueprint, TF-IDF: 0.0
# Term: board, TF-IDF: 0.0
# Term: boj, TF-IDF: 0.0
# Term: bonds, TF-IDF: 0.0
# Term: bonk, TF-IDF: 0.0
# Term: bonuses, TF-IDF: 0.0
# Term: book, TF-IDF: 0.0
# Term: boom, TF-IDF: 0.0
# Term: boost, TF-IDF: 0.0
# Term: born, TF-IDF: 0.0
# Term: boston, TF-IDF: 0.0
# Term: both, TF-IDF: 0.0
# Term: bottom, TF-IDF: 0.0
# Term: bought, TF-IDF: 0.0
# Term: bound, TF-IDF: 0.0
# Term: boutique, TF-IDF: 0.0
# Term: bradford, TF-IDF: 0.0
# Term: brain, TF-IDF: 0.0
# Term: brand, TF-IDF: 0.0
# Term: breach, TF-IDF: 0.0
# Term: breached, TF-IDF: 0.0
# Term: breaking, TF-IDF: 0.0
# Term: brexit, TF-IDF: 0.0
# Term: bridges, TF-IDF: 0.0
# Term: brief, TF-IDF: 0.0
# Term: briefs, TF-IDF: 0.0
# Term: brilliant, TF-IDF: 0.0
# Term: bring, TF-IDF: 0.0
# Term: brings, TF-IDF: 0.0
# Term: british, TF-IDF: 0.0
# Term: broad, TF-IDF: 0.0
# Term: broader, TF-IDF: 0.0
# Term: brody, TF-IDF: 0.0
# Term: broker, TF-IDF: 0.0
# Term: brokerages, TF-IDF: 0.0
# Term: brokers, TF-IDF: 0.0
# Term: bros, TF-IDF: 0.0
# Term: brought, TF-IDF: 0.0
# Term: btc, TF-IDF: 0.0
# Term: bucket, TF-IDF: 0.0
# Term: buckle, TF-IDF: 0.0
# Term: budgetary, TF-IDF: 0.0
# Term: buffett, TF-IDF: 0.0
# Term: bug, TF-IDF: 0.0
# Term: build, TF-IDF: 0.030557328577388205
# Term: builder, TF-IDF: 0.0
# Term: building, TF-IDF: 0.0
# Term: built, TF-IDF: 0.0
# Term: bukele, TF-IDF: 0.0
# Term: bull, TF-IDF: 0.0
# Term: bullish, TF-IDF: 0.0
# Term: bulls, TF-IDF: 0.0
# Term: bully, TF-IDF: 0.0
# Term: bureau, TF-IDF: 0.0
# Term: burgeoning, TF-IDF: 0.0
# Term: business, TF-IDF: 0.0
# Term: businesses, TF-IDF: 0.0
# Term: businessweek, TF-IDF: 0.0
# Term: busy, TF-IDF: 0.0
# Term: but, TF-IDF: 0.014247741942385633
# Term: buy, TF-IDF: 0.016029146124123417
# Term: buyers, TF-IDF: 0.0
# Term: buying, TF-IDF: 0.0
# Term: buys, TF-IDF: 0.0
# Term: by, TF-IDF: 0.031809881806962675
# Term: california, TF-IDF: 0.0
# Term: call, TF-IDF: 0.0
# Term: called, TF-IDF: 0.0
# Term: calm, TF-IDF: 0.0
# Term: calpers, TF-IDF: 0.0
# Term: cambridge, TF-IDF: 0.0
# Term: came, TF-IDF: 0.0
# Term: campaign, TF-IDF: 0.0
# Term: campbell, TF-IDF: 0.0
# Term: can, TF-IDF: 0.0854864516543138
# Term: candidate, TF-IDF: 0.0
# Term: cap, TF-IDF: 0.07601836762119707
# Term: capabilities, TF-IDF: 0.0
# Term: capability, TF-IDF: 0.0
# Term: capable, TF-IDF: 0.0
# Term: capital, TF-IDF: 0.0
# Term: capitalist, TF-IDF: 0.037020251588197016
# Term: capitalization, TF-IDF: 0.0
# Term: caps, TF-IDF: 0.0
# Term: carbon, TF-IDF: 0.0
# Term: cards, TF-IDF: 0.0
# Term: carefully, TF-IDF: 0.0
# Term: carries, TF-IDF: 0.0
# Term: case, TF-IDF: 0.0
# Term: cases, TF-IDF: 0.0
# Term: casey, TF-IDF: 0.0
# Term: cash, TF-IDF: 0.16097335355252304
# Term: cashflows, TF-IDF: 0.0
# Term: casino, TF-IDF: 0.0
# Term: cat, TF-IDF: 0.0
# Term: catalyst, TF-IDF: 0.0
# Term: catching, TF-IDF: 0.0
# Term: categories, TF-IDF: 0.0
# Term: category, TF-IDF: 0.0
# Term: caterpillar, TF-IDF: 0.0
# Term: cathedrals, TF-IDF: 0.0
# Term: cathie, TF-IDF: 0.0
# Term: caught, TF-IDF: 0.0
# Term: cause, TF-IDF: 0.0
# Term: causes, TF-IDF: 0.0
# Term: cboe, TF-IDF: 0.0
# Term: cd20, TF-IDF: 0.0
# Term: celebrated, TF-IDF: 0.0
# Term: center, TF-IDF: 0.0
# Term: centers, TF-IDF: 0.0
# Term: central, TF-IDF: 0.0
# Term: centralized, TF-IDF: 0.0
# Term: centric, TF-IDF: 0.0
# Term: cents, TF-IDF: 0.0
# Term: century, TF-IDF: 0.0
# Term: ceo, TF-IDF: 0.025339455873732354
# Term: certainly, TF-IDF: 0.0
# Term: chain, TF-IDF: 0.0
# Term: chair, TF-IDF: 0.0
# Term: chairman, TF-IDF: 0.0
# Term: challenge, TF-IDF: 0.0
# Term: challenger, TF-IDF: 0.0
# Term: challenging, TF-IDF: 0.0
# Term: chance, TF-IDF: 0.0
# Term: change, TF-IDF: 0.0
# Term: changed, TF-IDF: 0.0
# Term: changer, TF-IDF: 0.0
# Term: changing, TF-IDF: 0.0
# Term: changpeng, TF-IDF: 0.0
# Term: characteristics, TF-IDF: 0.0
# Term: charges, TF-IDF: 0.0
# Term: chart, TF-IDF: 0.0
# Term: charting, TF-IDF: 0.0
# Term: chase, TF-IDF: 0.0
# Term: check, TF-IDF: 0.0
# Term: checks, TF-IDF: 0.0
# Term: chesapeake, TF-IDF: 0.0
# Term: chg, TF-IDF: 0.0
# Term: chhugani, TF-IDF: 0.0
# Term: chief, TF-IDF: 0.0
# Term: china, TF-IDF: 0.0
# Term: chipmixer, TF-IDF: 0.0
# Term: chk, TF-IDF: 0.0
# Term: choice, TF-IDF: 0.037020251588197016
# Term: choices, TF-IDF: 0.0
# Term: choose, TF-IDF: 0.0
# Term: chooses, TF-IDF: 0.0
# Term: choppy, TF-IDF: 0.0
# Term: chunk, TF-IDF: 0.0
# Term: cifr, TF-IDF: 0.0
# Term: cipher, TF-IDF: 0.0
# Term: circle, TF-IDF: 0.0
# Term: circuits, TF-IDF: 0.0
# Term: circulation, TF-IDF: 0.0
# Term: circumvent, TF-IDF: 0.0
# Term: cited, TF-IDF: 0.0
# Term: cites, TF-IDF: 0.0
# Term: citing, TF-IDF: 0.0
# Term: citizens, TF-IDF: 0.0
# Term: cityfunds, TF-IDF: 0.11106075476459105
# Term: civil, TF-IDF: 0.0
# Term: claiming, TF-IDF: 0.0
# Term: claims, TF-IDF: 0.0
# Term: clarity, TF-IDF: 0.0
# Term: classic, TF-IDF: 0.0
# Term: classification, TF-IDF: 0.0
# Term: cleanspark, TF-IDF: 0.0
# Term: clear, TF-IDF: 0.0
# Term: clearing, TF-IDF: 0.0
# Term: clearly, TF-IDF: 0.0
# Term: click, TF-IDF: 0.0
# Term: clients, TF-IDF: 0.0
# Term: climate, TF-IDF: 0.0
# Term: climbs, TF-IDF: 0.0
# Term: clorox, TF-IDF: 0.0
# Term: close, TF-IDF: 0.0
# Term: closed, TF-IDF: 0.0
# Term: closely, TF-IDF: 0.0
# Term: closer, TF-IDF: 0.0
# Term: closest, TF-IDF: 0.0
# Term: closing, TF-IDF: 0.0
# Term: cloud, TF-IDF: 0.0
# Term: clsk, TF-IDF: 0.0
# Term: clubs, TF-IDF: 0.0
# Term: clx, TF-IDF: 0.0
# Term: cmcsa, TF-IDF: 0.0
# Term: co, TF-IDF: 0.0
# Term: coca, TF-IDF: 0.0
# Term: code, TF-IDF: 0.0
# Term: cohorts, TF-IDF: 0.0
# Term: coin, TF-IDF: 0.0
# Term: coinbase, TF-IDF: 0.0
# Term: coincided, TF-IDF: 0.0
# Term: coindesk, TF-IDF: 0.0
# Term: coinfund, TF-IDF: 0.0
# Term: coingecko, TF-IDF: 0.0
# Term: coinkite, TF-IDF: 0.0
# Term: coins, TF-IDF: 0.0
# Term: cola, TF-IDF: 0.0
# Term: collaborate, TF-IDF: 0.0
# Term: collapse, TF-IDF: 0.0
# Term: collapsed, TF-IDF: 0.0
# Term: collateral, TF-IDF: 0.0
# Term: collateralized, TF-IDF: 0.037020251588197016
# Term: collection, TF-IDF: 0.0
# Term: collective, TF-IDF: 0.0
# Term: collectively, TF-IDF: 0.0
# Term: collison, TF-IDF: 0.0
# Term: columbia, TF-IDF: 0.0
# Term: columnist, TF-IDF: 0.0
# Term: com, TF-IDF: 0.02112513438659526
# Term: combination, TF-IDF: 0.0
# Term: combined, TF-IDF: 0.0
# Term: comcast, TF-IDF: 0.0
# Term: come, TF-IDF: 0.0
# Term: comes, TF-IDF: 0.0
# Term: coming, TF-IDF: 0.019567517594520887
# Term: command, TF-IDF: 0.0
# Term: commensurate, TF-IDF: 0.0
# Term: comment, TF-IDF: 0.0
# Term: comments, TF-IDF: 0.009324026977341044
# Term: commercial, TF-IDF: 0.0
# Term: commercialization, TF-IDF: 0.0
# Term: commission, TF-IDF: 0.026776760971017177
# Term: commissioners, TF-IDF: 0.0
# Term: committed, TF-IDF: 0.0
# Term: committee, TF-IDF: 0.0
# Term: commodities, TF-IDF: 0.0
# Term: commodity, TF-IDF: 0.0
# Term: communication, TF-IDF: 0.037020251588197016
# Term: community, TF-IDF: 0.0
# Term: companies, TF-IDF: 0.01887653286292354
# Term: company, TF-IDF: 0.0
# Term: compared, TF-IDF: 0.0
# Term: comparison, TF-IDF: 0.0
# Term: compelling, TF-IDF: 0.028476732085114826
# Term: compete, TF-IDF: 0.0
# Term: competent, TF-IDF: 0.0
# Term: competition, TF-IDF: 0.0
# Term: competitor, TF-IDF: 0.0
# Term: competitors, TF-IDF: 0.0
# Term: compiled, TF-IDF: 0.0
# Term: complete, TF-IDF: 0.0
# Term: completeness, TF-IDF: 0.0
# Term: complex, TF-IDF: 0.0
# Term: complexity, TF-IDF: 0.0
# Term: compliance, TF-IDF: 0.0
# Term: complicated, TF-IDF: 0.0
# Term: component, TF-IDF: 0.0
# Term: compute, TF-IDF: 0.0
# Term: computer, TF-IDF: 0.0
# Term: computers, TF-IDF: 0.0
# Term: computing, TF-IDF: 0.0
# Term: con, TF-IDF: 0.0
# Term: conceal, TF-IDF: 0.0
# Term: concentrated, TF-IDF: 0.0
# Term: concern, TF-IDF: 0.0
# Term: concerned, TF-IDF: 0.0
# Term: concerning, TF-IDF: 0.0
# Term: concerns, TF-IDF: 0.0
# Term: concluded, TF-IDF: 0.0
# Term: condition, TF-IDF: 0.037020251588197016
# Term: conditions, TF-IDF: 0.0
# Term: condo, TF-IDF: 0.0
# Term: conference, TF-IDF: 0.0
# Term: confidence, TF-IDF: 0.0
# Term: confirmation, TF-IDF: 0.0
# Term: confiscated, TF-IDF: 0.0
# Term: conflate, TF-IDF: 0.0
# Term: confuse, TF-IDF: 0.0
# Term: congress, TF-IDF: 0.0
# Term: congressional, TF-IDF: 0.0
# Term: congressman, TF-IDF: 0.0
# Term: connected, TF-IDF: 0.0
# Term: consecutive, TF-IDF: 0.03323968398182599
# Term: consensus, TF-IDF: 0.0
# Term: consensys, TF-IDF: 0.0
# Term: conservative, TF-IDF: 0.0
# Term: consider, TF-IDF: 0.022013809074306008
# Term: considerable, TF-IDF: 0.0
# Term: considerably, TF-IDF: 0.0
# Term: considerations, TF-IDF: 0.0
# Term: considered, TF-IDF: 0.0
# Term: consistent, TF-IDF: 0.0
# Term: consistently, TF-IDF: 0.0
# Term: consists, TF-IDF: 0.0
# Term: constant, TF-IDF: 0.0
# Term: constitutes, TF-IDF: 0.0
# Term: consultant, TF-IDF: 0.0
# Term: consume, TF-IDF: 0.0
# Term: consumer, TF-IDF: 0.0
# Term: consumers, TF-IDF: 0.0
# Term: consumes, TF-IDF: 0.0
# Term: consumption, TF-IDF: 0.0
# Term: contained, TF-IDF: 0.0
# Term: contender, TF-IDF: 0.037020251588197016
# Term: content, TF-IDF: 0.0
# Term: contest, TF-IDF: 0.0
# Term: context, TF-IDF: 0.0
# Term: continue, TF-IDF: 0.0
# Term: continued, TF-IDF: 0.0
# Term: continues, TF-IDF: 0.0
# Term: continuing, TF-IDF: 0.0
# Term: continuously, TF-IDF: 0.0
# Term: contract, TF-IDF: 0.0
# Term: contribute, TF-IDF: 0.03323968398182599
# Term: contributing, TF-IDF: 0.0
# Term: control, TF-IDF: 0.0
# Term: controlled, TF-IDF: 0.0
# Term: controlling, TF-IDF: 0.0
# Term: controls, TF-IDF: 0.0
# Term: conundrum, TF-IDF: 0.0
# Term: convenient, TF-IDF: 0.0
# Term: conventional, TF-IDF: 0.0
# Term: convert, TF-IDF: 0.0
# Term: converted, TF-IDF: 0.0
# Term: convertible, TF-IDF: 0.0
# Term: cool, TF-IDF: 0.0
# Term: cooled, TF-IDF: 0.0
# Term: cooley, TF-IDF: 0.0
# Term: cooperation, TF-IDF: 0.0
# Term: coordination, TF-IDF: 0.0
# Term: copyright, TF-IDF: 0.0
# Term: copyrighted, TF-IDF: 0.0
# Term: core, TF-IDF: 0.0
# Term: corner, TF-IDF: 0.0
# Term: corp, TF-IDF: 0.0
# Term: corporate, TF-IDF: 0.0
# Term: corporation, TF-IDF: 0.0
# Term: correct, TF-IDF: 0.0
# Term: correction, TF-IDF: 0.0
# Term: correlated, TF-IDF: 0.0
# Term: correlation, TF-IDF: 0.0
# Term: cost, TF-IDF: 0.0
# Term: costly, TF-IDF: 0.0
# Term: costs, TF-IDF: 0.0
# Term: costume, TF-IDF: 0.0
# Term: could, TF-IDF: 0.0
# Term: couldn, TF-IDF: 0.0
# Term: council, TF-IDF: 0.0
# Term: counsel, TF-IDF: 0.0
# Term: count, TF-IDF: 0.0
# Term: countries, TF-IDF: 0.0
# Term: country, TF-IDF: 0.0
# Term: counts, TF-IDF: 0.0
# Term: couple, TF-IDF: 0.0
# Term: course, TF-IDF: 0.0
# Term: court, TF-IDF: 0.0
# Term: courthouse, TF-IDF: 0.0
# Term: cowen, TF-IDF: 0.0
# Term: crack, TF-IDF: 0.0
# Term: crackdown, TF-IDF: 0.0
# Term: crazy, TF-IDF: 0.0
# Term: create, TF-IDF: 0.02409440556657939
# Term: created, TF-IDF: 0.0
# Term: creating, TF-IDF: 0.0
# Term: creator, TF-IDF: 0.0
# Term: creators, TF-IDF: 0.0
# Term: cref, TF-IDF: 0.0
# Term: crime, TF-IDF: 0.0
# Term: criminal, TF-IDF: 0.0
# Term: criminals, TF-IDF: 0.0
# Term: crisis, TF-IDF: 0.0
# Term: critic, TF-IDF: 0.0
# Term: criticism, TF-IDF: 0.0
# Term: criticizes, TF-IDF: 0.0
# Term: critics, TF-IDF: 0.0
# Term: cross, TF-IDF: 0.0
# Term: crowd, TF-IDF: 0.0
# Term: crucial, TF-IDF: 0.0
# Term: crude, TF-IDF: 0.0
# Term: crunch, TF-IDF: 0.0
# Term: cruz, TF-IDF: 0.0
# Term: cry, TF-IDF: 0.0
# Term: crypto, TF-IDF: 0.0
# Term: cryptocurrencies, TF-IDF: 0.0
# Term: cryptocurrency, TF-IDF: 0.0
# Term: cryptographic, TF-IDF: 0.0
# Term: cryptos, TF-IDF: 0.0
# Term: culminating, TF-IDF: 0.0
# Term: cumulative, TF-IDF: 0.0
# Term: cure, TF-IDF: 0.0
# Term: curiae, TF-IDF: 0.0
# Term: currencies, TF-IDF: 0.0
# Term: currency, TF-IDF: 0.0
# Term: current, TF-IDF: 0.0
# Term: currently, TF-IDF: 0.022013809074306008
# Term: custodial, TF-IDF: 0.0
# Term: custodians, TF-IDF: 0.0
# Term: custody, TF-IDF: 0.0
# Term: customers, TF-IDF: 0.0
# Term: cut, TF-IDF: 0.0
# Term: cuts, TF-IDF: 0.0
# Term: cybercrime, TF-IDF: 0.0
# Term: cycle, TF-IDF: 0.0
# Term: cycles, TF-IDF: 0.0
# Term: cz, TF-IDF: 0.0
# Term: daily, TF-IDF: 0.0
# Term: damages, TF-IDF: 0.0
# Term: dark, TF-IDF: 0.0
# Term: dashboard, TF-IDF: 0.0
# Term: dasp, TF-IDF: 0.0
# Term: data, TF-IDF: 0.0
# Term: date, TF-IDF: 0.030557328577388205
# Term: david, TF-IDF: 0.0
# Term: day, TF-IDF: 0.0
# Term: days, TF-IDF: 0.0
# Term: db, TF-IDF: 0.0
# Term: dc, TF-IDF: 0.0
# Term: de, TF-IDF: 0.0
# Term: deal, TF-IDF: 0.0
# Term: dealer, TF-IDF: 0.0
# Term: dealings, TF-IDF: 0.0
# Term: deaton, TF-IDF: 0.0
# Term: debased, TF-IDF: 0.0
# Term: debasement, TF-IDF: 0.0
# Term: debasing, TF-IDF: 0.0
# Term: debate, TF-IDF: 0.0
# Term: debt, TF-IDF: 0.0
# Term: debut, TF-IDF: 0.0
# Term: decade, TF-IDF: 0.0
# Term: decades, TF-IDF: 0.0
# Term: deceiving, TF-IDF: 0.0
# Term: december, TF-IDF: 0.0
# Term: decent, TF-IDF: 0.0
# Term: decentralized, TF-IDF: 0.0
# Term: decided, TF-IDF: 0.0
# Term: deciding, TF-IDF: 0.0
# Term: decision, TF-IDF: 0.0
# Term: decisions, TF-IDF: 0.0
# Term: decline, TF-IDF: 0.0
# Term: declining, TF-IDF: 0.0
# Term: dedicated, TF-IDF: 0.03323968398182599
# Term: deduct, TF-IDF: 0.0
# Term: deemed, TF-IDF: 0.0
# Term: deems, TF-IDF: 0.0
# Term: deep, TF-IDF: 0.0
# Term: deeply, TF-IDF: 0.0
# Term: defense, TF-IDF: 0.0
# Term: defi, TF-IDF: 0.0
# Term: deficit, TF-IDF: 0.0
# Term: deflationary, TF-IDF: 0.0
# Term: defy, TF-IDF: 0.0
# Term: degree, TF-IDF: 0.0
# Term: delays, TF-IDF: 0.0
# Term: delist, TF-IDF: 0.0
# Term: deliver, TF-IDF: 0.0
# Term: demand, TF-IDF: 0.0
# Term: demanded, TF-IDF: 0.0
# Term: democrat, TF-IDF: 0.0
# Term: democratic, TF-IDF: 0.0
# Term: democratize, TF-IDF: 0.0
# Term: demographic, TF-IDF: 0.0
# Term: demonstrated, TF-IDF: 0.0
# Term: demonstrates, TF-IDF: 0.037020251588197016
# Term: denominated, TF-IDF: 0.0
# Term: departed, TF-IDF: 0.0
# Term: departure, TF-IDF: 0.0
# Term: depend, TF-IDF: 0.0
# Term: dependence, TF-IDF: 0.0
# Term: depends, TF-IDF: 0.0
# Term: deposit, TF-IDF: 0.0
# Term: deposited, TF-IDF: 0.0
# Term: deposits, TF-IDF: 0.0
# Term: deputy, TF-IDF: 0.0
# Term: deribit, TF-IDF: 0.0
# Term: derivatives, TF-IDF: 0.0
# Term: deserve, TF-IDF: 0.0
# Term: design, TF-IDF: 0.0
# Term: designed, TF-IDF: 0.03323968398182599
# Term: designer, TF-IDF: 0.0
# Term: designing, TF-IDF: 0.0
# Term: desk, TF-IDF: 0.0
# Term: despite, TF-IDF: 0.0
# Term: detail, TF-IDF: 0.0
# Term: detailed, TF-IDF: 0.0
# Term: details, TF-IDF: 0.0
# Term: detective, TF-IDF: 0.0
# Term: determining, TF-IDF: 0.0
# Term: devaluation, TF-IDF: 0.0
# Term: developer, TF-IDF: 0.0
# Term: developers, TF-IDF: 0.0
# Term: development, TF-IDF: 0.0
# Term: developments, TF-IDF: 0.0
# Term: device, TF-IDF: 0.0
# Term: devices, TF-IDF: 0.0
# Term: dia, TF-IDF: 0.0
# Term: diamondback, TF-IDF: 0.0
# Term: did, TF-IDF: 0.0
# Term: didn, TF-IDF: 0.0
# Term: different, TF-IDF: 0.0
# Term: differentiator, TF-IDF: 0.0
# Term: difficult, TF-IDF: 0.0
# Term: difficulty, TF-IDF: 0.0
# Term: digital, TF-IDF: 0.0
# Term: digitalx, TF-IDF: 0.0
# Term: diligence, TF-IDF: 0.0
# Term: diminish, TF-IDF: 0.0
# Term: diminished, TF-IDF: 0.0
# Term: diminishing, TF-IDF: 0.0
# Term: dipped, TF-IDF: 0.0
# Term: direct, TF-IDF: 0.0
# Term: direction, TF-IDF: 0.0
# Term: directly, TF-IDF: 0.0
# Term: director, TF-IDF: 0.0
# Term: disclosure, TF-IDF: 0.0
# Term: disclosures, TF-IDF: 0.0
# Term: discontinuing, TF-IDF: 0.0
# Term: discovered, TF-IDF: 0.0
# Term: discovery, TF-IDF: 0.0
# Term: discretion, TF-IDF: 0.0
# Term: disinflationary, TF-IDF: 0.0
# Term: dismay, TF-IDF: 0.0
# Term: display, TF-IDF: 0.0
# Term: disruption, TF-IDF: 0.0
# Term: disservice, TF-IDF: 0.0
# Term: distinguishable, TF-IDF: 0.0
# Term: distributed, TF-IDF: 0.0
# Term: distribution, TF-IDF: 0.0
# Term: distributions, TF-IDF: 0.037020251588197016
# Term: district, TF-IDF: 0.0
# Term: dive, TF-IDF: 0.0
# Term: diverse, TF-IDF: 0.0
# Term: diversification, TF-IDF: 0.0
# Term: diversified, TF-IDF: 0.037020251588197016
# Term: dividend, TF-IDF: 0.25914176111737913
# Term: dividends, TF-IDF: 0.07404050317639403
# Term: dividing, TF-IDF: 0.0
# Term: dlx, TF-IDF: 0.0
# Term: do, TF-IDF: 0.0
# Term: does, TF-IDF: 0.0
# Term: doesn, TF-IDF: 0.0
# Term: dog, TF-IDF: 0.0
# Term: doge, TF-IDF: 0.0
# Term: dogecoin, TF-IDF: 0.0
# Term: dogwifhat, TF-IDF: 0.0
# Term: doing, TF-IDF: 0.0
# Term: dollar, TF-IDF: 0.0
# Term: dollars, TF-IDF: 0.0
# Term: dominance, TF-IDF: 0.0
# Term: dominant, TF-IDF: 0.0
# Term: dominate, TF-IDF: 0.0
# Term: dominic, TF-IDF: 0.0
# Term: don, TF-IDF: 0.0
# Term: donald, TF-IDF: 0.0
# Term: done, TF-IDF: 0.0
# Term: door, TF-IDF: 0.0
# Term: doors, TF-IDF: 0.0
# Term: dorman, TF-IDF: 0.0
# Term: double, TF-IDF: 0.0
# Term: doubled, TF-IDF: 0.0
# Term: dove, TF-IDF: 0.0
# Term: dow, TF-IDF: 0.0
# Term: down, TF-IDF: 0.0
# Term: download, TF-IDF: 0.0
# Term: downturn, TF-IDF: 0.0
# Term: downturns, TF-IDF: 0.0
# Term: downward, TF-IDF: 0.0
# Term: drawbacks, TF-IDF: 0.0
# Term: drawn, TF-IDF: 0.0
# Term: drive, TF-IDF: 0.0
# Term: driven, TF-IDF: 0.0
# Term: driver, TF-IDF: 0.0
# Term: driving, TF-IDF: 0.0
# Term: drones, TF-IDF: 0.0
# Term: drop, TF-IDF: 0.0
# Term: dropped, TF-IDF: 0.0
# Term: dropping, TF-IDF: 0.0
# Term: drops, TF-IDF: 0.0
# Term: drying, TF-IDF: 0.0
# Term: due, TF-IDF: 0.0
# Term: dumb, TF-IDF: 0.0
# Term: dune, TF-IDF: 0.0
# Term: during, TF-IDF: 0.0
# Term: dust, TF-IDF: 0.0
# Term: dvol, TF-IDF: 0.0
# Term: dxy, TF-IDF: 0.0
# Term: dynamic, TF-IDF: 0.0
# Term: dynamics, TF-IDF: 0.0
# Term: each, TF-IDF: 0.0
# Term: earlier, TF-IDF: 0.0
# Term: early, TF-IDF: 0.0
# Term: earn, TF-IDF: 0.03323968398182599
# Term: earned, TF-IDF: 0.0
# Term: earning, TF-IDF: 0.03323968398182599
# Term: earnings, TF-IDF: 0.0
# Term: earns, TF-IDF: 0.0
# Term: earth, TF-IDF: 0.0
# Term: easily, TF-IDF: 0.0
# Term: easing, TF-IDF: 0.0
# Term: east, TF-IDF: 0.0
# Term: easy, TF-IDF: 0.0
# Term: easygoatfish351, TF-IDF: 0.0
# Term: eat, TF-IDF: 0.0
# Term: eaton, TF-IDF: 0.0
# Term: economic, TF-IDF: 0.0
# Term: economies, TF-IDF: 0.0
# Term: economy, TF-IDF: 0.0
# Term: ecosystem, TF-IDF: 0.0
# Term: ecosystems, TF-IDF: 0.0
# Term: eden, TF-IDF: 0.0
# Term: edged, TF-IDF: 0.0
# Term: editing, TF-IDF: 0.0
# Term: edt, TF-IDF: 0.0
# Term: eea, TF-IDF: 0.0
# Term: effect, TF-IDF: 0.0
# Term: effectively, TF-IDF: 0.0
# Term: effects, TF-IDF: 0.0
# Term: effort, TF-IDF: 0.0
# Term: efforts, TF-IDF: 0.0
# Term: eighth, TF-IDF: 0.0
# Term: either, TF-IDF: 0.0
# Term: el, TF-IDF: 0.0
# Term: election, TF-IDF: 0.0
# Term: electricity, TF-IDF: 0.0
# Term: electronic, TF-IDF: 0.0
# Term: elegance, TF-IDF: 0.0
# Term: eleven, TF-IDF: 0.0
# Term: eli, TF-IDF: 0.0
# Term: eligible, TF-IDF: 0.0
# Term: elizabeth, TF-IDF: 0.0
# Term: elliott, TF-IDF: 0.0
# Term: elon, TF-IDF: 0.0
# Term: else, TF-IDF: 0.0
# Term: elsewhere, TF-IDF: 0.0
# Term: email, TF-IDF: 0.0
# Term: embraced, TF-IDF: 0.0
# Term: embracing, TF-IDF: 0.0
# Term: emi, TF-IDF: 0.0
# Term: emphasizing, TF-IDF: 0.037020251588197016
# Term: empire, TF-IDF: 0.0
# Term: employee, TF-IDF: 0.0
# Term: employing, TF-IDF: 0.0
# Term: employment, TF-IDF: 0.0
# Term: enable, TF-IDF: 0.0
# Term: enables, TF-IDF: 0.0
# Term: enabling, TF-IDF: 0.0
# Term: encourage, TF-IDF: 0.0
# Term: encrypted, TF-IDF: 0.0
# Term: end, TF-IDF: 0.0
# Term: ended, TF-IDF: 0.0
# Term: endorses, TF-IDF: 0.0
# Term: ends, TF-IDF: 0.0
# Term: energy, TF-IDF: 0.0
# Term: enforce, TF-IDF: 0.0
# Term: engage, TF-IDF: 0.0
# Term: engaged, TF-IDF: 0.0
# Term: engagement, TF-IDF: 0.0
# Term: engages, TF-IDF: 0.0
# Term: engaging, TF-IDF: 0.0
# Term: engineering, TF-IDF: 0.0
# Term: enhanced, TF-IDF: 0.0
# Term: enjoy, TF-IDF: 0.0
# Term: enormous, TF-IDF: 0.0
# Term: enough, TF-IDF: 0.0
# Term: enquiry, TF-IDF: 0.0
# Term: ensue, TF-IDF: 0.0
# Term: ensuring, TF-IDF: 0.0
# Term: enter, TF-IDF: 0.0
# Term: entering, TF-IDF: 0.0
# Term: enterprise, TF-IDF: 0.0
# Term: enterprises, TF-IDF: 0.0
# Term: enthusiast, TF-IDF: 0.0
# Term: enticing, TF-IDF: 0.037020251588197016
# Term: entire, TF-IDF: 0.0
# Term: entirely, TF-IDF: 0.0
# Term: entities, TF-IDF: 0.0
# Term: entrepreneur, TF-IDF: 0.0
# Term: entrepreneurs, TF-IDF: 0.0
# Term: entry, TF-IDF: 0.0
# Term: environment, TF-IDF: 0.0
# Term: environmental, TF-IDF: 0.0
# Term: environments, TF-IDF: 0.0
# Term: epic, TF-IDF: 0.0
# Term: equation, TF-IDF: 0.0
# Term: equipment, TF-IDF: 0.0
# Term: equities, TF-IDF: 0.0
# Term: equity, TF-IDF: 0.028476732085114826
# Term: equivalent, TF-IDF: 0.0
# Term: era, TF-IDF: 0.0
# Term: erman, TF-IDF: 0.0
# Term: error, TF-IDF: 0.0
# Term: especially, TF-IDF: 0.0
# Term: essentially, TF-IDF: 0.0
# Term: established, TF-IDF: 0.0
# Term: establishing, TF-IDF: 0.0
# Term: estate, TF-IDF: 0.07228321669973817
# Term: estimate, TF-IDF: 0.0
# Term: estimated, TF-IDF: 0.0
# Term: estimates, TF-IDF: 0.0
# Term: et, TF-IDF: 0.0
# Term: etch, TF-IDF: 0.0
# Term: etf, TF-IDF: 0.03775306572584708
# Term: etfs, TF-IDF: 0.03306654070767467
# Term: eth, TF-IDF: 0.0
# Term: ether, TF-IDF: 0.0
# Term: ethereum, TF-IDF: 0.0
# Term: etn, TF-IDF: 0.0
# Term: eu, TF-IDF: 0.0
# Term: euphoria, TF-IDF: 0.0
# Term: europe, TF-IDF: 0.0
# Term: european, TF-IDF: 0.0
# Term: evade, TF-IDF: 0.0
# Term: evelyn, TF-IDF: 0.0
# Term: even, TF-IDF: 0.0
# Term: evening, TF-IDF: 0.0
# Term: event, TF-IDF: 0.0
# Term: events, TF-IDF: 0.0
# Term: eventually, TF-IDF: 0.0
# Term: ever, TF-IDF: 0.0
# Term: every, TF-IDF: 0.0
# Term: everything, TF-IDF: 0.0
# Term: evidence, TF-IDF: 0.0
# Term: evident, TF-IDF: 0.0
# Term: evo, TF-IDF: 0.0
# Term: evolution, TF-IDF: 0.0
# Term: evolving, TF-IDF: 0.0
# Term: ex, TF-IDF: 0.0
# Term: exactly, TF-IDF: 0.0
# Term: examination, TF-IDF: 0.0
# Term: example, TF-IDF: 0.0
# Term: examples, TF-IDF: 0.0
# Term: exceeding, TF-IDF: 0.0
# Term: except, TF-IDF: 0.0
# Term: exchange, TF-IDF: 0.0
# Term: exchanges, TF-IDF: 0.0
# Term: excitement, TF-IDF: 0.0
# Term: exciting, TF-IDF: 0.037020251588197016
# Term: excluding, TF-IDF: 0.0
# Term: executes, TF-IDF: 0.0
# Term: executing, TF-IDF: 0.0
# Term: executive, TF-IDF: 0.0
# Term: exercising, TF-IDF: 0.0
# Term: exert, TF-IDF: 0.0
# Term: exhibit, TF-IDF: 0.037020251588197016
# Term: exist, TF-IDF: 0.0
# Term: existed, TF-IDF: 0.0
# Term: existing, TF-IDF: 0.0
# Term: exists, TF-IDF: 0.0
# Term: exited, TF-IDF: 0.0
# Term: exodus, TF-IDF: 0.0
# Term: expand, TF-IDF: 0.0
# Term: expansion, TF-IDF: 0.0
# Term: expect, TF-IDF: 0.0
# Term: expectation, TF-IDF: 0.0
# Term: expectations, TF-IDF: 0.0
# Term: expected, TF-IDF: 0.0
# Term: expenses, TF-IDF: 0.0
# Term: expensive, TF-IDF: 0.0
# Term: experienced, TF-IDF: 0.0
# Term: experiences, TF-IDF: 0.0
# Term: experts, TF-IDF: 0.0
# Term: expire, TF-IDF: 0.0
# Term: explained, TF-IDF: 0.0
# Term: explicit, TF-IDF: 0.0
# Term: exploded, TF-IDF: 0.0
# Term: exploitation, TF-IDF: 0.0
# Term: exploration, TF-IDF: 0.0
# Term: explore, TF-IDF: 0.0
# Term: explosive, TF-IDF: 0.0
# Term: exponentially, TF-IDF: 0.0
# Term: exports, TF-IDF: 0.0
# Term: exposed, TF-IDF: 0.0
# Term: exposes, TF-IDF: 0.0
# Term: exposure, TF-IDF: 0.026776760971017177
# Term: express, TF-IDF: 0.0
# Term: expressing, TF-IDF: 0.0
# Term: extent, TF-IDF: 0.0
# Term: extreme, TF-IDF: 0.0
# Term: extremely, TF-IDF: 0.0
# Term: ey, TF-IDF: 0.0
# Term: eye, TF-IDF: 0.0
# Term: eyebrows, TF-IDF: 0.0
# Term: eyes, TF-IDF: 0.0
# Term: ezbc, TF-IDF: 0.0
# Term: face, TF-IDF: 0.0
# Term: facebook, TF-IDF: 0.0
# Term: faced, TF-IDF: 0.0
# Term: facing, TF-IDF: 0.0
# Term: fact, TF-IDF: 0.0
# Term: factor, TF-IDF: 0.0
# Term: factors, TF-IDF: 0.0
# Term: fade, TF-IDF: 0.0
# Term: faded, TF-IDF: 0.0
# Term: fading, TF-IDF: 0.0
# Term: fail, TF-IDF: 0.0
# Term: failed, TF-IDF: 0.0
# Term: failla, TF-IDF: 0.0
# Term: failure, TF-IDF: 0.0
# Term: fair, TF-IDF: 0.0
# Term: fairjunco470, TF-IDF: 0.0
# Term: fairly, TF-IDF: 0.0
# Term: faith, TF-IDF: 0.0
# Term: fall, TF-IDF: 0.0
# Term: fallen, TF-IDF: 0.0
# Term: falling, TF-IDF: 0.0
# Term: falls, TF-IDF: 0.0
# Term: false, TF-IDF: 0.0
# Term: famed, TF-IDF: 0.0
# Term: familiar, TF-IDF: 0.0
# Term: family, TF-IDF: 0.037020251588197016
# Term: fang, TF-IDF: 0.0
# Term: fans, TF-IDF: 0.0
# Term: far, TF-IDF: 0.0
# Term: faster, TF-IDF: 0.0
# Term: fate, TF-IDF: 0.0
# Term: favored, TF-IDF: 0.0
# Term: fbi, TF-IDF: 0.0
# Term: fbtc, TF-IDF: 0.0
# Term: fears, TF-IDF: 0.0
# Term: feat, TF-IDF: 0.0
# Term: features, TF-IDF: 0.0
# Term: february, TF-IDF: 0.0
# Term: fed, TF-IDF: 0.0
# Term: federal, TF-IDF: 0.0
# Term: fees, TF-IDF: 0.0
# Term: fell, TF-IDF: 0.0
# Term: fervently, TF-IDF: 0.0
# Term: few, TF-IDF: 0.0
# Term: fewer, TF-IDF: 0.0
# Term: fiat, TF-IDF: 0.0
# Term: fidelity, TF-IDF: 0.0
# Term: field, TF-IDF: 0.0
# Term: fierce, TF-IDF: 0.0
# Term: fight, TF-IDF: 0.0
# Term: fighting, TF-IDF: 0.0
# Term: fights, TF-IDF: 0.0
# Term: file, TF-IDF: 0.0
# Term: filed, TF-IDF: 0.0
# Term: filing, TF-IDF: 0.0
# Term: filings, TF-IDF: 0.0
# Term: fill, TF-IDF: 0.0
# Term: finally, TF-IDF: 0.0
# Term: finance, TF-IDF: 0.026776760971017177
# Term: financial, TF-IDF: 0.01706621694646304
# Term: financing, TF-IDF: 0.0
# Term: find, TF-IDF: 0.0
# Term: fine, TF-IDF: 0.0
# Term: finite, TF-IDF: 0.0
# Term: finiteness, TF-IDF: 0.0
# Term: fintech, TF-IDF: 0.0
# Term: firm, TF-IDF: 0.0
# Term: firms, TF-IDF: 0.0
# Term: first, TF-IDF: 0.0
# Term: fiscal, TF-IDF: 0.0
# Term: five, TF-IDF: 0.028476732085114826
# Term: flagship, TF-IDF: 0.0
# Term: flat, TF-IDF: 0.0
# Term: flawed, TF-IDF: 0.0
# Term: flood, TF-IDF: 0.0
# Term: flow, TF-IDF: 0.16619841990912995
# Term: flowing, TF-IDF: 0.07404050317639403
# Term: flows, TF-IDF: 0.0
# Term: fluctuations, TF-IDF: 0.0
# Term: focus, TF-IDF: 0.030557328577388205
# Term: focused, TF-IDF: 0.0
# Term: focuses, TF-IDF: 0.0
# Term: folk, TF-IDF: 0.0
# Term: follow, TF-IDF: 0.0
# Term: following, TF-IDF: 0.0
# Term: follows, TF-IDF: 0.0
# Term: fool, TF-IDF: 0.0
# Term: fools, TF-IDF: 0.0
# Term: football, TF-IDF: 0.0
# Term: footprint, TF-IDF: 0.0
# Term: for, TF-IDF: 0.04028138937211408
# Term: foray, TF-IDF: 0.0
# Term: force, TF-IDF: 0.0
# Term: forced, TF-IDF: 0.0
# Term: forcing, TF-IDF: 0.0
# Term: forecast, TF-IDF: 0.0
# Term: forecasted, TF-IDF: 0.0
# Term: forecasts, TF-IDF: 0.0
# Term: forever, TF-IDF: 0.0
# Term: forget, TF-IDF: 0.2221215095291821
# Term: form, TF-IDF: 0.0
# Term: formally, TF-IDF: 0.0
# Term: former, TF-IDF: 0.0
# Term: formerly, TF-IDF: 0.0
# Term: formidable, TF-IDF: 0.0
# Term: fortunes, TF-IDF: 0.0
# Term: forward, TF-IDF: 0.0
# Term: found, TF-IDF: 0.0
# Term: foundation, TF-IDF: 0.037020251588197016
# Term: founder, TF-IDF: 0.025339455873732354
# Term: founding, TF-IDF: 0.0
# Term: four, TF-IDF: 0.0
# Term: fourth, TF-IDF: 0.0
# Term: fox, TF-IDF: 0.0
# Term: fractional, TF-IDF: 0.037020251588197016
# Term: fractions, TF-IDF: 0.0
# Term: frame, TF-IDF: 0.0
# Term: framework, TF-IDF: 0.0
# Term: frameworks, TF-IDF: 0.0
# Term: france, TF-IDF: 0.0
# Term: francisco, TF-IDF: 0.0
# Term: frankfurt, TF-IDF: 0.0
# Term: franklin, TF-IDF: 0.0
# Term: fraud, TF-IDF: 0.0
# Term: free, TF-IDF: 0.022996193364646148
# Term: french, TF-IDF: 0.0
# Term: frenzy, TF-IDF: 0.0
# Term: fresh, TF-IDF: 0.0
# Term: friday, TF-IDF: 0.0
# Term: fried, TF-IDF: 0.0
# Term: friend, TF-IDF: 0.0
# Term: from, TF-IDF: 0.00981487856854707
# Term: frozen, TF-IDF: 0.0
# Term: ftx, TF-IDF: 0.0
# Term: fuel, TF-IDF: 0.0
# Term: fueled, TF-IDF: 0.0
# Term: fueling, TF-IDF: 0.0
# Term: full, TF-IDF: 0.0
# Term: fully, TF-IDF: 0.0
# Term: fulton, TF-IDF: 0.0
# Term: fun, TF-IDF: 0.0
# Term: functions, TF-IDF: 0.0
# Term: fund, TF-IDF: 0.10156918980104182
# Term: fundamental, TF-IDF: 0.0
# Term: fundamentals, TF-IDF: 0.0
# Term: funded, TF-IDF: 0.037020251588197016
# Term: funding, TF-IDF: 0.0
# Term: fundraising, TF-IDF: 0.0
# Term: funds, TF-IDF: 0.0
# Term: fungible, TF-IDF: 0.0
# Term: further, TF-IDF: 0.02112513438659526
# Term: furthest, TF-IDF: 0.0
# Term: future, TF-IDF: 0.0
# Term: futures, TF-IDF: 0.0
# Term: gain, TF-IDF: 0.0
# Term: gained, TF-IDF: 0.0
# Term: gains, TF-IDF: 0.0
# Term: gambling, TF-IDF: 0.0
# Term: game, TF-IDF: 0.0
# Term: games, TF-IDF: 0.0
# Term: gamut, TF-IDF: 0.0
# Term: gapping, TF-IDF: 0.0
# Term: gaps, TF-IDF: 0.0
# Term: garantex, TF-IDF: 0.0
# Term: gardens, TF-IDF: 0.0
# Term: garnered, TF-IDF: 0.0
# Term: gary, TF-IDF: 0.0
# Term: gas, TF-IDF: 0.0
# Term: gathered, TF-IDF: 0.0
# Term: gautam, TF-IDF: 0.0
# Term: gave, TF-IDF: 0.0
# Term: gbtc, TF-IDF: 0.0
# Term: gdp, TF-IDF: 0.0
# Term: ge, TF-IDF: 0.0
# Term: gehc, TF-IDF: 0.0
# Term: gen, TF-IDF: 0.0
# Term: general, TF-IDF: 0.0
# Term: generally, TF-IDF: 0.0
# Term: generate, TF-IDF: 0.0
# Term: generated, TF-IDF: 0.03323968398182599
# Term: generates, TF-IDF: 0.0
# Term: generation, TF-IDF: 0.0
# Term: generational, TF-IDF: 0.0
# Term: generations, TF-IDF: 0.0
# Term: generative, TF-IDF: 0.0
# Term: gensler, TF-IDF: 0.0
# Term: geopolitical, TF-IDF: 0.0
# Term: germany, TF-IDF: 0.0
# Term: gestation, TF-IDF: 0.0
# Term: get, TF-IDF: 0.0
# Term: getting, TF-IDF: 0.0
# Term: getty, TF-IDF: 0.0
# Term: giant, TF-IDF: 0.03323968398182599
# Term: gifted, TF-IDF: 0.0
# Term: ginns, TF-IDF: 0.0
# Term: give, TF-IDF: 0.0
# Term: given, TF-IDF: 0.0
# Term: gives, TF-IDF: 0.0
# Term: global, TF-IDF: 0.0
# Term: globaldata, TF-IDF: 0.0
# Term: globally, TF-IDF: 0.0
# Term: globe, TF-IDF: 0.0
# Term: gme, TF-IDF: 0.0
# Term: go, TF-IDF: 0.0
# Term: goal, TF-IDF: 0.0
# Term: godbole, TF-IDF: 0.0
# Term: goes, TF-IDF: 0.0
# Term: going, TF-IDF: 0.0
# Term: gold, TF-IDF: 0.022013809074306008
# Term: goldman, TF-IDF: 0.0
# Term: gone, TF-IDF: 0.0
# Term: good, TF-IDF: 0.0
# Term: gop, TF-IDF: 0.0
# Term: got, TF-IDF: 0.037020251588197016
# Term: gotten, TF-IDF: 0.0
# Term: government, TF-IDF: 0.0
# Term: governments, TF-IDF: 0.0
# Term: gpus, TF-IDF: 0.0
# Term: grab, TF-IDF: 0.0
# Term: grade, TF-IDF: 0.0
# Term: graduate, TF-IDF: 0.0
# Term: grand, TF-IDF: 0.0
# Term: granted, TF-IDF: 0.0
# Term: graph, TF-IDF: 0.0
# Term: graphic, TF-IDF: 0.0
# Term: gravity, TF-IDF: 0.0
# Term: grayscale, TF-IDF: 0.0
# Term: great, TF-IDF: 0.0
# Term: greater, TF-IDF: 0.0
# Term: greatest, TF-IDF: 0.0
# Term: greek, TF-IDF: 0.0
# Term: greenback, TF-IDF: 0.0
# Term: greenfield, TF-IDF: 0.0
# Term: grew, TF-IDF: 0.0
# Term: grewal, TF-IDF: 0.0
# Term: grips, TF-IDF: 0.0
# Term: grounds, TF-IDF: 0.0
# Term: group, TF-IDF: 0.0
# Term: groups, TF-IDF: 0.0
# Term: grow, TF-IDF: 0.0
# Term: growing, TF-IDF: 0.0
# Term: grown, TF-IDF: 0.0
# Term: grows, TF-IDF: 0.0
# Term: growth, TF-IDF: 0.0
# Term: gtbc, TF-IDF: 0.0
# Term: guarantee, TF-IDF: 0.0
# Term: guaranteed, TF-IDF: 0.037020251588197016
# Term: guess, TF-IDF: 0.0
# Term: guesses, TF-IDF: 0.0
# Term: guessing, TF-IDF: 0.0
# Term: guidance, TF-IDF: 0.0
# Term: guide, TF-IDF: 0.0
# Term: guilty, TF-IDF: 0.0
# Term: hacker, TF-IDF: 0.0
# Term: hacking, TF-IDF: 0.0
# Term: hacks, TF-IDF: 0.0
# Term: had, TF-IDF: 0.0
# Term: half, TF-IDF: 0.0
# Term: hallucination, TF-IDF: 0.0
# Term: halt, TF-IDF: 0.0
# Term: halved, TF-IDF: 0.0
# Term: halving, TF-IDF: 0.0
# Term: halvings, TF-IDF: 0.0
# Term: handful, TF-IDF: 0.0
# Term: hanging, TF-IDF: 0.0
# Term: hangs, TF-IDF: 0.0
# Term: hannah, TF-IDF: 0.0
# Term: hans, TF-IDF: 0.037020251588197016
# Term: happen, TF-IDF: 0.0
# Term: happened, TF-IDF: 0.0
# Term: happens, TF-IDF: 0.0
# Term: harbor, TF-IDF: 0.0
# Term: hard, TF-IDF: 0.0
# Term: harder, TF-IDF: 0.0
# Term: hardware, TF-IDF: 0.0
# Term: hardwired, TF-IDF: 0.0
# Term: harvard, TF-IDF: 0.0
# Term: has, TF-IDF: 0.03021104202908556
# Term: hash, TF-IDF: 0.0
# Term: hasn, TF-IDF: 0.0
# Term: haul, TF-IDF: 0.0
# Term: have, TF-IDF: 0.0
# Term: haven, TF-IDF: 0.0
# Term: having, TF-IDF: 0.030557328577388205
# Term: hawkish, TF-IDF: 0.0
# Term: he, TF-IDF: 0.04062767592041673
# Term: head, TF-IDF: 0.0
# Term: headed, TF-IDF: 0.0
# Term: headquarters, TF-IDF: 0.0
# Term: headwinds, TF-IDF: 0.0
# Term: healthcare, TF-IDF: 0.0
# Term: healthy, TF-IDF: 0.037020251588197016
# Term: heard, TF-IDF: 0.0
# Term: hearing, TF-IDF: 0.0
# Term: heavily, TF-IDF: 0.028476732085114826
# Term: heavy, TF-IDF: 0.0
# Term: heavyweights, TF-IDF: 0.0
# Term: hedge, TF-IDF: 0.0
# Term: hedges, TF-IDF: 0.0
# Term: hedging, TF-IDF: 0.0
# Term: heels, TF-IDF: 0.0
# Term: hefty, TF-IDF: 0.0
# Term: heists, TF-IDF: 0.0
# Term: held, TF-IDF: 0.0
# Term: help, TF-IDF: 0.025339455873732354
# Term: helped, TF-IDF: 0.0
# Term: helping, TF-IDF: 0.0
# Term: helps, TF-IDF: 0.0
# Term: here, TF-IDF: 0.03306654070767467
# Term: hero, TF-IDF: 0.0
# Term: hester, TF-IDF: 0.0
# Term: hidden, TF-IDF: 0.0
# Term: high, TF-IDF: 0.036466482935869966
# Term: higher, TF-IDF: 0.0
# Term: highest, TF-IDF: 0.0
# Term: highlights, TF-IDF: 0.03323968398182599
# Term: highly, TF-IDF: 0.0
# Term: highs, TF-IDF: 0.0
# Term: hiked, TF-IDF: 0.0
# Term: him, TF-IDF: 0.0
# Term: himself, TF-IDF: 0.0
# Term: hinder, TF-IDF: 0.0
# Term: hired, TF-IDF: 0.0
# Term: his, TF-IDF: 0.022013809074306008
# Term: historic, TF-IDF: 0.0
# Term: historical, TF-IDF: 0.0
# Term: historically, TF-IDF: 0.0
# Term: history, TF-IDF: 0.0
# Term: hit, TF-IDF: 0.0
# Term: hits, TF-IDF: 0.0
# Term: hitting, TF-IDF: 0.0
# Term: hobby, TF-IDF: 0.0
# Term: hockstein, TF-IDF: 0.0
# Term: hoium, TF-IDF: 0.0
# Term: hold, TF-IDF: 0.0
# Term: holder, TF-IDF: 0.0
# Term: holders, TF-IDF: 0.0
# Term: holding, TF-IDF: 0.0
# Term: holdings, TF-IDF: 0.0
# Term: holds, TF-IDF: 0.0
# Term: home, TF-IDF: 0.037020251588197016
# Term: honest, TF-IDF: 0.0
# Term: hong, TF-IDF: 0.0
# Term: hood, TF-IDF: 0.0
# Term: hopes, TF-IDF: 0.0
# Term: hoping, TF-IDF: 0.0
# Term: horizon, TF-IDF: 0.0
# Term: horizons, TF-IDF: 0.0
# Term: hostile, TF-IDF: 0.0
# Term: hot, TF-IDF: 0.0
# Term: hottest, TF-IDF: 0.0
# Term: hours, TF-IDF: 0.0
# Term: household, TF-IDF: 0.0
# Term: housing, TF-IDF: 0.0
# Term: hovering, TF-IDF: 0.0
# Term: how, TF-IDF: 0.0
# Term: howcroft, TF-IDF: 0.0
# Term: however, TF-IDF: 0.022013809074306008
# Term: howey, TF-IDF: 0.0
# Term: hsbc, TF-IDF: 0.0
# Term: huge, TF-IDF: 0.0
# Term: human, TF-IDF: 0.0
# Term: humanity, TF-IDF: 0.0
# Term: humans, TF-IDF: 0.0
# Term: hundreds, TF-IDF: 0.0
# Term: hype, TF-IDF: 0.0
# Term: hyperbitcoinization, TF-IDF: 0.0
# Term: hypothesis, TF-IDF: 0.0
# Term: ibit, TF-IDF: 0.0
# Term: ibkr, TF-IDF: 0.0
# Term: iceberg, TF-IDF: 0.0
# Term: icos, TF-IDF: 0.0
# Term: icp, TF-IDF: 0.0
# Term: ideas, TF-IDF: 0.0
# Term: identified, TF-IDF: 0.0
# Term: identifying, TF-IDF: 0.0
# Term: identities, TF-IDF: 0.0
# Term: identity, TF-IDF: 0.0
# Term: if, TF-IDF: 0.015095965256552516
# Term: illicit, TF-IDF: 0.0
# Term: illistration, TF-IDF: 0.0
# Term: image, TF-IDF: 0.0
# Term: images, TF-IDF: 0.0
# Term: immediate, TF-IDF: 0.0
# Term: immediately, TF-IDF: 0.0
# Term: impact, TF-IDF: 0.0
# Term: impacts, TF-IDF: 0.0
# Term: impairment, TF-IDF: 0.0
# Term: impasse, TF-IDF: 0.0
# Term: implant, TF-IDF: 0.0
# Term: implants, TF-IDF: 0.0
# Term: implement, TF-IDF: 0.0
# Term: implementation, TF-IDF: 0.0
# ...
# Term: stated, TF-IDF: 0.03323968398182599
# Term: statement, TF-IDF: 0.0
# Term: statements, TF-IDF: 0.0
# Term: states, TF-IDF: 0.0
# Term: stating, TF-IDF: 0.037020251588197016
# Term: statistics, TF-IDF: 0.0
# Term: status, TF-IDF: 0.0
# Term: stay, TF-IDF: 0.0
# Term: staying, TF-IDF: 0.0
# Term: stays, TF-IDF: 0.0
# Term: steady, TF-IDF: 0.06647936796365198
# Term: step, TF-IDF: 0.0
# Term: steps, TF-IDF: 0.0
# Term: sticking, TF-IDF: 0.0
# Term: sticky, TF-IDF: 0.0
# Term: still, TF-IDF: 0.0
# Term: stimulate, TF-IDF: 0.0
# Term: stock, TF-IDF: 0.0
# Term: stocks, TF-IDF: 0.016533270353837334
# Term: stolen, TF-IDF: 0.0
# Term: stonks, TF-IDF: 0.0
# Term: stop, TF-IDF: 0.0
# Term: stopped, TF-IDF: 0.0
# Term: stopping, TF-IDF: 0.0
# Term: store, TF-IDF: 0.0
# Term: stored, TF-IDF: 0.0
# Term: stories, TF-IDF: 0.0
# Term: story, TF-IDF: 0.0
# Term: straight, TF-IDF: 0.0
# Term: strain, TF-IDF: 0.0
# Term: strategic, TF-IDF: 0.0
# Term: strategies, TF-IDF: 0.0
# Term: strategy, TF-IDF: 0.05067891174746471
# Term: streak, TF-IDF: 0.0
# Term: stream, TF-IDF: 0.037020251588197016
# Term: street, TF-IDF: 0.0
# Term: strength, TF-IDF: 0.0
# Term: strengthening, TF-IDF: 0.0
# Term: strict, TF-IDF: 0.0
# Term: strike, TF-IDF: 0.0
# Term: stripe, TF-IDF: 0.0
# Term: strong, TF-IDF: 0.026776760971017177
# Term: stronger, TF-IDF: 0.0
# Term: strongest, TF-IDF: 0.0
# Term: stronghold, TF-IDF: 0.0
# Term: struck, TF-IDF: 0.0
# Term: structured, TF-IDF: 0.0
# Term: stryker, TF-IDF: 0.0
# Term: stubbornly, TF-IDF: 0.0
# Term: stuck, TF-IDF: 0.0
# Term: subject, TF-IDF: 0.0
# Term: subscribe, TF-IDF: 0.0
# Term: subscriptions, TF-IDF: 0.0
# Term: subsides, TF-IDF: 0.0
# Term: substantial, TF-IDF: 0.0
# Term: substantially, TF-IDF: 0.0
# Term: succeed, TF-IDF: 0.0
# Term: success, TF-IDF: 0.0
# Term: successful, TF-IDF: 0.0
# Term: successfully, TF-IDF: 0.0
# Term: such, TF-IDF: 0.0
# Term: sudden, TF-IDF: 0.0
# Term: sued, TF-IDF: 0.0
# Term: suffer, TF-IDF: 0.0
# Term: suffered, TF-IDF: 0.0
# Term: sufficient, TF-IDF: 0.0
# Term: suggest, TF-IDF: 0.0
# Term: suitable, TF-IDF: 0.0
# Term: suited, TF-IDF: 0.0
# Term: sum, TF-IDF: 0.0
# Term: sumitomo, TF-IDF: 0.0
# Term: summer, TF-IDF: 0.0
# Term: sums, TF-IDF: 0.0
# Term: sunday, TF-IDF: 0.0
# Term: super, TF-IDF: 0.0
# Term: supercharge, TF-IDF: 0.0
# Term: superior, TF-IDF: 0.0
# Term: supply, TF-IDF: 0.0
# Term: support, TF-IDF: 0.0
# Term: supporters, TF-IDF: 0.0
# Term: supporting, TF-IDF: 0.0
# Term: supports, TF-IDF: 0.0
# Term: supposed, TF-IDF: 0.0
# Term: supreme, TF-IDF: 0.0
# Term: sure, TF-IDF: 0.03323968398182599
# Term: surface, TF-IDF: 0.0
# Term: surge, TF-IDF: 0.0
# Term: surged, TF-IDF: 0.0
# Term: surging, TF-IDF: 0.0
# Term: surpass, TF-IDF: 0.0
# Term: surpassed, TF-IDF: 0.0
# Term: surpasses, TF-IDF: 0.0
# Term: surpassing, TF-IDF: 0.0
# Term: surprise, TF-IDF: 0.0
# Term: surprising, TF-IDF: 0.0
# Term: surveyed, TF-IDF: 0.0
# Term: survival, TF-IDF: 0.0
# Term: survive, TF-IDF: 0.0
# Term: suspected, TF-IDF: 0.0
# Term: suspicion, TF-IDF: 0.0
# Term: suspicious, TF-IDF: 0.0
# Term: sustainable, TF-IDF: 0.0
# Term: sustained, TF-IDF: 0.0
# Term: sutor, TF-IDF: 0.0
# Term: suzanne, TF-IDF: 0.0
# Term: swap, TF-IDF: 0.0
# Term: swiftly, TF-IDF: 0.0
# Term: swings, TF-IDF: 0.0
# Term: swks, TF-IDF: 0.0
# Term: sword, TF-IDF: 0.0
# Term: syk, TF-IDF: 0.0
# Term: system, TF-IDF: 0.0
# Term: systems, TF-IDF: 0.0
# Term: tailwind, TF-IDF: 0.0
# Term: tailwinds, TF-IDF: 0.0
# Term: take, TF-IDF: 0.0
# Term: takeaway, TF-IDF: 0.0
# Term: taken, TF-IDF: 0.0
# Term: takes, TF-IDF: 0.0
# Term: taking, TF-IDF: 0.0
# Term: talented, TF-IDF: 0.0
# Term: tame, TF-IDF: 0.0
# Term: tank, TF-IDF: 0.14808100635278806
# Term: tanked, TF-IDF: 0.0
# Term: target, TF-IDF: 0.0
# Term: targeting, TF-IDF: 0.03323968398182599
# Term: targets, TF-IDF: 0.0
# Term: tax, TF-IDF: 0.0
# Term: taxed, TF-IDF: 0.0
# Term: taxes, TF-IDF: 0.0
# Term: taxpayer, TF-IDF: 0.0
# Term: td, TF-IDF: 0.0
# Term: teachers, TF-IDF: 0.0
# Term: team, TF-IDF: 0.0
# Term: tech, TF-IDF: 0.0
# Term: technical, TF-IDF: 0.0
# Term: techno, TF-IDF: 0.0
# Term: technologies, TF-IDF: 0.0
# Term: technologists, TF-IDF: 0.0
# Term: technology, TF-IDF: 0.0
# Term: telecom, TF-IDF: 0.037020251588197016
# Term: television, TF-IDF: 0.0
# Term: tell, TF-IDF: 0.0
# Term: tells, TF-IDF: 0.0
# Term: tempered, TF-IDF: 0.0
# Term: templeton, TF-IDF: 0.0
# Term: temporary, TF-IDF: 0.0
# Term: tend, TF-IDF: 0.0
# Term: tender, TF-IDF: 0.0
# Term: tends, TF-IDF: 0.0
# Term: tens, TF-IDF: 0.0
# Term: tensions, TF-IDF: 0.0
# Term: tensor, TF-IDF: 0.0
# Term: tentative, TF-IDF: 0.0
# Term: tepid, TF-IDF: 0.0
# Term: terawatt, TF-IDF: 0.0
# Term: term, TF-IDF: 0.058702552783562664
# Term: terms, TF-IDF: 0.0
# Term: terrorist, TF-IDF: 0.0
# Term: tesla, TF-IDF: 0.0
# Term: test, TF-IDF: 0.0
# Term: testifies, TF-IDF: 0.0
# Term: testing, TF-IDF: 0.0
# Term: tether, TF-IDF: 0.0
# Term: texas, TF-IDF: 0.0
# Term: texts, TF-IDF: 0.0
# Term: than, TF-IDF: 0.013470289571223822
# Term: thank, TF-IDF: 0.0
# Term: thanked, TF-IDF: 0.0
# Term: that, TF-IDF: 0.04028138937211408
# Term: the, TF-IDF: 0.15850845861479776
# Term: thefts, TF-IDF: 0.0
# Term: their, TF-IDF: 0.0
# Term: them, TF-IDF: 0.0
# Term: themed, TF-IDF: 0.0
# Term: themselves, TF-IDF: 0.0
# Term: then, TF-IDF: 0.0
# Term: theory, TF-IDF: 0.0
# Term: there, TF-IDF: 0.0
# Term: thereby, TF-IDF: 0.0
# Term: therefore, TF-IDF: 0.0
# Term: these, TF-IDF: 0.031101772126994397
# Term: they, TF-IDF: 0.014662211375786448
# Term: things, TF-IDF: 0.0
# Term: think, TF-IDF: 0.0
# Term: thinking, TF-IDF: 0.0
# Term: thinks, TF-IDF: 0.0
# Term: third, TF-IDF: 0.0
# Term: this, TF-IDF: 0.03099904007952406
# Term: thompson, TF-IDF: 0.0
# Term: thorn, TF-IDF: 0.0
# Term: those, TF-IDF: 0.022013809074306008
# Term: though, TF-IDF: 0.0
# Term: thousand, TF-IDF: 0.0
# Term: threat, TF-IDF: 0.0
# Term: three, TF-IDF: 0.02112513438659526
# Term: threshold, TF-IDF: 0.0
# Term: thrive, TF-IDF: 0.0
# Term: thriving, TF-IDF: 0.0
# Term: through, TF-IDF: 0.039135035189041774
# Term: throw, TF-IDF: 0.0
# Term: thursday, TF-IDF: 0.0
# Term: thus, TF-IDF: 0.0
# Term: tiaa, TF-IDF: 0.0
# Term: tight, TF-IDF: 0.0
# Term: tightening, TF-IDF: 0.0
# Term: tiktok, TF-IDF: 0.0
# Term: till, TF-IDF: 0.0
# Term: time, TF-IDF: 0.0
# Term: timeline, TF-IDF: 0.0
# Term: times, TF-IDF: 0.0
# Term: tiny, TF-IDF: 0.0
# Term: tip, TF-IDF: 0.0
# Term: titled, TF-IDF: 0.0
# Term: to, TF-IDF: 0.10256429675075149
# Term: today, TF-IDF: 0.0
# Term: together, TF-IDF: 0.0
# Term: token, TF-IDF: 0.0
# Term: tokenized, TF-IDF: 0.0
# Term: tokenomics, TF-IDF: 0.0
# Term: tokens, TF-IDF: 0.0
# Term: told, TF-IDF: 0.0
# Term: tolerance, TF-IDF: 0.0
# Term: tonkin, TF-IDF: 0.0
# Term: too, TF-IDF: 0.0
# Term: took, TF-IDF: 0.0
# Term: tool, TF-IDF: 0.0
# Term: tools, TF-IDF: 0.0
# Term: top, TF-IDF: 0.0
# Term: topic, TF-IDF: 0.0
# Term: torn, TF-IDF: 0.0
# Term: tornado, TF-IDF: 0.0
# Term: torres, TF-IDF: 0.0
# Term: total, TF-IDF: 0.0
# Term: totaled, TF-IDF: 0.0
# Term: touch, TF-IDF: 0.0
# Term: toward, TF-IDF: 0.0
# Term: track, TF-IDF: 0.0
# Term: tracked, TF-IDF: 0.0
# Term: tracking, TF-IDF: 0.0
# Term: tracks, TF-IDF: 0.0
# Term: trade, TF-IDF: 0.0
# Term: traded, TF-IDF: 0.0
# Term: trader, TF-IDF: 0.0
# Term: traders, TF-IDF: 0.0
# Term: trades, TF-IDF: 0.0
# Term: tradfi, TF-IDF: 0.0
# Term: trading, TF-IDF: 0.0
# Term: tradingview, TF-IDF: 0.0
# Term: traditional, TF-IDF: 0.0
# Term: trail, TF-IDF: 0.0
# Term: traits, TF-IDF: 0.0
# Term: trajectory, TF-IDF: 0.0
# Term: trane, TF-IDF: 0.0
# Term: transaction, TF-IDF: 0.0
# Term: transactions, TF-IDF: 0.0
# Term: transfer, TF-IDF: 0.0
# Term: transfers, TF-IDF: 0.0
# Term: transform, TF-IDF: 0.0
# Term: transformation, TF-IDF: 0.0
# Term: transition, TF-IDF: 0.0
# Term: translates, TF-IDF: 0.0
# Term: transparency, TF-IDF: 0.0
# Term: travel, TF-IDF: 0.0
# Term: travis, TF-IDF: 0.0
# Term: treading, TF-IDF: 0.0
# Term: treasuries, TF-IDF: 0.0
# Term: treasury, TF-IDF: 0.0
# Term: treating, TF-IDF: 0.0
# Term: tremendous, TF-IDF: 0.0
# Term: trend, TF-IDF: 0.0
# Term: trending, TF-IDF: 0.0
# Term: trezor, TF-IDF: 0.0
# Term: trial, TF-IDF: 0.0
# Term: tricking, TF-IDF: 0.0
# Term: tried, TF-IDF: 0.0
# Term: trillion, TF-IDF: 0.0
# Term: true, TF-IDF: 0.0
# Term: truly, TF-IDF: 0.0
# Term: trump, TF-IDF: 0.0
# Term: trust, TF-IDF: 0.0
# Term: trying, TF-IDF: 0.0
# Term: tsla, TF-IDF: 0.0
# Term: tt, TF-IDF: 0.0
# Term: tuesday, TF-IDF: 0.0
# Term: tumble, TF-IDF: 0.0
# Term: tumbled, TF-IDF: 0.0
# Term: tumbles, TF-IDF: 0.0
# Term: tune, TF-IDF: 0.0
# Term: turbulence, TF-IDF: 0.0
# Term: turmoil, TF-IDF: 0.0
# Term: turn, TF-IDF: 0.0
# Term: turnaround, TF-IDF: 0.0
# Term: turned, TF-IDF: 0.0
# Term: tv, TF-IDF: 0.0
# Term: tweeted, TF-IDF: 0.0
# Term: twitter, TF-IDF: 0.0
# Term: two, TF-IDF: 0.0
# Term: type, TF-IDF: 0.0
# Term: types, TF-IDF: 0.0
# Term: typical, TF-IDF: 0.0
# Term: typically, TF-IDF: 0.0
# Term: tysons, TF-IDF: 0.0
# Term: uk, TF-IDF: 0.0
# Term: ultimately, TF-IDF: 0.0
# Term: unauthorised, TF-IDF: 0.0
# Term: unbelievable, TF-IDF: 0.0
# Term: uncertain, TF-IDF: 0.037020251588197016
# Term: uncertainty, TF-IDF: 0.0
# Term: unclear, TF-IDF: 0.0
# Term: uncommon, TF-IDF: 0.0
# Term: uncovered, TF-IDF: 0.0
# Term: under, TF-IDF: 0.0
# Term: underlying, TF-IDF: 0.0
# Term: undermine, TF-IDF: 0.0
# Term: underperformed, TF-IDF: 0.0
# Term: underperforming, TF-IDF: 0.0
# Term: underpins, TF-IDF: 0.0
# Term: understand, TF-IDF: 0.0
# Term: understandable, TF-IDF: 0.0
# Term: understands, TF-IDF: 0.0
# Term: undervalued, TF-IDF: 0.0
# Term: underway, TF-IDF: 0.0
# Term: undoubtedly, TF-IDF: 0.0
# Term: unexpectedly, TF-IDF: 0.0
# Term: unfairly, TF-IDF: 0.0
# Term: unfamiliar, TF-IDF: 0.0
# Term: unfiltered, TF-IDF: 0.0
# Term: unfortunate, TF-IDF: 0.0
# Term: unfortunately, TF-IDF: 0.0
# Term: unheard, TF-IDF: 0.0
# Term: uni, TF-IDF: 0.0
# Term: union, TF-IDF: 0.0
# Term: unions, TF-IDF: 0.0
# Term: unique, TF-IDF: 0.0
# Term: uniquely, TF-IDF: 0.0
# Term: uniswap, TF-IDF: 0.0
# Term: unit, TF-IDF: 0.0
# Term: united, TF-IDF: 0.0
# Term: units, TF-IDF: 0.0
# Term: unless, TF-IDF: 0.0
# Term: unlike, TF-IDF: 0.0
# Term: unlikely, TF-IDF: 0.0
# Term: unlimited, TF-IDF: 0.0
# Term: unlocked, TF-IDF: 0.0
# Term: unm, TF-IDF: 0.0
# Term: unnamed, TF-IDF: 0.0
# Term: unparalleled, TF-IDF: 0.0
# Term: unprecedented, TF-IDF: 0.0
# Term: unprofitable, TF-IDF: 0.0
# Term: unregistered, TF-IDF: 0.0
# Term: unregulated, TF-IDF: 0.0
# Term: unsc, TF-IDF: 0.0
# Term: unseat, TF-IDF: 0.0
# Term: until, TF-IDF: 0.0
# Term: untouched, TF-IDF: 0.0
# Term: unum, TF-IDF: 0.0
# Term: up, TF-IDF: 0.013850914949399547
# Term: update, TF-IDF: 0.0
# Term: updated, TF-IDF: 0.0
# Term: updates, TF-IDF: 0.0
# Term: upfront, TF-IDF: 0.0
# Term: upgrades, TF-IDF: 0.0
# Term: ups, TF-IDF: 0.0
# Term: upside, TF-IDF: 0.0
# Term: upstart, TF-IDF: 0.0
# Term: uptick, TF-IDF: 0.0
# Term: upward, TF-IDF: 0.0
# Term: urban, TF-IDF: 0.0
# Term: us, TF-IDF: 0.060941513880625096
# Term: usage, TF-IDF: 0.0
# Term: usd, TF-IDF: 0.0
# Term: usdc, TF-IDF: 0.0
# Term: usdo, TF-IDF: 0.0
# Term: usdt, TF-IDF: 0.0
# Term: use, TF-IDF: 0.0
# Term: used, TF-IDF: 0.0
# Term: useful, TF-IDF: 0.0
# Term: usernames, TF-IDF: 0.0
# Term: users, TF-IDF: 0.026776760971017177
# Term: uses, TF-IDF: 0.0
# Term: using, TF-IDF: 0.0
# Term: usual, TF-IDF: 0.0
# Term: usually, TF-IDF: 0.0
# Term: utc, TF-IDF: 0.0
# Term: utilities, TF-IDF: 0.0
# Term: utility, TF-IDF: 0.0
# Term: utilizing, TF-IDF: 0.0
# Term: uup, TF-IDF: 0.0
# Term: uyeda, TF-IDF: 0.0
# Term: validate, TF-IDF: 0.0
# Term: validates, TF-IDF: 0.0
# Term: validating, TF-IDF: 0.0
# Term: validation, TF-IDF: 0.0
# Term: valuable, TF-IDF: 0.0
# Term: valuation, TF-IDF: 0.0
# Term: value, TF-IDF: 0.0
# Term: values, TF-IDF: 0.0
# Term: valuing, TF-IDF: 0.0
# Term: vaneck, TF-IDF: 0.0
# Term: vaporware, TF-IDF: 0.0
# Term: varied, TF-IDF: 0.0
# Term: variety, TF-IDF: 0.0
# Term: various, TF-IDF: 0.0
# Term: vasps, TF-IDF: 0.0
# Term: vast, TF-IDF: 0.0
# Term: ve, TF-IDF: 0.030557328577388205
# Term: vehicle, TF-IDF: 0.0
# Term: venezuela, TF-IDF: 0.0
# Term: venture, TF-IDF: 0.028476732085114826
# Term: ventures, TF-IDF: 0.0
# Term: verdict, TF-IDF: 0.0
# Term: verify, TF-IDF: 0.0
# Term: verizon, TF-IDF: 0.14808100635278806
# Term: versus, TF-IDF: 0.0
# Term: very, TF-IDF: 0.0
# Term: vestberg, TF-IDF: 0.037020251588197016
# Term: vetle, TF-IDF: 0.0
# Term: via, TF-IDF: 0.0
# Term: viability, TF-IDF: 0.0
# Term: viable, TF-IDF: 0.0
# Term: viabtc, TF-IDF: 0.0
# Term: vibes, TF-IDF: 0.0
# Term: view, TF-IDF: 0.018648053954682088
# Term: viewable, TF-IDF: 0.0
# Term: viewed, TF-IDF: 0.0
# Term: views, TF-IDF: 0.0
# Term: violating, TF-IDF: 0.0
# Term: virgin, TF-IDF: 0.0
# Term: virginia, TF-IDF: 0.0
# Term: virtual, TF-IDF: 0.0
# Term: virtually, TF-IDF: 0.0
# Term: vision, TF-IDF: 0.0
# Term: visit, TF-IDF: 0.0
# Term: vitanza, TF-IDF: 0.0
# Term: voice, TF-IDF: 0.0
# Term: voiced, TF-IDF: 0.0
# Term: voices, TF-IDF: 0.0
# Term: volatile, TF-IDF: 0.0
# Term: volatility, TF-IDF: 0.02112513438659526
# Term: volcano, TF-IDF: 0.0
# Term: volume, TF-IDF: 0.0
# Term: volumes, TF-IDF: 0.0
# Term: von, TF-IDF: 0.0
# Term: vote, TF-IDF: 0.0
# Term: voted, TF-IDF: 0.0
# Term: vulnerability, TF-IDF: 0.0
# Term: vz, TF-IDF: 0.07404050317639403
# Term: wage, TF-IDF: 0.0
# Term: waitlisters, TF-IDF: 0.0
# Term: wake, TF-IDF: 0.0
# Term: wall, TF-IDF: 0.0
# Term: walled, TF-IDF: 0.0
# Term: wallet, TF-IDF: 0.0
# Term: wallets, TF-IDF: 0.0
# Term: waning, TF-IDF: 0.0
# Term: want, TF-IDF: 0.0
# Term: warner, TF-IDF: 0.0
# Term: warns, TF-IDF: 0.0
# Term: warranty, TF-IDF: 0.0
# Term: warren, TF-IDF: 0.0
# Term: was, TF-IDF: 0.0
# Term: wasabi, TF-IDF: 0.0
# Term: washington, TF-IDF: 0.0
# Term: wasn, TF-IDF: 0.0
# Term: watch, TF-IDF: 0.0
# Term: watchers, TF-IDF: 0.0
# Term: water, TF-IDF: 0.0
# Term: watershed, TF-IDF: 0.0
# Term: wave, TF-IDF: 0.0
# Term: way, TF-IDF: 0.0
# Term: ways, TF-IDF: 0.0
# Term: wbd, TF-IDF: 0.0
# Term: we, TF-IDF: 0.0
# Term: weak, TF-IDF: 0.0
# Term: weakened, TF-IDF: 0.0
# Term: weakening, TF-IDF: 0.0
# Term: weaker, TF-IDF: 0.0
# Term: weakest, TF-IDF: 0.0
# Term: weakness, TF-IDF: 0.0
# Term: wealth, TF-IDF: 0.0
# Term: weapon, TF-IDF: 0.0
# Term: weapons, TF-IDF: 0.0
# Term: wear, TF-IDF: 0.0
# Term: weather, TF-IDF: 0.037020251588197016
# Term: web, TF-IDF: 0.0
# Term: web3, TF-IDF: 0.0
# Term: website, TF-IDF: 0.0
# Term: wednesday, TF-IDF: 0.0
# Term: week, TF-IDF: 0.0
# Term: weekend, TF-IDF: 0.0
# Term: weeks, TF-IDF: 0.0
# Term: weighting, TF-IDF: 0.0
# Term: welcomed, TF-IDF: 0.0
# Term: well, TF-IDF: 0.02112513438659526
# Term: went, TF-IDF: 0.0
# Term: were, TF-IDF: 0.0
# Term: western, TF-IDF: 0.0
# Term: weth, TF-IDF: 0.0
# Term: whales, TF-IDF: 0.0
# Term: what, TF-IDF: 0.0
# Term: when, TF-IDF: 0.0
# Term: where, TF-IDF: 0.0
# Term: whether, TF-IDF: 0.0
# Term: which, TF-IDF: 0.0
# Term: while, TF-IDF: 0.014247741942385633
# Term: whilst, TF-IDF: 0.0
# Term: who, TF-IDF: 0.0
# Term: whose, TF-IDF: 0.0
# Term: why, TF-IDF: 0.0
# Term: wide, TF-IDF: 0.0
# Term: widely, TF-IDF: 0.0
# Term: wider, TF-IDF: 0.0
# Term: widespread, TF-IDF: 0.0
# Term: wif, TF-IDF: 0.0
# Term: wild, TF-IDF: 0.0
# Term: wildly, TF-IDF: 0.0
# Term: will, TF-IDF: 0.0
# Term: windows, TF-IDF: 0.0
# Term: winning, TF-IDF: 0.0
# Term: wins, TF-IDF: 0.0
# Term: wisdom, TF-IDF: 0.037020251588197016
# Term: wise, TF-IDF: 0.0
# Term: wishing, TF-IDF: 0.0
# Term: with, TF-IDF: 0.058889271411282425
# Term: within, TF-IDF: 0.0
# Term: without, TF-IDF: 0.0
# Term: woburn, TF-IDF: 0.0
# Term: woes, TF-IDF: 0.0
# Term: won, TF-IDF: 0.0
# Term: wonder, TF-IDF: 0.0
# Term: wood, TF-IDF: 0.0
# Term: words, TF-IDF: 0.0
# Term: work, TF-IDF: 0.0
# Term: worked, TF-IDF: 0.0
# Term: worker, TF-IDF: 0.0
# Term: working, TF-IDF: 0.0
# Term: works, TF-IDF: 0.0
# Term: world, TF-IDF: 0.0
# Term: worldwide, TF-IDF: 0.0
# Term: worrying, TF-IDF: 0.0
# Term: worst, TF-IDF: 0.0
# Term: worth, TF-IDF: 0.0
# Term: worthless, TF-IDF: 0.0
# Term: would, TF-IDF: 0.0
# Term: wouldn, TF-IDF: 0.0
# Term: wrap, TF-IDF: 0.0
# Term: wrapped, TF-IDF: 0.0
# Term: write, TF-IDF: 0.0
# Term: writing, TF-IDF: 0.0
# Term: writte, TF-IDF: 0.0
# Term: wrote, TF-IDF: 0.0
# Term: wünscher, TF-IDF: 0.0
# Term: xle, TF-IDF: 0.0
# Term: xlu, TF-IDF: 0.0
# Term: xrp, TF-IDF: 0.0
# Term: yahoo, TF-IDF: 0.037020251588197016
# Term: year, TF-IDF: 0.05540365979759819
# Term: years, TF-IDF: 0.015095965256552516
# Term: yellen, TF-IDF: 0.0
# Term: yen, TF-IDF: 0.0
# Term: yesterday, TF-IDF: 0.0
# Term: yet, TF-IDF: 0.0
# Term: yield, TF-IDF: 0.21390130004171742
# Term: yields, TF-IDF: 0.030557328577388205
# Term: york, TF-IDF: 0.0
# Term: you, TF-IDF: 0.07331105687893225
# Term: younger, TF-IDF: 0.0
# Term: your, TF-IDF: 0.04062767592041673
# Term: zach, TF-IDF: 0.0
# Term: zachxbt, TF-IDF: 0.0
# Term: zacks, TF-IDF: 0.0
# Term: zero, TF-IDF: 0.0
# Term: zhao, TF-IDF: 0.0
# Term: zooming, TF-IDF: 0.0
